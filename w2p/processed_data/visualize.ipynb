# %%
#visualize light curves

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
global_view=pd.read_csv('globalbinned.csv')
local_view=pd.read_csv('localbinned.csv')
print(global_view.head(10))
print('global_view shape:',global_view.shape)
print('local_view shape:',local_view.shape)
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.014559  0.068393 -0.138818  0.022008 -0.167936 -0.073134  0.090063
# 1  0.005354  0.009204  0.004280  0.003521  0.000064 -0.003665  0.006399
# 2  0.011717  0.006695 -0.010160  0.028366 -0.026076 -0.003582  0.007106
# 3  0.036590 -0.007479 -0.052008 -0.022667 -0.089173 -0.018525 -0.062478
# 4  0.181464 -0.085867 -0.103381  0.207979 -0.103746 -0.014960  0.092921
#
#           7         8         9  ...      1991      1992      1993      1994  \
# 0 -0.000677  0.023362  0.177078  ... -0.316066  0.149653 -0.058067 -0.115964
# 1  0.002018 -0.004974 -0.003142  ... -0.005762  0.005268 -0.007007 -0.016390
# 2  0.002496  0.004199 -0.003098  ...  0.014447  0.021495 -0.000514 -0.001204
# 3 -0.160741 -0.004718 -0.047866  ... -0.022207  0.131170 -0.069267 -0.154873
# 4  0.054488 -0.109219  0.089029  ...  0.006568 -0.073218 -0.103260  0.000487
#
#        1995      1996      1997      1998      1999      2000
# ...

# %%
global_view.loc[1]
# Out:
# 0       0.005354
# 1       0.009204
# 2       0.004280
# 3       0.003521
# 4       0.000064
#           ...
# 1996    0.001603
# 1997   -0.000744
# 1998    0.003550
# 1999    0.004251
# 2000    0.002276
# Name: 1, Length: 2001, dtype: float64

# %%
sns.scatterplot(data=global_view.loc[1])

# %%
sns.scatterplot(data=local_view.loc[1])

# %%
sns.scatterplot(data=global_view.loc[2])

# %%
sns.scatterplot(data=local_view.loc[2])

# %%
# !ls -l
# Out:
# total 10940
# -rw-rw-r-- 1 ubuntu ubuntu   56273 Oct 15 20:47 Untitled.ipynb
# -rw-rw-r-- 1 ubuntu ubuntu 3113303 Oct 14 22:02 flattened.csv
# -rw-rw-r-- 1 ubuntu ubuntu 2350252 Oct 14 22:02 flattened.pkl
# -rw-rw-r-- 1 ubuntu ubuntu 3113303 Oct 14 22:02 folded.csv
# -rw-rw-r-- 1 ubuntu ubuntu 2350252 Oct 14 22:02 folded.pkl
# -rw-rw-r-- 1 ubuntu ubuntu   10317 Oct 14 22:02 globalbinned.csv
# -rw-rw-r-- 1 ubuntu ubuntu    7953 Oct 14 22:02 globalbinned.pkl
# -rw-rw-r-- 1 ubuntu ubuntu  106651 Oct 14 22:02 localbinned.csv
# -rw-rw-r-- 1 ubuntu ubuntu   72766 Oct 14 22:02 localbinned.pkl
# -rw-rw-r-- 1 ubuntu ubuntu     159 Oct 15 20:20 visualize.py

# %%
flattened=pd.read_csv('flattened.csv')

# %%
print(flattened.shape)
flattened.head()
# Out:
# (5, 65264)
#           0         1         2        3         4         5         6  \
# 0  1.001210  0.998266  0.999892  1.00204  0.999048  0.992263  0.991363
# 1  0.999963  0.999156  1.000510  1.00059  0.999206  0.999097  0.999560
# 2  1.000870  0.999998  0.999852  1.00007  0.999802  0.999618  0.999796
# 3  0.999937  0.999905  0.999804  1.00006  1.000130  1.000160  1.000230
# 4  0.997028  0.988661  1.003910  1.00030  0.989006  0.998678  1.008480
#
#           7         8         9  ...     65254     65255     65256     65257  \
# 0  1.001410  1.012170  1.008470  ...  0.992284  0.985245  0.993118  1.007320
# 1  1.001070  1.000090  0.999354  ...  0.999547  0.999114  0.999652  1.000950
# 2  0.999719  0.999884  0.999859  ...  0.999642  1.000120  0.999319  0.999737
# 3  0.999966  0.999985  1.000040  ...       NaN       NaN       NaN       NaN
# 4  0.998888  0.997696  1.002680  ...  0.998938  1.003200  1.001180  1.000760
#
#      65258     65259     65260     65261     65262     65263
# ...

# %%
plt.plot(flattened.loc[0],'.')
# Out:
# Error in callback <function flush_figures at 0x7fb106deb680> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/envs/thesis/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~/anaconda3/envs/thesis/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# ...
