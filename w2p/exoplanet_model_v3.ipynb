# %% [markdown]
# ## Exoplanet Model

# %% [markdown]
# ### Import packages and set constants

# %%
import pydot
import numpy as np
import tensorflow as tf
import pandas as pd 
import matplotlib.pyplot as plt
import cv2
import os
import shutil
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
import io
from keras.utils import plot_model
import random
import yaml
#import ktrain
from astropy.io import ascii as ap_ascii
import seaborn as sns
import os
import IPython
import time

import matplotlib as mpl
from sklearn.metrics import roc_curve
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import RandomizedSearchCV
import kerastuner as kt

pd.set_option('display.float_format', lambda x: '%.5f' % x)
mpl.rcParams['figure.figsize'] = (12, 10)
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
np.set_printoptions(precision=None, suppress=True)

from helpers.visualize import chart_curves 
from definitions import PROCESSED_DATA_DIR,PROCESSED_DATA_CATALOG
#PROCESSED_DATA_DIR='processed_data'
TCE_LIST='tce_table.csv'
FAILED_LIST='failed_kepids.csv'
MODEL_DIR='models'
BATCH_SIZE=96

METRICS = [
          tf.keras.metrics.TruePositives(name='tp'),
          tf.keras.metrics.FalsePositives(name='fp'),
          tf.keras.metrics.TrueNegatives(name='tn'),
          tf.keras.metrics.FalseNegatives(name='fn'), 
          tf.keras.metrics.BinaryAccuracy(name='accuracy'),
          tf.keras.metrics.Precision(name='precision'),
          tf.keras.metrics.Recall(name='recall'),
          tf.keras.metrics.AUC(name='auc')
    ]

# %% [markdown]
# ### Model analysis plotting and charting functions

# %%
def plot_metrics(history):
    metrics =  ['loss', 'accuracy', 'precision', 'recall']
    for n, metric in enumerate(metrics):
        name = metric.replace("_"," ").capitalize()
        plt.subplot(2,2,n+1)
        plt.plot(history.epoch,  history.history[metric], color=colors[0], label='Train')
        plt.plot(history.epoch, history.history['val_'+metric],
                 color=colors[0], linestyle="--", label='Val')
        plt.xlabel('Epoch')
        plt.ylabel(name)
        if metric == 'loss':
          plt.ylim([0, plt.ylim()[1]])
        elif metric == 'auc':
          plt.ylim([0.8,1])
        else:
          plt.ylim([0,1])

        plt.legend()
    plt.show()


#roc curve
def plot_roc(name, labels, predictions, **kwargs):
    fp, tp, _ = roc_curve(labels, predictions)

    plt.plot(100*fp, 100*tp, label=name, linewidth=2, **kwargs)
    plt.xlabel('False positives [%]')
    plt.ylabel('True positives [%]')
    plt.xlim([-0.5,20])
    plt.ylim([80,100.5])
    plt.grid(True)
    ax = plt.gca()
    ax.set_aspect('equal')
    

#confusion matrix
def plot_cm(labels, predictions, p=0.5):
    cm = confusion_matrix(labels, predictions > p)
    plt.figure(figsize=(5,5))
    sns.heatmap(cm, annot=True, fmt="d")
    plt.title('Confusion matrix @{:.2f}'.format(p))
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')
    plt.show()
    
    print('Not Planets Properly Categorized (True Negatives): ', cm[0][0])
    print('Not Planets Categorized as Planets Detected (False Positives): ', cm[0][1])
    print('Planets Missed (False Negatives): ', cm[1][0])
    print('Planets Properly Categorized (True Positives): ', cm[1][1])
    print('Total Planets: ', np.sum(cm[1]))
    print('Accuracy: ',(cm[0][0]+cm[1][1])/len(predictions))
    
#takes in the tce index number, the tce id table, the results table (which figures out tp etc),
#and the two vector tables and then calls the visualization helper function which
#creates a chart and saves inside of processed_data folder structure
def chart(tce_number,tce_id,results,x_global,x_local):
    kepid=tce_id.loc[tce_number].kepid
    result=val_results.loc[tce_number].result
    tce_plnt_num=tce_id.loc[tce_number].tce_plnt_num
    chart_curves(str(kepid),tce_plnt_num,
             result,
             x_global_val[tce_number],x_local_val[tce_number])

def model_results(model):
    val_predictions_baseline = model.predict([x_local_val,x_global_val], batch_size=BATCH_SIZE)
    train_predictions_baseline = model.predict([x_local_train,x_global_train], batch_size=BATCH_SIZE)
    plot_cm(Y_val, val_predictions_baseline,p=.6)
    plot_cm(Y_val, val_predictions_baseline)
    plot_cm(Y_val, val_predictions_baseline,p=.4)
    try:
        plot_metrics(history)
    except:
        print('No history available')

    plot_roc("Train Baseline", Y_train, train_predictions_baseline, color=colors[0])
    plot_roc("Test Baseline", Y_val, val_predictions_baseline, color=colors[0], linestyle='--')
    plt.legend(loc='lower right')
    return (val_predictions_baseline,train_predictions_baseline)

# %% [markdown]
# ### Model utility functions

# %%
def load_model(model_name):
    model = tf.keras.models.load_model(os.path.join(MODEL_DIR,model_name))
    return model

def save_model(model_name):
    model.save(os.path.join(MODEL_DIR,model_name))
    
def model_picture(model,model_name):
    tf.keras.utils.plot_model(
        model, to_file=os.path.join(MODEL_DIR,model_name+'.png'), show_shapes=True, show_layer_names=True,
        rankdir='TB', expand_nested=True, dpi=96
    )

# %%
#takes in model and creates full prediction file etc
def create_prediction_output(model,name):
    full_predictions = model.predict([x_local,x_global])
        
    print('Predictions shape from w2p model:',full_predictions.shape)
    print('Original Y shape:',Y.shape)
    plot_cm(Y, full_predictions)

    #this builds a temp df with just the processed tces and w2p result
    temp_df=pd.DataFrame()
    temp_df['kepid']=processed.kepid
    temp_df['tce_plnt_num']=processed.tce_plnt_num
    temp_df['w2p_score']=full_predictions
    
    #this merges into full file (including the ~500 that did not have processed light curves)
    #and then for those that the model did not run on, puts w2p prob at 0
    processed_final=original.merge(temp_df,how='outer',left_on=['kepid','tce_plnt_num'],right_on=['kepid','tce_plnt_num'])
    processed_final.w2p_score = processed_final.w2p_score.fillna(0)
    
    
    processed_final['w2p_disposition']='FALSE POSITIVE'
    processed_final.loc[processed_final.w2p_score>=0.5,['w2p_disposition']]='CONFIRMED'
    processed_final.replace({'koi_disposition':
                       {'1-CONFIRMED':'CONFIRMED','0-FALSE POSITIVE':'FALSE POSITIVE'}},
                      inplace=True)
    
    print('processed_final shape:',processed_final.shape)
    #key columns to compare
    #koi_disposition
    #https://exoplanetarchive.ipac.caltech.edu/docs/API_kepcandidate_columns.html
    #https://exoplanetarchive.ipac.caltech.edu/docs/API_kepcandidate_columns.html (has AV descriptions)
    #koi_pdisposition and koi_score are ROBOVETTER outcomes (where available)
    print('w2p_disposition:',processed_final.w2p_disposition.value_counts())
    print('koi disposition:',processed_final.koi_disposition.value_counts())
    print('koi pdisposition:',processed_final.koi_pdisposition.value_counts())
    print('koi pdisposition:',processed_final.koi_pdisposition.value_counts())

    #av_pp_pc is posterior probability score from autovetter model (where available).  
    #Have divided by 100 to make comparable to koi_score
    #and created a column representing AV disposition / unclear how differs from av_pred_class
    processed_final.av_vf_pc=processed_final.av_vf_pc/100
    processed_final['av_disposition']='FALSE POSITIVE'
    processed_final.loc[processed_final.av_vf_pc>.5,['av_disposition']]='CONFIRMED'
    print('AV disposition:',processed_final.av_disposition.value_counts())

    #replacing koi_score with zero where NAN.  Only 8000 of TCEs had koi_score and koi_pdisposition (ie robovetter)
    #same with av_vf_pc
    processed_final.koi_score.fillna(0,inplace=True)
    processed_final.av_vf_pc.fillna(0,inplace=True)

    #koi_score is RV monte carlo prob.  koi_pdisposition is some subjective measure beyond RV score
    processed_final[(processed_final.koi_score>=0.5)&(processed_final.koi_pdisposition=='FALSE POSITIVE')][[
        'kepid','tce_plnt_num','koi_disposition','koi_score','koi_pdisposition','w2p_score','w2p_disposition','av_disposition','av_vf_pc']]

    print(processed_final[[
        'kepid','tce_plnt_num','koi_disposition',
        'w2p_score','w2p_disposition',
        'koi_score','koi_pdisposition',
        'av_disposition','av_vf_pc']])

    print('Accuracy after adding back non-processed kepids:',sum(processed_final.koi_disposition==processed_final.w2p_disposition)/processed_final.shape[0])
    processed_final.to_csv(os.path.join(PROCESSED_DATA_DIR,name+'_final.csv'),index=False)
    return processed_final

# %% [markdown]
# ### Read in and process data for use in model

# %%
def get_data():
    #this excludes from tce_list those kepids and planet numbers that failed make_data process
    original=pd.read_csv(os.path.join(PROCESSED_DATA_DIR,TCE_LIST))
    processed=original.copy()
    try:
        failed=pd.read_csv(os.path.join(PROCESSED_DATA_DIR,FAILED_LIST))
        failed.columns=['kepid','tce_plnt_num']
        print(failed.shape)
        for index,row in failed.iterrows():
            processed.drop(processed[(processed.kepid==row.kepid) & 
                                     (processed.tce_plnt_num==row.tce_plnt_num)].index,inplace=True)
    except:
        pass

    processed=processed.reset_index(drop=True)
    print('Shape of processed file:',processed.shape)

    #all of the failed KEPIDs from preprocessing pipeline are FALSE POSITIVES

    #save processed list back out (so excludes those KEPIDS/PLNTs with NO light curves)
    processed.to_csv(os.path.join(PROCESSED_DATA_DIR,PROCESSED_DATA_CATALOG),index=False)
    
    
    print('Original TCE list:',original.koi_disposition.value_counts())
    print('Processed TCE list:',processed.koi_disposition.value_counts())

    #combine confirmed and candidate
    #using 0 and 1 in front of name to force positive class to be planets
    processed.replace({'koi_disposition':
                       {'CANDIDATE':'1-CONFIRMED','CONFIRMED':'1-CONFIRMED','FALSE POSITIVE':'0-FALSE POSITIVE'}},
                      inplace=True)
    original.replace({'koi_disposition':
                       {'CANDIDATE':'1-CONFIRMED','CONFIRMED':'1-CONFIRMED','FALSE POSITIVE':'0-FALSE POSITIVE'}},
                      inplace=True)

    print(processed.koi_disposition.value_counts())
    print('Baseline accuracy:', processed[processed.koi_disposition=='0-FALSE POSITIVE'].shape[0]/processed.shape[0])

    
    LOCAL='localbinned_df.csv'
    GLOBAL='globalbinned_df.csv'
    x_local=pd.read_csv(os.path.join(PROCESSED_DATA_DIR,LOCAL))
    x_global=pd.read_csv(os.path.join(PROCESSED_DATA_DIR,GLOBAL))
    print(x_local.shape)
    print(x_global.shape)
    
    
    #add kepid and tce_plnt_number to x
    tce_id=pd.DataFrame()
    tce_id['kepid']=processed.kepid.astype('int')
    tce_id['tce_plnt_num']=processed.tce_plnt_num.astype('int')
    tce_id['koi_disposition']=processed.koi_disposition
    
    #turn into numpy arrays/series
    x_local=x_local.to_numpy()
    x_global=x_global.to_numpy()
    print(x_local.shape)
    print(x_global.shape)
    
    #can print out charts
    tce_number=3
    chart_curves(tce_id.kepid[tce_number],
                 tce_id.tce_plnt_num[tce_number],
                 x_global[tce_number],
                 x_local[tce_number],
                 tce_id.koi_disposition[tce_number])
    
    tce_number=4
    chart_curves(tce_id.kepid[tce_number],
                 tce_id.tce_plnt_num[tce_number],
                 x_global[tce_number],
                 x_local[tce_number],
                 tce_id.koi_disposition[tce_number])
    
    
    #Conv1D layers take in tensors of dimension (length of vector = 201 or 2001, and dimensions of vector=1)
    #So as with Conv2D in BW where need to add a color dimension here have to specify that there is only one
    #dimension in each vector
    x_local=np.expand_dims(x_local,axis=2)
    x_global=np.expand_dims(x_global,axis=2)

    print(x_local.shape)
    print(x_global.shape)
    
    #turn output into categorical variable with encoding
    Y=processed.koi_disposition
    le=LabelEncoder()
    le.fit(['1-CONFIRMED','0-FALSE POSITIVE'])
    Y=le.transform(Y)
    
    x_local_train, x_local_val, x_global_train, x_global_val, Y_train, Y_val,tce_id_train,tce_id_val = train_test_split(
    x_local,x_global, Y,tce_id, test_size=0.2)


    return (x_local, x_local_train, x_local_val, 
            x_global, x_global_train, x_global_val, 
            Y, Y_train, Y_val,
            tce_id,tce_id_train,tce_id_val,
            processed,original)


x_local, x_local_train, x_local_val, x_global, x_global_train, x_global_val, Y, Y_train, Y_val,tce_id, tce_id_train,tce_id_val,processed,original=get_data()   
print(x_local_train.shape)
print(x_global_train.shape)
print(Y_train.shape)
print(tce_id_train.shape)
print(x_local_val.shape)
print(x_global_val.shape)
print(Y_val.shape)
print(tce_id_val.shape)
# Out:
# (438, 2)
# Shape of processed file: (33594, 86)
# Original TCE list: FALSE POSITIVE    29835
# CONFIRMED          2345
# CANDIDATE          1852
# Name: koi_disposition, dtype: int64
# Processed TCE list: FALSE POSITIVE    29397
# CONFIRMED          2345
# CANDIDATE          1852
# Name: koi_disposition, dtype: int64
# 0-FALSE POSITIVE    29397
# 1-CONFIRMED          4197
# Name: koi_disposition, dtype: int64
# Baseline accuracy: 0.8750669762457581
# (33594, 201)
# (33594, 2001)
# (33594, 201)
# (33594, 2001)
# (33594, 201, 1)
# (33594, 2001, 1)
# (26875, 201, 1)
# (26875, 2001, 1)
# (26875,)
# (26875, 3)
# (6719, 201, 1)
# (6719, 2001, 1)
# (6719,)
# (6719, 3)

# %% [markdown]
# ### Build W2P CNN Model

# %%
def make_w2p_cnn_model():
    
    input_local = tf.keras.layers.Input(shape=[x_local_train.shape[1],1])
    input_global=tf.keras.layers.Input(shape=[x_global_train.shape[1],1])
    
    
    k_global=tf.keras.layers.Conv1D(filters=16,kernel_size=5,activation='relu')(input_global)
    k_global=tf.keras.layers.MaxPooling1D(pool_size=5,strides=2,padding='same')(k_global)
    k_global=tf.keras.layers.Conv1D(filters=32,kernel_size=5,activation='relu')(k_global)
    k_global=tf.keras.layers.MaxPooling1D(pool_size=5,strides=2,padding='same')(k_global)    
    k_global=tf.keras.layers.Conv1D(filters=64,kernel_size=5,activation='relu')(k_global)
    k_global=tf.keras.layers.MaxPooling1D(pool_size=5,strides=2,padding='same')(k_global)    
    
    
    k_local=tf.keras.layers.Conv1D(filters=16,kernel_size=5,activation='relu')(input_local)
    k_local=tf.keras.layers.MaxPooling1D(pool_size=7,strides=2,padding='same')(k_local)
    k_local=tf.keras.layers.Conv1D(filters=32,kernel_size=5,activation='relu')(k_local)
    k_local=tf.keras.layers.MaxPooling1D(pool_size=7,strides=2,padding='same')(k_local)
    
    #flatten
    k_global=tf.keras.layers.Flatten()(k_global)
    k_local=tf.keras.layers.Flatten()(k_local)
    
    #concatenate
    k =tf.keras.layers.concatenate([k_local, k_global])
    
    #dense layers
    k=tf.keras.layers.Dense(512,activation='relu')(k)
    k=tf.keras.layers.Dropout(0.4)(k)
    k=tf.keras.layers.Dense(512,activation='relu')(k)
    k=tf.keras.layers.Dropout(0.4)(k)
    k=tf.keras.layers.Dense(512,activation='relu')(k)
    k=tf.keras.layers.Dropout(0.4)(k)
    k=tf.keras.layers.Dense(512,activation='relu')(k)
    
    
    #output layer        
    output=tf.keras.layers.Dense(1,activation='sigmoid')(k)

    model=tf.keras.Model(inputs=[input_local,input_global],outputs=output)
    learning_rate=1e-5
    model.compile(loss=tf.keras.losses.BinaryCrossentropy()
                  ,optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
                  metrics=METRICS)
    return model

# %% [markdown]
# ### Run W2P CNN Model

# %%
EPOCHS=100
BATCH_SIZE=64

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy', 
    verbose=1,
    patience=7,
    mode='max',
    restore_best_weights=True)

model=make_w2p_cnn_model()
print(model.summary())

tf.keras.backend.clear_session()
history=model.fit([x_local_train,x_global_train],
                  Y_train,
                  validation_data=([x_local_val,x_global_val],Y_val),
                  epochs=EPOCHS,
                  batch_size=BATCH_SIZE,
                  callbacks=[early_stopping],
                  verbose=2)

# %%
#save model
model_name='best_cnn_model'
#save_model(model_name)

# %% [markdown]
# ### W2P CNN Model Results (loads model so can done without retraining)

# %%
model=load_model('best_cnn_model')

val_predictions_baseline, train_predictions_baseline=model_results(model)
model.summary()

#create picture of model
model_picture(model,model_name)
# Out:
# Not Planets Properly Categorized (True Negatives):  5846
# Not Planets Categorized as Planets Detected (False Positives):  54
# Planets Missed (False Negatives):  106
# Planets Properly Categorized (True Positives):  713
# Total Planets:  819
# Accuracy:  0.9761869325792528
# Not Planets Properly Categorized (True Negatives):  5838
# Not Planets Categorized as Planets Detected (False Positives):  62
# Planets Missed (False Negatives):  99
# Planets Properly Categorized (True Positives):  720
# Total Planets:  819
# Accuracy:  0.9760381009078732
# Not Planets Properly Categorized (True Negatives):  5824
# Not Planets Categorized as Planets Detected (False Positives):  76
# Planets Missed (False Negatives):  89
# Planets Properly Categorized (True Positives):  730
# Total Planets:  819
# Accuracy:  0.9754427742223545
# No history available
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 2001, 1)]    0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 1997, 16)     96          input_2[0][0]
# __________________________________________________________________________________________________
# input_1 (InputLayer)            [(None, 201, 1)]     0
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 999, 16)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 197, 16)      96          input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 995, 32)      2592        max_pooling1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 99, 16)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 498, 32)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 95, 32)       2592        max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 494, 64)      10304       max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 48, 32)       0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 247, 64)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1536)         0           max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 15808)        0           max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 17344)        0           flatten_1[0][0]
#                                                                  flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          8880640     concatenate[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          262656      dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          262656      dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 512)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 512)          262656      dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            513         dense_3[0][0]
# ==================================================================================================
# Total params: 9,684,801
# Trainable params: 9,684,801
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Create Output File for Full TCE List for W2P CNN Model

# %%
output_name='w2p_cnn'
processed_final=create_prediction_output(model,output_name)

# %% [markdown]
# #### Key column descriptions
# - koi_disposition:  ground truth
# - w2p_score: w2p probability
# - w2p_disposition: w2p disposition
# - koi_score: robovetter probability
# - koi_pdisposition: robovetter disposition (though does not exactly match up with koi_score>0.5- unclear why)
# - av_disposition: autovetter disposition (does not exactly match up with av_vf_pc>0- unclear why)
# - av_vf_pc: autovetter probability (not posterior)
#
# Links for other column descriptions:
#
# https://exoplanetarchive.ipac.caltech.edu/docs/API_kepcandidate_columns.html
#
# https://exoplanetarchive.ipac.caltech.edu/docs/API_tce_columns.html (has AV descriptions)

# %% [markdown]
# ### Error Analysis of W2P CNN Model

# %%
val_results=pd.DataFrame({'truth':Y_val, 'prediction':np.squeeze(val_predictions_baseline)})
val_results['truth_delta']=val_results.truth-val_results.prediction
val_results=val_results.sort_values('truth_delta')

val_results['result']='True Positive'
val_results.loc[val_results.truth_delta<0,'result']='True Negative' #then some get replaced by false positive
val_results.loc[val_results.truth_delta<=-0.5,'result']='False Positive'
val_results.loc[val_results.truth_delta>=0.5,'result']='False Negative'

print('Val_results',val_results.result.value_counts())

# %%
number_per_category=3

#FALSE POSITIVES
false_positives=val_results[val_results.truth_delta<=-.5]
#print('False positives:\n',false_positives)

for tce_number in false_positives.index[0:number_per_category]:
    chart_curves(tce_id_val.kepid.iloc[tce_number],
                 tce_id_val.tce_plnt_num.iloc[tce_number],
                 x_global_val[tce_number],
                 x_local_val[tce_number],
                 false_positives.loc[tce_number].result)#tce_id.koi_disposition[tce_number])
#FALSE NEGATIVES
false_negatives=val_results[val_results.truth_delta>=0.5].sort_values('truth_delta',ascending=False)
#print('False negatives:\n',false_negatives)

for tce_number in false_negatives.index[0:number_per_category]:
    chart_curves(tce_id_val.kepid.iloc[tce_number],
                 tce_id_val.tce_plnt_num.iloc[tce_number],
                 x_global_val[tce_number],
                 x_local_val[tce_number],
                 false_negatives.loc[tce_number].result)


#TRUE POSITIVES
true_positives=val_results[val_results.result=='True Positive'].sort_values('prediction',ascending=False)

#print('True positives:\n',true_positives)
for tce_number in true_positives.index[0:number_per_category]:
    chart_curves(tce_id_val.kepid.iloc[tce_number],
                 tce_id_val.tce_plnt_num.iloc[tce_number],
                 x_global_val[tce_number],
                 x_local_val[tce_number],
                 true_positives.loc[tce_number].result)

#TRUE NEGATIVES
true_negatives=val_results[val_results.result=='True Negative'].sort_values('prediction',ascending=True)

#print('True negatives:\n',true_negatives)
for tce_number in true_negatives.index[0:number_per_category]:
    chart_curves(tce_id_val.kepid.iloc[tce_number],
                 tce_id_val.tce_plnt_num.iloc[tce_number],
                 x_global_val[tce_number],
                 x_local_val[tce_number],
                 true_negatives.loc[tce_number].result)

# %%
cutoff=.05
val_results_mod=val_results[(val_results.truth_delta<-cutoff)|(val_results.truth_delta>cutoff)]
ax = sns.histplot(data=val_results_mod, 
                  x="truth_delta",
                  hue='result').set_title('Distribution of Deltas (excluding vast majority between -.05 and .05)')

# %%
val_results_mod=val_results[(val_results.prediction>cutoff)]
ax = sns.histplot(data=val_results_mod, 
                  x="prediction",
                  hue='result',
                  multiple='stack',
                  bins=30).set_title('Distribution of Validation Set Predictions (excluding true negatives <0.05)')

plt.axvline(0.5,0,30)

# %% [markdown]
# ### CNN model in format for use of Keras Tuner

# %%
#revised for keras-tuner
#model making that allows keras-tuner hyperparameter optimization to be run

def make_cnn_model(hp):
    #model = Sequential()   
    
    
    input_local = tf.keras.layers.Input(shape=[x_local_train.shape[1],1])
    input_global=tf.keras.layers.Input(shape=[x_global_train.shape[1],1])
    
    first_global_cnn_filters=hp.Int('first_global_cnn_filters',min_value=8,max_value=32,step=8)
    further_global_cnn_filters=hp.Int('further_global_cnn_filters',min_value=16,max_value=128, step=16)
    #can not have kernel greater than maxpool size?
    cnn_global_kernel=hp.Int('cnn_global_kernel',min_value=3,max_value=5,step=2)
    cnn_global_maxpool=hp.Int('cnn_global_maxpool',min_value=3,max_value=7,step=2)
    cnn_global_stride=hp.Int('cnn_global_stride',min_value=1,max_value=3,step=1)
    
    first_local_cnn_filters=hp.Int('first_local_cnn_filters',min_value=8,max_value=32,step=8)
    further_local_cnn_filters=hp.Int('further_local_cnn_filters',min_value=16,max_value=128, step=16)
    cnn_local_kernel=hp.Int('cnn_local_kernel',min_value=3,max_value=5,step=2)
    cnn_local_maxpool=hp.Int('cnn_local_maxpool',min_value=3,max_value=7,step=2)
    cnn_local_stride=hp.Int('cnn_local_stride',min_value=1,max_value=3,step=1)   
    
    cnn_activation=hp.Choice('cnn_activation',values=['relu'])#,'PReLU()'])
    
    
    #first global cnn
    k_global=tf.keras.layers.Conv1D(filters=first_global_cnn_filters,
                                    kernel_size=cnn_global_kernel,
                                    activation=cnn_activation)(input_global)
    
    k_global=tf.keras.layers.MaxPooling1D(pool_size=cnn_global_maxpool,
                                              strides=cnn_global_stride,padding='same')(k_global)
    
    #first local cnn
    k_local=tf.keras.layers.Conv1D(filters=first_local_cnn_filters,
                                    kernel_size=cnn_local_kernel,
                                    activation=cnn_activation)(input_local)
    
    k_local=tf.keras.layers.MaxPooling1D(pool_size=cnn_local_maxpool,
                                              strides=cnn_local_stride,padding='same')(k_local)
    
    
    
    further_global_cnn_layers=hp.Int('further_global_cnn_layers',min_value=1,max_value=3,step=1)
    further_local_cnn_layers=hp.Int('further_global_cnn_layers',min_value=1,max_value=3,step=1)
    
    for i in range(further_global_cnn_layers):
        k_global=tf.keras.layers.Conv1D(filters=further_global_cnn_filters,
                                    kernel_size=cnn_global_kernel,
                                    activation=cnn_activation)(k_global)
        k_global=tf.keras.layers.MaxPooling1D(pool_size=cnn_global_maxpool,
                                              strides=cnn_global_stride,padding='same')(k_global)
    
    for i in range(further_local_cnn_layers):
        k_local=tf.keras.layers.Conv1D(filters=further_local_cnn_filters,
                                    kernel_size=cnn_local_kernel,
                                    activation=cnn_activation)(k_local)
        k_local=tf.keras.layers.MaxPooling1D(pool_size=cnn_local_maxpool,
                                              strides=cnn_local_stride,padding='same')(k_local)
        
    #flatten and concatenate
    k_global=tf.keras.layers.Flatten()(k_global)
    k_local=tf.keras.layers.Flatten()(k_local)
    k = tf.keras.layers.concatenate([k_local, k_global])
    
    
    number_of_dense_layers=hp.Int('number_of_dense_layers',min_value=2,max_value=5,step=1)
    size_of_dense_layers=hp.Int('size_of_dense_layers',min_value=64, max_value=512, step=64)
    dense_activation=hp.Choice('dense_activation',values=['relu'])#,'PReLU()'])
    dense_dropout=hp.Choice('dense_dropout',values=[0.0,.2,.5])
    
    #now add dense layers
    for i in range(number_of_dense_layers):
        k=tf.keras.layers.Dense(size_of_dense_layers,activation=dense_activation)(k)
        k=tf.keras.layers.Dropout(dense_dropout)(k)
    
    #output layer        
    output=tf.keras.layers.Dense(1,activation='sigmoid')(k)

    model=tf.keras.Model(inputs=[input_local,input_global],outputs=output)

    learning_rate=hp.Choice('learning_rate',values=[1e-4,1e-5,1e-6])
    
    model.compile(loss=tf.keras.losses.BinaryCrossentropy()
                  ,optimizer=tf.keras.optimizers.Adam(learning_rate),
                  metrics=METRICS)
    return model

# %% [markdown]
# #### set up to run keras-tuner

# %%
OPTIMIZATION_DIRECTORY='w2p_optimization'


class MyTuner(kt.tuners.BayesianOptimization):
  def run_trial(self, trial, *args, **kwargs):
    # You can add additional HyperParameters for preprocessing and custom training loops
    # via overriding `run_trial`
    kwargs['batch_size'] = trial.hyperparameters.Int('batch_size', 32, 256, step=32)
    super(MyTuner, self).run_trial(trial, *args, **kwargs)

#tuner=kt.BayesianOptimization(
tuner=MyTuner(
    make_cnn_model,
    kt.Objective("val_accuracy",direction="max"),
    max_trials=100,
    executions_per_trial=1,
    project_name=OPTIMIZATION_DIRECTORY
    )


early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy', 
    verbose=1,
    patience=20,
    mode='max',
    restore_best_weights=True)

NUMBER_OF_EPOCHS=30
# Out:
# INFO:tensorflow:Reloading Oracle from existing project ./w2p_optimization/oracle.json
# INFO:tensorflow:Reloading Tuner from ./w2p_optimization/tuner0.json

# %% [markdown]
# #### now running tuner - this takes a long time
# Note directory removal if model structure has changed

# %%
#this is what takes a long time - does hyper paramater search

#have to remove parameter search history if make_model function has been changed in some way
dirpath=os.path.join(OPTIMIZATION_DIRECTORY)
if os.path.exists(dirpath) and os.path.isdir(dirpath):
    shutil.rmtree(dirpath)

#when change model structure, have to remove optimization directory to stop it from
#trying to continue on from old tuning session

start_time=time.time()
print ('Start',start_time)

tuner.search([x_local_train,x_global_train],
             Y_train,
             epochs = NUMBER_OF_EPOCHS, 
             validation_data=([x_local_val,x_global_val],Y_val),
             callbacks = [early_stopping],
             verbose=2)

end_time=time.time()

print('Start',start_time)
print ('End',end_time)
print('Duration (hours)',(end_time-start_time)/3600)
# Out:
# Start 1605873326.444573
# Epoch 1/10
# 840/840 - 21s - loss: 0.3710 - tp: 13.0000 - fp: 116.0000 - tn: 23382.0000 - fn: 3364.0000 - accuracy: 0.8705 - precision: 0.1008 - recall: 0.0038 - auc: 0.6924 - val_loss: 0.3291 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 5899.0000 - val_fn: 820.0000 - val_accuracy: 0.8780 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7772
# Epoch 2/10
# 840/840 - 19s - loss: 0.3066 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 23498.0000 - fn: 3377.0000 - accuracy: 0.8743 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.8288 - val_loss: 0.2755 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 5899.0000 - val_fn: 820.0000 - val_accuracy: 0.8780 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8919
# Epoch 3/10
# 840/840 - 22s - loss: 0.2532 - tp: 381.0000 - fp: 52.0000 - tn: 23446.0000 - fn: 2996.0000 - accuracy: 0.8866 - precision: 0.8799 - recall: 0.1128 - auc: 0.9162 - val_loss: 0.2308 - val_tp: 208.0000 - val_fp: 45.0000 - val_tn: 5854.0000 - val_fn: 612.0000 - val_accuracy: 0.9022 - val_precision: 0.8221 - val_recall: 0.2537 - val_auc: 0.9320
# Epoch 4/10
# 840/840 - 22s - loss: 0.2160 - tp: 1208.0000 - fp: 229.0000 - tn: 23269.0000 - fn: 2169.0000 - accuracy: 0.9108 - precision: 0.8406 - recall: 0.3577 - auc: 0.9418 - val_loss: 0.2038 - val_tp: 376.0000 - val_fp: 101.0000 - val_tn: 5798.0000 - val_fn: 444.0000 - val_accuracy: 0.9189 - val_precision: 0.7883 - val_recall: 0.4585 - val_auc: 0.9420
# Epoch 5/10
# 840/840 - 22s - loss: 0.1930 - tp: 1741.0000 - fp: 414.0000 - tn: 23084.0000 - fn: 1636.0000 - accuracy: 0.9237 - precision: 0.8079 - recall: 0.5155 - auc: 0.9478 - val_loss: 0.1871 - val_tp: 439.0000 - val_fp: 131.0000 - val_tn: 5768.0000 - val_fn: 381.0000 - val_accuracy: 0.9238 - val_precision: 0.7702 - val_recall: 0.5354 - val_auc: 0.9453
# Epoch 6/10
# 840/840 - 22s - loss: 0.1792 - tp: 2047.0000 - fp: 517.0000 - tn: 22981.0000 - fn: 1330.0000 - accuracy: 0.9313 - precision: 0.7984 - recall: 0.6062 - auc: 0.9507 - val_loss: 0.1800 - val_tp: 558.0000 - val_fp: 185.0000 - val_tn: 5714.0000 - val_fn: 262.0000 - val_accuracy: 0.9335 - val_precision: 0.7510 - val_recall: 0.6805 - val_auc: 0.9483
# Epoch 7/10
# 840/840 - 20s - loss: 0.1710 - tp: 2209.0000 - fp: 590.0000 - tn: 22908.0000 - fn: 1168.0000 - accuracy: 0.9346 - precision: 0.7892 - recall: 0.6541 - auc: 0.9529 - val_loss: 0.1717 - val_tp: 531.0000 - val_fp: 161.0000 - val_tn: 5738.0000 - val_fn: 289.0000 - val_accuracy: 0.9330 - val_precision: 0.7673 - val_recall: 0.6476 - val_auc: 0.9497
# Epoch 8/10
# 840/840 - 20s - loss: 0.1655 - tp: 2303.0000 - fp: 629.0000 - tn: 22869.0000 - fn: 1074.0000 - accuracy: 0.9366 - precision: 0.7855 - recall: 0.6820 - auc: 0.9545 - val_loss: 0.1681 - val_tp: 537.0000 - val_fp: 166.0000 - val_tn: 5733.0000 - val_fn: 283.0000 - val_accuracy: 0.9332 - val_precision: 0.7639 - val_recall: 0.6549 - val_auc: 0.9506
# Epoch 9/10
# 840/840 - 22s - loss: 0.1620 - tp: 2363.0000 - fp: 647.0000 - tn: 22851.0000 - fn: 1014.0000 - accuracy: 0.9382 - precision: 0.7850 - recall: 0.6997 - auc: 0.9556 - val_loss: 0.1653 - val_tp: 549.0000 - val_fp: 173.0000 - val_tn: 5726.0000 - val_fn: 271.0000 - val_accuracy: 0.9339 - val_precision: 0.7604 - val_recall: 0.6695 - val_auc: 0.9522
# Epoch 10/10
# 840/840 - 20s - loss: 0.1589 - tp: 2407.0000 - fp: 657.0000 - tn: 22841.0000 - fn: 970.0000 - accuracy: 0.9395 - precision: 0.7856 - recall: 0.7128 - auc: 0.9568 - val_loss: 0.1635 - val_tp: 549.0000 - val_fp: 173.0000 - val_tn: 5726.0000 - val_fn: 271.0000 - val_accuracy: 0.9339 - val_precision: 0.7604 - val_recall: 0.6695 - val_auc: 0.9526
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 0178df68ac34c50d69d87547e4416602</span>
# <span style="color:cyan"> |-Score: 0.9339187145233154</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-batch_size: 32</span>
# <span style="color:blue"> |-cnn_activation: relu</span>
# <span style="color:cyan"> |-cnn_global_kernel: 5</span>
# <span style="color:blue"> |-cnn_global_maxpool: 7</span>
# <span style="color:cyan"> |-cnn_global_stride: 1</span>
# <span style="color:blue"> |-cnn_local_kernel: 3</span>
# <span style="color:cyan"> |-cnn_local_maxpool: 5</span>
# <span style="color:blue"> |-cnn_local_stride: 3</span>
# <span style="color:cyan"> |-dense_activation: relu</span>
# <span style="color:blue"> |-dense_dropout: 0.0</span>
# <span style="color:cyan"> |-first_global_cnn_filters: 8</span>
# <span style="color:blue"> |-first_local_cnn_filters: 24</span>
# <span style="color:cyan"> |-further_global_cnn_filters: 64</span>
# <span style="color:blue"> |-further_global_cnn_layers: 2</span>
# <span style="color:cyan"> |-further_local_cnn_filters: 32</span>
# <span style="color:blue"> |-learning_rate: 1e-06</span>
# <span style="color:cyan"> |-number_of_dense_layers: 2</span>
# <span style="color:blue"> |-size_of_dense_layers: 384</span>
# Epoch 1/10
# 840/840 - 9s - loss: 0.1873 - tp: 2552.0000 - fp: 739.0000 - tn: 28658.0000 - fn: 1645.0000 - accuracy: 0.9290 - precision: 0.7754 - recall: 0.6081 - auc: 0.9443 - val_loss: 0.1348 - val_tp: 674.0000 - val_fp: 199.0000 - val_tn: 5700.0000 - val_fn: 146.0000 - val_accuracy: 0.9487 - val_precision: 0.7721 - val_recall: 0.8220 - val_auc: 0.9663
# Epoch 2/10
# 840/840 - 9s - loss: 0.1287 - tp: 2648.0000 - fp: 481.0000 - tn: 23017.0000 - fn: 729.0000 - accuracy: 0.9550 - precision: 0.8463 - recall: 0.7841 - auc: 0.9682 - val_loss: 0.1249 - val_tp: 696.0000 - val_fp: 178.0000 - val_tn: 5721.0000 - val_fn: 124.0000 - val_accuracy: 0.9551 - val_precision: 0.7963 - val_recall: 0.8488 - val_auc: 0.9699
# Epoch 3/10
# 840/840 - 9s - loss: 0.1120 - tp: 2761.0000 - fp: 408.0000 - tn: 23090.0000 - fn: 616.0000 - accuracy: 0.9619 - precision: 0.8713 - recall: 0.8176 - auc: 0.9744 - val_loss: 0.1198 - val_tp: 700.0000 - val_fp: 154.0000 - val_tn: 5745.0000 - val_fn: 120.0000 - val_accuracy: 0.9592 - val_precision: 0.8197 - val_recall: 0.8537 - val_auc: 0.9723
# Epoch 4/10
# 840/840 - 8s - loss: 0.0949 - tp: 2848.0000 - fp: 328.0000 - tn: 23170.0000 - fn: 529.0000 - accuracy: 0.9681 - precision: 0.8967 - recall: 0.8434 - auc: 0.9800 - val_loss: 0.1355 - val_tp: 570.0000 - val_fp: 65.0000 - val_tn: 5834.0000 - val_fn: 250.0000 - val_accuracy: 0.9531 - val_precision: 0.8976 - val_recall: 0.6951 - val_auc: 0.9676
# Epoch 5/10
# 840/840 - 8s - loss: 0.0756 - tp: 2956.0000 - fp: 229.0000 - tn: 23269.0000 - fn: 421.0000 - accuracy: 0.9758 - precision: 0.9281 - recall: 0.8753 - auc: 0.9861 - val_loss: 0.1338 - val_tp: 665.0000 - val_fp: 127.0000 - val_tn: 5772.0000 - val_fn: 155.0000 - val_accuracy: 0.9580 - val_precision: 0.8396 - val_recall: 0.8110 - val_auc: 0.9676
# Epoch 6/10
# Restoring model weights from the end of the best epoch.
# 840/840 - 8s - loss: 0.0593 - tp: 3051.0000 - fp: 158.0000 - tn: 23340.0000 - fn: 326.0000 - accuracy: 0.9820 - precision: 0.9508 - recall: 0.9035 - auc: 0.9914 - val_loss: 0.1498 - val_tp: 673.0000 - val_fp: 137.0000 - val_tn: 5762.0000 - val_fn: 147.0000 - val_accuracy: 0.9577 - val_precision: 0.8309 - val_recall: 0.8207 - val_auc: 0.9645
# Epoch 00006: early stopping
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 8a9a835db9b36c49a87c98d7eaaff540</span>
# <span style="color:cyan"> |-Score: 0.9592201113700867</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-batch_size: 32</span>
# <span style="color:blue"> |-cnn_activation: relu</span>
# <span style="color:cyan"> |-cnn_global_kernel: 3</span>
# <span style="color:blue"> |-cnn_global_maxpool: 3</span>
# <span style="color:cyan"> |-cnn_global_stride: 2</span>
# <span style="color:blue"> |-cnn_local_kernel: 5</span>
# <span style="color:cyan"> |-cnn_local_maxpool: 7</span>
# <span style="color:blue"> |-cnn_local_stride: 2</span>
# <span style="color:cyan"> |-dense_activation: relu</span>
# <span style="color:blue"> |-dense_dropout: 0.2</span>
# <span style="color:cyan"> |-first_global_cnn_filters: 32</span>
# <span style="color:blue"> |-first_local_cnn_filters: 16</span>
# <span style="color:cyan"> |-further_global_cnn_filters: 64</span>
# <span style="color:blue"> |-further_global_cnn_layers: 1</span>
# <span style="color:cyan"> |-further_local_cnn_filters: 96</span>
# <span style="color:blue"> |-learning_rate: 0.0001</span>
# <span style="color:cyan"> |-number_of_dense_layers: 3</span>
# <span style="color:blue"> |-size_of_dense_layers: 320</span>
# Epoch 1/10
# 105/105 - 8s - loss: 0.6819 - tp: 1721.0000 - fp: 7547.0000 - tn: 21850.0000 - fn: 2476.0000 - accuracy: 0.7016 - precision: 0.1857 - recall: 0.4101 - auc: 0.6697 - val_loss: 0.6788 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 5899.0000 - val_fn: 820.0000 - val_accuracy: 0.8780 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7829
# Epoch 2/10
# 105/105 - 7s - loss: 0.6671 - tp: 950.0000 - fp: 6438.0000 - tn: 17060.0000 - fn: 2427.0000 - accuracy: 0.6701 - precision: 0.1286 - recall: 0.2813 - auc: 0.5558 - val_loss: 0.6605 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 5899.0000 - val_fn: 820.0000 - val_accuracy: 0.8780 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8045
# Epoch 3/10
# 105/105 - 7s - loss: 0.6487 - tp: 820.0000 - fp: 5851.0000 - tn: 17647.0000 - fn: 2557.0000 - accuracy: 0.6871 - precision: 0.1229 - recall: 0.2428 - auc: 0.5584 - val_loss: 0.6404 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 5899.0000 - val_fn: 820.0000 - val_accuracy: 0.8780 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8178
# Epoch 4/10
# Restoring model weights from the end of the best epoch.
# 105/105 - 7s - loss: 0.6289 - tp: 802.0000 - fp: 5561.0000 - tn: 17937.0000 - fn: 2575.0000 - accuracy: 0.6973 - precision: 0.1260 - recall: 0.2375 - auc: 0.5681 - val_loss: 0.6181 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 5899.0000 - val_fn: 820.0000 - val_accuracy: 0.8780 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8194
# Epoch 00004: early stopping
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: bc5576cea5af0350ba0043333afed2c1</span>
# <span style="color:cyan"> |-Score: 0.8779579997062683</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-batch_size: 256</span>
# <span style="color:blue"> |-cnn_activation: relu</span>
# <span style="color:cyan"> |-cnn_global_kernel: 3</span>
# <span style="color:blue"> |-cnn_global_maxpool: 3</span>
# <span style="color:cyan"> |-cnn_global_stride: 3</span>
# <span style="color:blue"> |-cnn_local_kernel: 3</span>
# <span style="color:cyan"> |-cnn_local_maxpool: 3</span>
# <span style="color:blue"> |-cnn_local_stride: 1</span>
# <span style="color:cyan"> |-dense_activation: relu</span>
# <span style="color:blue"> |-dense_dropout: 0.5</span>
# <span style="color:cyan"> |-first_global_cnn_filters: 32</span>
# <span style="color:blue"> |-first_local_cnn_filters: 8</span>
# <span style="color:cyan"> |-further_global_cnn_filters: 128</span>
# <span style="color:blue"> |-further_global_cnn_layers: 3</span>
# <span style="color:cyan"> |-further_local_cnn_filters: 128</span>
# <span style="color:blue"> |-learning_rate: 1e-06</span>
# <span style="color:cyan"> |-number_of_dense_layers: 5</span>
# <span style="color:blue"> |-size_of_dense_layers: 64</span>
# Epoch 1/10
# 105/105 - 3s - loss: 0.2534 - tp: 876.0000 - fp: 297.0000 - tn: 29100.0000 - fn: 3321.0000 - accuracy: 0.8923 - precision: 0.7468 - recall: 0.2087 - auc: 0.8100 - val_loss: 0.1848 - val_tp: 661.0000 - val_fp: 317.0000 - val_tn: 5582.0000 - val_fn: 159.0000 - val_accuracy: 0.9292 - val_precision: 0.6759 - val_recall: 0.8061 - val_auc: 0.9541
# Epoch 2/10
# 105/105 - 2s - loss: 0.1566 - tp: 2435.0000 - fp: 633.0000 - tn: 22865.0000 - fn: 942.0000 - accuracy: 0.9414 - precision: 0.7937 - recall: 0.7211 - auc: 0.9610 - val_loss: 0.1401 - val_tp: 590.0000 - val_fp: 111.0000 - val_tn: 5788.0000 - val_fn: 230.0000 - val_accuracy: 0.9492 - val_precision: 0.8417 - val_recall: 0.7195 - val_auc: 0.9645
# Epoch 3/10
# 105/105 - 2s - loss: 0.1346 - tp: 2618.0000 - fp: 495.0000 - tn: 23003.0000 - fn: 759.0000 - accuracy: 0.9533 - precision: 0.8410 - recall: 0.7752 - auc: 0.9674 - val_loss: 0.1301 - val_tp: 676.0000 - val_fp: 169.0000 - val_tn: 5730.0000 - val_fn: 144.0000 - val_accuracy: 0.9534 - val_precision: 0.8000 - val_recall: 0.8244 - val_auc: 0.9680
# Epoch 4/10
# 105/105 - 2s - loss: 0.1254 - tp: 2649.0000 - fp: 475.0000 - tn: 23023.0000 - fn: 728.0000 - accuracy: 0.9552 - precision: 0.8480 - recall: 0.7844 - auc: 0.9711 - val_loss: 0.1231 - val_tp: 665.0000 - val_fp: 119.0000 - val_tn: 5780.0000 - val_fn: 155.0000 - val_accuracy: 0.9592 - val_precision: 0.8482 - val_recall: 0.8110 - val_auc: 0.9684
# Epoch 5/10
# 105/105 - 1s - loss: 0.1187 - tp: 2702.0000 - fp: 467.0000 - tn: 23031.0000 - fn: 675.0000 - accuracy: 0.9575 - precision: 0.8526 - recall: 0.8001 - auc: 0.9726 - val_loss: 0.1217 - val_tp: 635.0000 - val_fp: 107.0000 - val_tn: 5792.0000 - val_fn: 185.0000 - val_accuracy: 0.9565 - val_precision: 0.8558 - val_recall: 0.7744 - val_auc: 0.9699
# Epoch 6/10
# 105/105 - 2s - loss: 0.1152 - tp: 2729.0000 - fp: 457.0000 - tn: 23041.0000 - fn: 648.0000 - accuracy: 0.9589 - precision: 0.8566 - recall: 0.8081 - auc: 0.9745 - val_loss: 0.1191 - val_tp: 681.0000 - val_fp: 133.0000 - val_tn: 5766.0000 - val_fn: 139.0000 - val_accuracy: 0.9595 - val_precision: 0.8366 - val_recall: 0.8305 - val_auc: 0.9708
# Epoch 7/10
# 105/105 - 2s - loss: 0.1114 - tp: 2748.0000 - fp: 432.0000 - tn: 23066.0000 - fn: 629.0000 - accuracy: 0.9605 - precision: 0.8642 - recall: 0.8137 - auc: 0.9762 - val_loss: 0.1182 - val_tp: 654.0000 - val_fp: 104.0000 - val_tn: 5795.0000 - val_fn: 166.0000 - val_accuracy: 0.9598 - val_precision: 0.8628 - val_recall: 0.7976 - val_auc: 0.9702
# Epoch 8/10
# 105/105 - 1s - loss: 0.1043 - tp: 2792.0000 - fp: 397.0000 - tn: 23101.0000 - fn: 585.0000 - accuracy: 0.9635 - precision: 0.8755 - recall: 0.8268 - auc: 0.9783 - val_loss: 0.1199 - val_tp: 646.0000 - val_fp: 102.0000 - val_tn: 5797.0000 - val_fn: 174.0000 - val_accuracy: 0.9589 - val_precision: 0.8636 - val_recall: 0.7878 - val_auc: 0.9703
# Epoch 9/10
# 105/105 - 1s - loss: 0.0997 - tp: 2827.0000 - fp: 392.0000 - tn: 23106.0000 - fn: 550.0000 - accuracy: 0.9649 - precision: 0.8782 - recall: 0.8371 - auc: 0.9810 - val_loss: 0.1251 - val_tp: 706.0000 - val_fp: 175.0000 - val_tn: 5724.0000 - val_fn: 114.0000 - val_accuracy: 0.9570 - val_precision: 0.8014 - val_recall: 0.8610 - val_auc: 0.9714
# Epoch 10/10
# Restoring model weights from the end of the best epoch.
# 105/105 - 1s - loss: 0.0990 - tp: 2831.0000 - fp: 398.0000 - tn: 23100.0000 - fn: 546.0000 - accuracy: 0.9649 - precision: 0.8767 - recall: 0.8383 - auc: 0.9813 - val_loss: 0.1178 - val_tp: 681.0000 - val_fp: 131.0000 - val_tn: 5768.0000 - val_fn: 139.0000 - val_accuracy: 0.9598 - val_precision: 0.8387 - val_recall: 0.8305 - val_auc: 0.9715
# Epoch 00010: early stopping
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 879a9fc71e49003cbe53d287c0a3b009</span>
# <span style="color:cyan"> |-Score: 0.9598154425621033</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-batch_size: 256</span>
# <span style="color:blue"> |-cnn_activation: relu</span>
# <span style="color:cyan"> |-cnn_global_kernel: 5</span>
# <span style="color:blue"> |-cnn_global_maxpool: 3</span>
# <span style="color:cyan"> |-cnn_global_stride: 3</span>
# <span style="color:blue"> |-cnn_local_kernel: 5</span>
# <span style="color:cyan"> |-cnn_local_maxpool: 7</span>
# <span style="color:blue"> |-cnn_local_stride: 1</span>
# <span style="color:cyan"> |-dense_activation: relu</span>
# <span style="color:blue"> |-dense_dropout: 0.0</span>
# <span style="color:cyan"> |-first_global_cnn_filters: 8</span>
# <span style="color:blue"> |-first_local_cnn_filters: 32</span>
# <span style="color:cyan"> |-further_global_cnn_filters: 16</span>
# <span style="color:blue"> |-further_global_cnn_layers: 1</span>
# <span style="color:cyan"> |-further_local_cnn_filters: 16</span>
# <span style="color:blue"> |-learning_rate: 0.0001</span>
# <span style="color:cyan"> |-number_of_dense_layers: 2</span>
# <span style="color:blue"> |-size_of_dense_layers: 512</span>
# Epoch 1/10
# 105/105 - 4s - loss: 0.2692 - tp: 1245.0000 - fp: 362.0000 - tn: 29035.0000 - fn: 2952.0000 - accuracy: 0.9014 - precision: 0.7747 - recall: 0.2966 - auc: 0.8997 - val_loss: 0.1774 - val_tp: 564.0000 - val_fp: 214.0000 - val_tn: 5685.0000 - val_fn: 256.0000 - val_accuracy: 0.9300 - val_precision: 0.7249 - val_recall: 0.6878 - val_auc: 0.9482
# Epoch 2/10
# 105/105 - 4s - loss: 0.1806 - tp: 2258.0000 - fp: 781.0000 - tn: 22717.0000 - fn: 1119.0000 - accuracy: 0.9293 - precision: 0.7430 - recall: 0.6686 - auc: 0.9487 - val_loss: 0.1637 - val_tp: 556.0000 - val_fp: 177.0000 - val_tn: 5722.0000 - val_fn: 264.0000 - val_accuracy: 0.9344 - val_precision: 0.7585 - val_recall: 0.6780 - val_auc: 0.9547
# Epoch 3/10
# 105/105 - 4s - loss: 0.1641 - tp: 2444.0000 - fp: 745.0000 - tn: 22753.0000 - fn: 933.0000 - accuracy: 0.9376 - precision: 0.7664 - recall: 0.7237 - auc: 0.9557 - val_loss: 0.1515 - val_tp: 581.0000 - val_fp: 171.0000 - val_tn: 5728.0000 - val_fn: 239.0000 - val_accuracy: 0.9390 - val_precision: 0.7726 - val_recall: 0.7085 - val_auc: 0.9594
# Epoch 4/10
# 105/105 - 4s - loss: 0.1531 - tp: 2518.0000 - fp: 662.0000 - tn: 22836.0000 - fn: 859.0000 - accuracy: 0.9434 - precision: 0.7918 - recall: 0.7456 - auc: 0.9603 - val_loss: 0.1474 - val_tp: 701.0000 - val_fp: 237.0000 - val_tn: 5662.0000 - val_fn: 119.0000 - val_accuracy: 0.9470 - val_precision: 0.7473 - val_recall: 0.8549 - val_auc: 0.9638
# Epoch 5/10
# 105/105 - 4s - loss: 0.1412 - tp: 2616.0000 - fp: 634.0000 - tn: 22864.0000 - fn: 761.0000 - accuracy: 0.9481 - precision: 0.8049 - recall: 0.7747 - auc: 0.9655 - val_loss: 0.1335 - val_tp: 606.0000 - val_fp: 128.0000 - val_tn: 5771.0000 - val_fn: 214.0000 - val_accuracy: 0.9491 - val_precision: 0.8256 - val_recall: 0.7390 - val_auc: 0.9667
# Epoch 6/10
# 105/105 - 4s - loss: 0.1313 - tp: 2650.0000 - fp: 528.0000 - tn: 22970.0000 - fn: 727.0000 - accuracy: 0.9533 - precision: 0.8339 - recall: 0.7847 - auc: 0.9690 - val_loss: 0.1305 - val_tp: 692.0000 - val_fp: 197.0000 - val_tn: 5702.0000 - val_fn: 128.0000 - val_accuracy: 0.9516 - val_precision: 0.7784 - val_recall: 0.8439 - val_auc: 0.9678
# Epoch 7/10
# 105/105 - 4s - loss: 0.1223 - tp: 2735.0000 - fp: 505.0000 - tn: 22993.0000 - fn: 642.0000 - accuracy: 0.9573 - precision: 0.8441 - recall: 0.8099 - auc: 0.9722 - val_loss: 0.1226 - val_tp: 655.0000 - val_fp: 136.0000 - val_tn: 5763.0000 - val_fn: 165.0000 - val_accuracy: 0.9552 - val_precision: 0.8281 - val_recall: 0.7988 - val_auc: 0.9692
# Epoch 8/10
# 105/105 - 3s - loss: 0.1147 - tp: 2766.0000 - fp: 448.0000 - tn: 23050.0000 - fn: 611.0000 - accuracy: 0.9606 - precision: 0.8606 - recall: 0.8191 - auc: 0.9749 - val_loss: 0.1374 - val_tp: 564.0000 - val_fp: 89.0000 - val_tn: 5810.0000 - val_fn: 256.0000 - val_accuracy: 0.9487 - val_precision: 0.8637 - val_recall: 0.6878 - val_auc: 0.9681
# Epoch 9/10
# 105/105 - 3s - loss: 0.1110 - tp: 2762.0000 - fp: 422.0000 - tn: 23076.0000 - fn: 615.0000 - accuracy: 0.9614 - precision: 0.8675 - recall: 0.8179 - auc: 0.9767 - val_loss: 0.1250 - val_tp: 661.0000 - val_fp: 146.0000 - val_tn: 5753.0000 - val_fn: 159.0000 - val_accuracy: 0.9546 - val_precision: 0.8191 - val_recall: 0.8061 - val_auc: 0.9690
# Epoch 10/10
# 105/105 - 4s - loss: 0.1052 - tp: 2802.0000 - fp: 404.0000 - tn: 23094.0000 - fn: 575.0000 - accuracy: 0.9636 - precision: 0.8740 - recall: 0.8297 - auc: 0.9784 - val_loss: 0.1226 - val_tp: 681.0000 - val_fp: 157.0000 - val_tn: 5742.0000 - val_fn: 139.0000 - val_accuracy: 0.9559 - val_precision: 0.8126 - val_recall: 0.8305 - val_auc: 0.9697
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: a987d13cf96e0a0dbb2b986c448d0bc6</span>
# <span style="color:cyan"> |-Score: 0.9559458494186401</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-batch_size: 256</span>
# <span style="color:blue"> |-cnn_activation: relu</span>
# <span style="color:cyan"> |-cnn_global_kernel: 3</span>
# <span style="color:blue"> |-cnn_global_maxpool: 7</span>
# <span style="color:cyan"> |-cnn_global_stride: 1</span>
# <span style="color:blue"> |-cnn_local_kernel: 5</span>
# <span style="color:cyan"> |-cnn_local_maxpool: 7</span>
# <span style="color:blue"> |-cnn_local_stride: 3</span>
# <span style="color:cyan"> |-dense_activation: relu</span>
# <span style="color:blue"> |-dense_dropout: 0.5</span>
# <span style="color:cyan"> |-first_global_cnn_filters: 8</span>
# <span style="color:blue"> |-first_local_cnn_filters: 32</span>
# <span style="color:cyan"> |-further_global_cnn_filters: 16</span>
# <span style="color:blue"> |-further_global_cnn_layers: 1</span>
# <span style="color:cyan"> |-further_local_cnn_filters: 128</span>
# <span style="color:blue"> |-learning_rate: 0.0001</span>
# <span style="color:cyan"> |-number_of_dense_layers: 2</span>
# <span style="color:blue"> |-size_of_dense_layers: 512</span>
# Epoch 1/10
# 840/840 - 10s - loss: 0.2228 - tp: 2031.0000 - fp: 497.0000 - tn: 28900.0000 - fn: 2166.0000 - accuracy: 0.9207 - precision: 0.8034 - recall: 0.4839 - auc: 0.9360 - val_loss: 0.1736 - val_tp: 618.0000 - val_fp: 173.0000 - val_tn: 5726.0000 - val_fn: 202.0000 - val_accuracy: 0.9442 - val_precision: 0.7813 - val_recall: 0.7537 - val_auc: 0.9573
# Epoch 2/10
# 840/840 - 10s - loss: 0.1528 - tp: 2648.0000 - fp: 563.0000 - tn: 22935.0000 - fn: 729.0000 - accuracy: 0.9519 - precision: 0.8247 - recall: 0.7841 - auc: 0.9619 - val_loss: 0.1295 - val_tp: 633.0000 - val_fp: 117.0000 - val_tn: 5782.0000 - val_fn: 187.0000 - val_accuracy: 0.9548 - val_precision: 0.8440 - val_recall: 0.7720 - val_auc: 0.9679
# Epoch 3/10
# 840/840 - 10s - loss: 0.1228 - tp: 2733.0000 - fp: 388.0000 - tn: 23110.0000 - fn: 644.0000 - accuracy: 0.9616 - precision: 0.8757 - recall: 0.8093 - auc: 0.9722 - val_loss: 0.1252 - val_tp: 701.0000 - val_fp: 155.0000 - val_tn: 5744.0000 - val_fn: 119.0000 - val_accuracy: 0.9592 - val_precision: 0.8189 - val_recall: 0.8549 - val_auc: 0.9705
# Epoch 4/10
# 840/840 - 9s - loss: 0.0951 - tp: 2837.0000 - fp: 256.0000 - tn: 23242.0000 - fn: 540.0000 - accuracy: 0.9704 - precision: 0.9172 - recall: 0.8401 - auc: 0.9805 - val_loss: 0.1223 - val_tp: 629.0000 - val_fp: 96.0000 - val_tn: 5803.0000 - val_fn: 191.0000 - val_accuracy: 0.9573 - val_precision: 0.8676 - val_recall: 0.7671 - val_auc: 0.9709
# Epoch 5/10
# 840/840 - 9s - loss: 0.0733 - tp: 2962.0000 - fp: 182.0000 - tn: 23316.0000 - fn: 415.0000 - accuracy: 0.9778 - precision: 0.9421 - recall: 0.8771 - auc: 0.9882 - val_loss: 0.1420 - val_tp: 671.0000 - val_fp: 128.0000 - val_tn: 5771.0000 - val_fn: 149.0000 - val_accuracy: 0.9588 - val_precision: 0.8398 - val_recall: 0.8183 - val_auc: 0.9673
# Epoch 6/10
# Restoring model weights from the end of the best epoch.
# 840/840 - 9s - loss: 0.0575 - tp: 3054.0000 - fp: 157.0000 - tn: 23341.0000 - fn: 323.0000 - accuracy: 0.9821 - precision: 0.9511 - recall: 0.9044 - auc: 0.9922 - val_loss: 0.1541 - val_tp: 630.0000 - val_fp: 112.0000 - val_tn: 5787.0000 - val_fn: 190.0000 - val_accuracy: 0.9551 - val_precision: 0.8491 - val_recall: 0.7683 - val_auc: 0.9635
# Epoch 00006: early stopping
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: c13c001f0fa1537a646e14d765ca8544</span>
# <span style="color:cyan"> |-Score: 0.9592201113700867</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-batch_size: 32</span>
# <span style="color:blue"> |-cnn_activation: relu</span>
# <span style="color:cyan"> |-cnn_global_kernel: 5</span>
# <span style="color:blue"> |-cnn_global_maxpool: 3</span>
# <span style="color:cyan"> |-cnn_global_stride: 1</span>
# <span style="color:blue"> |-cnn_local_kernel: 5</span>
# <span style="color:cyan"> |-cnn_local_maxpool: 7</span>
# <span style="color:blue"> |-cnn_local_stride: 3</span>
# <span style="color:cyan"> |-dense_activation: relu</span>
# <span style="color:blue"> |-dense_dropout: 0.5</span>
# <span style="color:cyan"> |-first_global_cnn_filters: 32</span>
# <span style="color:blue"> |-first_local_cnn_filters: 32</span>
# <span style="color:cyan"> |-further_global_cnn_filters: 16</span>
# <span style="color:blue"> |-further_global_cnn_layers: 1</span>
# <span style="color:cyan"> |-further_local_cnn_filters: 16</span>
# <span style="color:blue"> |-learning_rate: 0.0001</span>
# <span style="color:cyan"> |-number_of_dense_layers: 5</span>
# <span style="color:blue"> |-size_of_dense_layers: 512</span>
# Epoch 1/10
# 840/840 - 10s - loss: 0.1832 - tp: 2748.0000 - fp: 765.0000 - tn: 28632.0000 - fn: 1449.0000 - accuracy: 0.9341 - precision: 0.7822 - recall: 0.6548 - auc: 0.9482 - val_loss: 0.1444 - val_tp: 589.0000 - val_fp: 150.0000 - val_tn: 5749.0000 - val_fn: 231.0000 - val_accuracy: 0.9433 - val_precision: 0.7970 - val_recall: 0.7183 - val_auc: 0.9613
# Epoch 2/10
# 840/840 - 9s - loss: 0.1312 - tp: 2719.0000 - fp: 591.0000 - tn: 22907.0000 - fn: 658.0000 - accuracy: 0.9535 - precision: 0.8215 - recall: 0.8052 - auc: 0.9673 - val_loss: 0.1253 - val_tp: 678.0000 - val_fp: 157.0000 - val_tn: 5742.0000 - val_fn: 142.0000 - val_accuracy: 0.9555 - val_precision: 0.8120 - val_recall: 0.8268 - val_auc: 0.9675
# Epoch 3/10
# 840/840 - 9s - loss: 0.1064 - tp: 2829.0000 - fp: 446.0000 - tn: 23052.0000 - fn: 548.0000 - accuracy: 0.9630 - precision: 0.8638 - recall: 0.8377 - auc: 0.9763 - val_loss: 0.1231 - val_tp: 715.0000 - val_fp: 190.0000 - val_tn: 5709.0000 - val_fn: 105.0000 - val_accuracy: 0.9561 - val_precision: 0.7901 - val_recall: 0.8720 - val_auc: 0.9708
# Epoch 4/10
# 840/840 - 9s - loss: 0.0890 - tp: 2914.0000 - fp: 341.0000 - tn: 23157.0000 - fn: 463.0000 - accuracy: 0.9701 - precision: 0.8952 - recall: 0.8629 - auc: 0.9824 - val_loss: 0.1188 - val_tp: 643.0000 - val_fp: 101.0000 - val_tn: 5798.0000 - val_fn: 177.0000 - val_accuracy: 0.9586 - val_precision: 0.8642 - val_recall: 0.7841 - val_auc: 0.9716
# Epoch 5/10
# 840/840 - 9s - loss: 0.0706 - tp: 3000.0000 - fp: 259.0000 - tn: 23239.0000 - fn: 377.0000 - accuracy: 0.9763 - precision: 0.9205 - recall: 0.8884 - auc: 0.9882 - val_loss: 0.1232 - val_tp: 649.0000 - val_fp: 121.0000 - val_tn: 5778.0000 - val_fn: 171.0000 - val_accuracy: 0.9565 - val_precision: 0.8429 - val_recall: 0.7915 - val_auc: 0.9709
# Epoch 6/10
# 840/840 - 9s - loss: 0.0533 - tp: 3085.0000 - fp: 181.0000 - tn: 23317.0000 - fn: 292.0000 - accuracy: 0.9824 - precision: 0.9446 - recall: 0.9135 - auc: 0.9929 - val_loss: 0.1414 - val_tp: 630.0000 - val_fp: 112.0000 - val_tn: 5787.0000 - val_fn: 190.0000 - val_accuracy: 0.9551 - val_precision: 0.8491 - val_recall: 0.7683 - val_auc: 0.9625
# Epoch 7/10
# Restoring model weights from the end of the best epoch.
# 840/840 - 9s - loss: 0.0415 - tp: 3140.0000 - fp: 120.0000 - tn: 23378.0000 - fn: 237.0000 - accuracy: 0.9867 - precision: 0.9632 - recall: 0.9298 - auc: 0.9956 - val_loss: 0.1459 - val_tp: 628.0000 - val_fp: 99.0000 - val_tn: 5800.0000 - val_fn: 192.0000 - val_accuracy: 0.9567 - val_precision: 0.8638 - val_recall: 0.7659 - val_auc: 0.9616
# Epoch 00007: early stopping
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 3b2a3a7243b164c494489017a51efd80</span>
# <span style="color:cyan"> |-Score: 0.9586247801780701</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-batch_size: 32</span>
# <span style="color:blue"> |-cnn_activation: relu</span>
# <span style="color:cyan"> |-cnn_global_kernel: 3</span>
# <span style="color:blue"> |-cnn_global_maxpool: 7</span>
# <span style="color:cyan"> |-cnn_global_stride: 3</span>
# <span style="color:blue"> |-cnn_local_kernel: 5</span>
# <span style="color:cyan"> |-cnn_local_maxpool: 7</span>
# <span style="color:blue"> |-cnn_local_stride: 3</span>
# <span style="color:cyan"> |-dense_activation: relu</span>
# <span style="color:blue"> |-dense_dropout: 0.0</span>
# <span style="color:cyan"> |-first_global_cnn_filters: 32</span>
# <span style="color:blue"> |-first_local_cnn_filters: 32</span>
# <span style="color:cyan"> |-further_global_cnn_filters: 128</span>
# <span style="color:blue"> |-further_global_cnn_layers: 1</span>
# <span style="color:cyan"> |-further_local_cnn_filters: 16</span>
# <span style="color:blue"> |-learning_rate: 0.0001</span>
# <span style="color:cyan"> |-number_of_dense_layers: 2</span>
# <span style="color:blue"> |-size_of_dense_layers: 512</span>
# Epoch 1/10
# 840/840 - 14s - loss: 0.1569 - tp: 2992.0000 - fp: 671.0000 - tn: 28726.0000 - fn: 1205.0000 - accuracy: 0.9442 - precision: 0.8168 - recall: 0.7129 - auc: 0.9574 - val_loss: 0.1260 - val_tp: 638.0000 - val_fp: 96.0000 - val_tn: 5803.0000 - val_fn: 182.0000 - val_accuracy: 0.9586 - val_precision: 0.8692 - val_recall: 0.7780 - val_auc: 0.9686
# Epoch 2/10
# 840/840 - 13s - loss: 0.1183 - tp: 2730.0000 - fp: 461.0000 - tn: 23037.0000 - fn: 647.0000 - accuracy: 0.9588 - precision: 0.8555 - recall: 0.8084 - auc: 0.9724 - val_loss: 0.1191 - val_tp: 669.0000 - val_fp: 122.0000 - val_tn: 5777.0000 - val_fn: 151.0000 - val_accuracy: 0.9594 - val_precision: 0.8458 - val_recall: 0.8159 - val_auc: 0.9712
# Epoch 3/10
# 840/840 - 12s - loss: 0.1034 - tp: 2822.0000 - fp: 407.0000 - tn: 23091.0000 - fn: 555.0000 - accuracy: 0.9642 - precision: 0.8740 - recall: 0.8357 - auc: 0.9781 - val_loss: 0.1270 - val_tp: 603.0000 - val_fp: 83.0000 - val_tn: 5816.0000 - val_fn: 217.0000 - val_accuracy: 0.9554 - val_precision: 0.8790 - val_recall: 0.7354 - val_auc: 0.9666
# Epoch 4/10
# 840/840 - 12s - loss: 0.0903 - tp: 2874.0000 - fp: 354.0000 - tn: 23144.0000 - fn: 503.0000 - accuracy: 0.9681 - precision: 0.8903 - recall: 0.8511 - auc: 0.9838 - val_loss: 0.1262 - val_tp: 647.0000 - val_fp: 126.0000 - val_tn: 5773.0000 - val_fn: 173.0000 - val_accuracy: 0.9555 - val_precision: 0.8370 - val_recall: 0.7890 - val_auc: 0.9672
# Epoch 5/10
# Restoring model weights from the end of the best epoch.
# 840/840 - 12s - loss: 0.0719 - tp: 2957.0000 - fp: 262.0000 - tn: 23236.0000 - fn: 420.0000 - accuracy: 0.9746 - precision: 0.9186 - recall: 0.8756 - auc: 0.9898 - val_loss: 0.1352 - val_tp: 644.0000 - val_fp: 129.0000 - val_tn: 5770.0000 - val_fn: 176.0000 - val_accuracy: 0.9546 - val_precision: 0.8331 - val_recall: 0.7854 - val_auc: 0.9662
# Epoch 00005: early stopping
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 8b7532ce7ad5ec86d93f68b7a0064f0a</span>
# <span style="color:cyan"> |-Score: 0.9593689441680908</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-batch_size: 32</span>
# <span style="color:blue"> |-cnn_activation: relu</span>
# <span style="color:cyan"> |-cnn_global_kernel: 5</span>
# <span style="color:blue"> |-cnn_global_maxpool: 7</span>
# <span style="color:cyan"> |-cnn_global_stride: 1</span>
# <span style="color:blue"> |-cnn_local_kernel: 5</span>
# <span style="color:cyan"> |-cnn_local_maxpool: 7</span>
# <span style="color:blue"> |-cnn_local_stride: 1</span>
# <span style="color:cyan"> |-dense_activation: relu</span>
# <span style="color:blue"> |-dense_dropout: 0.0</span>
# <span style="color:cyan"> |-first_global_cnn_filters: 32</span>
# <span style="color:blue"> |-first_local_cnn_filters: 32</span>
# <span style="color:cyan"> |-further_global_cnn_filters: 16</span>
# <span style="color:blue"> |-further_global_cnn_layers: 1</span>
# <span style="color:cyan"> |-further_local_cnn_filters: 128</span>
# <span style="color:blue"> |-learning_rate: 0.0001</span>
# <span style="color:cyan"> |-number_of_dense_layers: 2</span>
# <span style="color:blue"> |-size_of_dense_layers: 512</span>
# Epoch 1/10
# 840/840 - 5s - loss: 0.2947 - tp: 680.0000 - fp: 242.0000 - tn: 29155.0000 - fn: 3517.0000 - accuracy: 0.8881 - precision: 0.7375 - recall: 0.1620 - auc: 0.8730 - val_loss: 0.1979 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 5899.0000 - val_fn: 820.0000 - val_accuracy: 0.8780 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.9462
# Epoch 2/10
# 840/840 - 5s - loss: 0.2018 - tp: 1424.0000 - fp: 367.0000 - tn: 23131.0000 - fn: 1953.0000 - accuracy: 0.9137 - precision: 0.7951 - recall: 0.4217 - auc: 0.9435 - val_loss: 0.1698 - val_tp: 538.0000 - val_fp: 138.0000 - val_tn: 5761.0000 - val_fn: 282.0000 - val_accuracy: 0.9375 - val_precision: 0.7959 - val_recall: 0.6561 - val_auc: 0.9592
# Epoch 3/10
# 840/840 - 5s - loss: 0.1810 - tp: 2250.0000 - fp: 564.0000 - tn: 22934.0000 - fn: 1127.0000 - accuracy: 0.9371 - precision: 0.7996 - recall: 0.6663 - auc: 0.9519 - val_loss: 0.1563 - val_tp: 616.0000 - val_fp: 153.0000 - val_tn: 5746.0000 - val_fn: 204.0000 - val_accuracy: 0.9469 - val_precision: 0.8010 - val_recall: 0.7512 - val_auc: 0.9632
# Epoch 4/10
# 840/840 - 5s - loss: 0.1710 - tp: 2436.0000 - fp: 568.0000 - tn: 22930.0000 - fn: 941.0000 - accuracy: 0.9439 - precision: 0.8109 - recall: 0.7214 - auc: 0.9551 - val_loss: 0.1472 - val_tp: 646.0000 - val_fp: 164.0000 - val_tn: 5735.0000 - val_fn: 174.0000 - val_accuracy: 0.9497 - val_precision: 0.7975 - val_recall: 0.7878 - val_auc: 0.9649
# Epoch 5/10
# 840/840 - 5s - loss: 0.1584 - tp: 2561.0000 - fp: 564.0000 - tn: 22934.0000 - fn: 816.0000 - accuracy: 0.9487 - precision: 0.8195 - recall: 0.7584 - auc: 0.9592 - val_loss: 0.1441 - val_tp: 592.0000 - val_fp: 118.0000 - val_tn: 5781.0000 - val_fn: 228.0000 - val_accuracy: 0.9485 - val_precision: 0.8338 - val_recall: 0.7220 - val_auc: 0.9649
# Epoch 6/10
# 840/840 - 5s - loss: 0.1493 - tp: 2620.0000 - fp: 525.0000 - tn: 22973.0000 - fn: 757.0000 - accuracy: 0.9523 - precision: 0.8331 - recall: 0.7758 - auc: 0.9622 - val_loss: 0.1382 - val_tp: 665.0000 - val_fp: 171.0000 - val_tn: 5728.0000 - val_fn: 155.0000 - val_accuracy: 0.9515 - val_precision: 0.7955 - val_recall: 0.8110 - val_auc: 0.9664
# Epoch 7/10
# 840/840 - 5s - loss: 0.1436 - tp: 2663.0000 - fp: 506.0000 - tn: 22992.0000 - fn: 714.0000 - accuracy: 0.9546 - precision: 0.8403 - recall: 0.7886 - auc: 0.9645 - val_loss: 0.1322 - val_tp: 652.0000 - val_fp: 146.0000 - val_tn: 5753.0000 - val_fn: 168.0000 - val_accuracy: 0.9533 - val_precision: 0.8170 - val_recall: 0.7951 - val_auc: 0.9665
# Epoch 8/10
# 840/840 - 5s - loss: 0.1374 - tp: 2672.0000 - fp: 466.0000 - tn: 23032.0000 - fn: 705.0000 - accuracy: 0.9564 - precision: 0.8515 - recall: 0.7912 - auc: 0.9666 - val_loss: 0.1305 - val_tp: 666.0000 - val_fp: 148.0000 - val_tn: 5751.0000 - val_fn: 154.0000 - val_accuracy: 0.9551 - val_precision: 0.8182 - val_recall: 0.8122 - val_auc: 0.9678
# Epoch 9/10
# 840/840 - 5s - loss: 0.1328 - tp: 2721.0000 - fp: 472.0000 - tn: 23026.0000 - fn: 656.0000 - accuracy: 0.9580 - precision: 0.8522 - recall: 0.8057 - auc: 0.9682 - val_loss: 0.1277 - val_tp: 653.0000 - val_fp: 133.0000 - val_tn: 5766.0000 - val_fn: 167.0000 - val_accuracy: 0.9554 - val_precision: 0.8308 - val_recall: 0.7963 - val_auc: 0.9685
# Epoch 10/10
# 840/840 - 5s - loss: 0.1289 - tp: 2736.0000 - fp: 451.0000 - tn: 23047.0000 - fn: 641.0000 - accuracy: 0.9594 - precision: 0.8585 - recall: 0.8102 - auc: 0.9698 - val_loss: 0.1269 - val_tp: 641.0000 - val_fp: 121.0000 - val_tn: 5778.0000 - val_fn: 179.0000 - val_accuracy: 0.9554 - val_precision: 0.8412 - val_recall: 0.7817 - val_auc: 0.9689
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 22c40af7390ea1d4fad4568c511f9294</span>
# <span style="color:cyan"> |-Score: 0.9553505182266235</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-batch_size: 32</span>
# <span style="color:blue"> |-cnn_activation: relu</span>
# <span style="color:cyan"> |-cnn_global_kernel: 5</span>
# <span style="color:blue"> |-cnn_global_maxpool: 7</span>
# <span style="color:cyan"> |-cnn_global_stride: 3</span>
# <span style="color:blue"> |-cnn_local_kernel: 5</span>
# <span style="color:cyan"> |-cnn_local_maxpool: 7</span>
# <span style="color:blue"> |-cnn_local_stride: 3</span>
# <span style="color:cyan"> |-dense_activation: relu</span>
# <span style="color:blue"> |-dense_dropout: 0.5</span>
# <span style="color:cyan"> |-first_global_cnn_filters: 8</span>
# <span style="color:blue"> |-first_local_cnn_filters: 8</span>
# <span style="color:cyan"> |-further_global_cnn_filters: 16</span>
# <span style="color:blue"> |-further_global_cnn_layers: 1</span>
# <span style="color:cyan"> |-further_local_cnn_filters: 16</span>
# <span style="color:blue"> |-learning_rate: 0.0001</span>
# <span style="color:cyan"> |-number_of_dense_layers: 2</span>
# <span style="color:blue"> |-size_of_dense_layers: 64</span>
# Epoch 1/10
# 840/840 - 9s - loss: 0.2072 - tp: 2605.0000 - fp: 811.0000 - tn: 28586.0000 - fn: 1592.0000 - accuracy: 0.9285 - precision: 0.7626 - recall: 0.6207 - auc: 0.9361 - val_loss: 0.1690 - val_tp: 669.0000 - val_fp: 294.0000 - val_tn: 5605.0000 - val_fn: 151.0000 - val_accuracy: 0.9338 - val_precision: 0.6947 - val_recall: 0.8159 - val_auc: 0.9550
# Epoch 2/10
# 840/840 - 9s - loss: 0.1491 - tp: 2621.0000 - fp: 708.0000 - tn: 22790.0000 - fn: 756.0000 - accuracy: 0.9455 - precision: 0.7873 - recall: 0.7761 - auc: 0.9615 - val_loss: 0.1507 - val_tp: 619.0000 - val_fp: 161.0000 - val_tn: 5738.0000 - val_fn: 201.0000 - val_accuracy: 0.9461 - val_precision: 0.7936 - val_recall: 0.7549 - val_auc: 0.9608
# Epoch 3/10
# 840/840 - 8s - loss: 0.1248 - tp: 2718.0000 - fp: 540.0000 - tn: 22958.0000 - fn: 659.0000 - accuracy: 0.9554 - precision: 0.8343 - recall: 0.8049 - auc: 0.9714 - val_loss: 0.1314 - val_tp: 650.0000 - val_fp: 156.0000 - val_tn: 5743.0000 - val_fn: 170.0000 - val_accuracy: 0.9515 - val_precision: 0.8065 - val_recall: 0.7927 - val_auc: 0.9655
# Epoch 4/10
# 840/840 - 8s - loss: 0.0987 - tp: 2830.0000 - fp: 343.0000 - tn: 23155.0000 - fn: 547.0000 - accuracy: 0.9669 - precision: 0.8919 - recall: 0.8380 - auc: 0.9796 - val_loss: 0.1473 - val_tp: 703.0000 - val_fp: 200.0000 - val_tn: 5699.0000 - val_fn: 117.0000 - val_accuracy: 0.9528 - val_precision: 0.7785 - val_recall: 0.8573 - val_auc: 0.9679
# Epoch 5/10
# 840/840 - 8s - loss: 0.0774 - tp: 2929.0000 - fp: 251.0000 - tn: 23247.0000 - fn: 448.0000 - accuracy: 0.9740 - precision: 0.9211 - recall: 0.8673 - auc: 0.9866 - val_loss: 0.1614 - val_tp: 686.0000 - val_fp: 187.0000 - val_tn: 5712.0000 - val_fn: 134.0000 - val_accuracy: 0.9522 - val_precision: 0.7858 - val_recall: 0.8366 - val_auc: 0.9665
# Epoch 6/10
# 840/840 - 8s - loss: 0.0518 - tp: 3058.0000 - fp: 150.0000 - tn: 23348.0000 - fn: 319.0000 - accuracy: 0.9825 - precision: 0.9532 - recall: 0.9055 - auc: 0.9938 - val_loss: 0.1792 - val_tp: 637.0000 - val_fp: 160.0000 - val_tn: 5739.0000 - val_fn: 183.0000 - val_accuracy: 0.9490 - val_precision: 0.7992 - val_recall: 0.7768 - val_auc: 0.9619
# Epoch 7/10
# Restoring model weights from the end of the best epoch.
# 840/840 - 8s - loss: 0.0307 - tp: 3197.0000 - fp: 114.0000 - tn: 23384.0000 - fn: 180.0000 - accuracy: 0.9891 - precision: 0.9656 - recall: 0.9467 - auc: 0.9976 - val_loss: 0.2512 - val_tp: 682.0000 - val_fp: 181.0000 - val_tn: 5718.0000 - val_fn: 138.0000 - val_accuracy: 0.9525 - val_precision: 0.7903 - val_recall: 0.8317 - val_auc: 0.9519
# Epoch 00007: early stopping
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: b3923199e3986cf6af82a0c1837ef111</span>
# <span style="color:cyan"> |-Score: 0.952820360660553</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-batch_size: 32</span>
# <span style="color:blue"> |-cnn_activation: relu</span>
# <span style="color:cyan"> |-cnn_global_kernel: 3</span>
# <span style="color:blue"> |-cnn_global_maxpool: 7</span>
# <span style="color:cyan"> |-cnn_global_stride: 1</span>
# <span style="color:blue"> |-cnn_local_kernel: 5</span>
# <span style="color:cyan"> |-cnn_local_maxpool: 7</span>
# <span style="color:blue"> |-cnn_local_stride: 3</span>
# <span style="color:cyan"> |-dense_activation: relu</span>
# <span style="color:blue"> |-dense_dropout: 0.0</span>
# <span style="color:cyan"> |-first_global_cnn_filters: 8</span>
# <span style="color:blue"> |-first_local_cnn_filters: 8</span>
# <span style="color:cyan"> |-further_global_cnn_filters: 16</span>
# <span style="color:blue"> |-further_global_cnn_layers: 1</span>
# <span style="color:cyan"> |-further_local_cnn_filters: 16</span>
# <span style="color:blue"> |-learning_rate: 0.0001</span>
# <span style="color:cyan"> |-number_of_dense_layers: 5</span>
# <span style="color:blue"> |-size_of_dense_layers: 512</span>
# Epoch 1/10
# 840/840 - 6s - loss: 0.1959 - tp: 2529.0000 - fp: 741.0000 - tn: 28656.0000 - fn: 1668.0000 - accuracy: 0.9283 - precision: 0.7734 - recall: 0.6026 - auc: 0.9402 - val_loss: 0.1546 - val_tp: 616.0000 - val_fp: 195.0000 - val_tn: 5704.0000 - val_fn: 204.0000 - val_accuracy: 0.9406 - val_precision: 0.7596 - val_recall: 0.7512 - val_auc: 0.9582
# Epoch 2/10
# 840/840 - 5s - loss: 0.1419 - tp: 2573.0000 - fp: 626.0000 - tn: 22872.0000 - fn: 804.0000 - accuracy: 0.9468 - precision: 0.8043 - recall: 0.7619 - auc: 0.9646 - val_loss: 0.1378 - val_tp: 689.0000 - val_fp: 214.0000 - val_tn: 5685.0000 - val_fn: 131.0000 - val_accuracy: 0.9487 - val_precision: 0.7630 - val_recall: 0.8402 - val_auc: 0.9658
# Epoch 3/10
# 840/840 - 5s - loss: 0.1230 - tp: 2712.0000 - fp: 528.0000 - tn: 22970.0000 - fn: 665.0000 - accuracy: 0.9556 - precision: 0.8370 - recall: 0.8031 - auc: 0.9712 - val_loss: 0.1270 - val_tp: 644.0000 - val_fp: 141.0000 - val_tn: 5758.0000 - val_fn: 176.0000 - val_accuracy: 0.9528 - val_precision: 0.8204 - val_recall: 0.7854 - val_auc: 0.9675
# Epoch 4/10
# 840/840 - 5s - loss: 0.1096 - tp: 2806.0000 - fp: 459.0000 - tn: 23039.0000 - fn: 571.0000 - accuracy: 0.9617 - precision: 0.8594 - recall: 0.8309 - auc: 0.9764 - val_loss: 0.1229 - val_tp: 687.0000 - val_fp: 169.0000 - val_tn: 5730.0000 - val_fn: 133.0000 - val_accuracy: 0.9551 - val_precision: 0.8026 - val_recall: 0.8378 - val_auc: 0.9695
# Epoch 5/10
# 840/840 - 5s - loss: 0.0998 - tp: 2863.0000 - fp: 419.0000 - tn: 23079.0000 - fn: 514.0000 - accuracy: 0.9653 - precision: 0.8723 - recall: 0.8478 - auc: 0.9804 - val_loss: 0.1254 - val_tp: 626.0000 - val_fp: 113.0000 - val_tn: 5786.0000 - val_fn: 194.0000 - val_accuracy: 0.9543 - val_precision: 0.8471 - val_recall: 0.7634 - val_auc: 0.9670
# Epoch 6/10
# 840/840 - 5s - loss: 0.0905 - tp: 2886.0000 - fp: 361.0000 - tn: 23137.0000 - fn: 491.0000 - accuracy: 0.9683 - precision: 0.8888 - recall: 0.8546 - auc: 0.9840 - val_loss: 0.1341 - val_tp: 597.0000 - val_fp: 81.0000 - val_tn: 5818.0000 - val_fn: 223.0000 - val_accuracy: 0.9548 - val_precision: 0.8805 - val_recall: 0.7280 - val_auc: 0.9659
# Epoch 7/10
# 840/840 - 5s - loss: 0.0822 - tp: 2941.0000 - fp: 309.0000 - tn: 23189.0000 - fn: 436.0000 - accuracy: 0.9723 - precision: 0.9049 - recall: 0.8709 - auc: 0.9866 - val_loss: 0.1284 - val_tp: 690.0000 - val_fp: 161.0000 - val_tn: 5738.0000 - val_fn: 130.0000 - val_accuracy: 0.9567 - val_precision: 0.8108 - val_recall: 0.8415 - val_auc: 0.9684
# Epoch 8/10
# 840/840 - 5s - loss: 0.0739 - tp: 2975.0000 - fp: 276.0000 - tn: 23222.0000 - fn: 402.0000 - accuracy: 0.9748 - precision: 0.9151 - recall: 0.8810 - auc: 0.9895 - val_loss: 0.1298 - val_tp: 686.0000 - val_fp: 169.0000 - val_tn: 5730.0000 - val_fn: 134.0000 - val_accuracy: 0.9549 - val_precision: 0.8023 - val_recall: 0.8366 - val_auc: 0.9676
# Epoch 9/10
# 840/840 - 5s - loss: 0.0675 - tp: 3000.0000 - fp: 249.0000 - tn: 23249.0000 - fn: 377.0000 - accuracy: 0.9767 - precision: 0.9234 - recall: 0.8884 - auc: 0.9916 - val_loss: 0.1294 - val_tp: 651.0000 - val_fp: 139.0000 - val_tn: 5760.0000 - val_fn: 169.0000 - val_accuracy: 0.9542 - val_precision: 0.8241 - val_recall: 0.7939 - val_auc: 0.9670
# Epoch 10/10
# Restoring model weights from the end of the best epoch.
# 840/840 - 5s - loss: 0.0582 - tp: 3046.0000 - fp: 199.0000 - tn: 23299.0000 - fn: 331.0000 - accuracy: 0.9803 - precision: 0.9387 - recall: 0.9020 - auc: 0.9934 - val_loss: 0.1468 - val_tp: 600.0000 - val_fp: 103.0000 - val_tn: 5796.0000 - val_fn: 220.0000 - val_accuracy: 0.9519 - val_precision: 0.8535 - val_recall: 0.7317 - val_auc: 0.9612
# Epoch 00010: early stopping
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: bfff29eed68be2b4adcfd0310f15a50f</span>
# <span style="color:cyan"> |-Score: 0.9566900134086609</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-batch_size: 32</span>
# <span style="color:blue"> |-cnn_activation: relu</span>
# <span style="color:cyan"> |-cnn_global_kernel: 3</span>
# <span style="color:blue"> |-cnn_global_maxpool: 3</span>
# <span style="color:cyan"> |-cnn_global_stride: 1</span>
# <span style="color:blue"> |-cnn_local_kernel: 5</span>
# <span style="color:cyan"> |-cnn_local_maxpool: 7</span>
# <span style="color:blue"> |-cnn_local_stride: 3</span>
# <span style="color:cyan"> |-dense_activation: relu</span>
# <span style="color:blue"> |-dense_dropout: 0.0</span>
# <span style="color:cyan"> |-first_global_cnn_filters: 8</span>
# <span style="color:blue"> |-first_local_cnn_filters: 32</span>
# <span style="color:cyan"> |-further_global_cnn_filters: 16</span>
# <span style="color:blue"> |-further_global_cnn_layers: 1</span>
# <span style="color:cyan"> |-further_local_cnn_filters: 128</span>
# <span style="color:blue"> |-learning_rate: 0.0001</span>
# <span style="color:cyan"> |-number_of_dense_layers: 2</span>
# <span style="color:blue"> |-size_of_dense_layers: 64</span>
# Epoch 1/10
# 840/840 - 6s - loss: 0.1871 - tp: 2597.0000 - fp: 656.0000 - tn: 28741.0000 - fn: 1600.0000 - accuracy: 0.9328 - precision: 0.7983 - recall: 0.6188 - auc: 0.9456 - val_loss: 0.1481 - val_tp: 653.0000 - val_fp: 221.0000 - val_tn: 5678.0000 - val_fn: 167.0000 - val_accuracy: 0.9423 - val_precision: 0.7471 - val_recall: 0.7963 - val_auc: 0.9611
# Epoch 2/10
# 840/840 - 5s - loss: 0.1306 - tp: 2690.0000 - fp: 557.0000 - tn: 22941.0000 - fn: 687.0000 - accuracy: 0.9537 - precision: 0.8285 - recall: 0.7966 - auc: 0.9676 - val_loss: 0.1219 - val_tp: 678.0000 - val_fp: 158.0000 - val_tn: 5741.0000 - val_fn: 142.0000 - val_accuracy: 0.9554 - val_precision: 0.8110 - val_recall: 0.8268 - val_auc: 0.9691
# Epoch 3/10
# ...
# <span style="color:cyan"> |-Trial ID: 809aa1e1111493afe25a3d5fea47eb1e</span>
# <span style="color:cyan"> |-Score: 0.9602619409561157</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-batch_size: 32</span>
# <span style="color:blue"> |-cnn_activation: relu</span>
# <span style="color:cyan"> |-cnn_global_kernel: 5</span>
# <span style="color:blue"> |-cnn_global_maxpool: 7</span>
# <span style="color:cyan"> |-cnn_global_stride: 2</span>
# <span style="color:blue"> |-cnn_local_kernel: 5</span>
# <span style="color:cyan"> |-cnn_local_maxpool: 5</span>
# <span style="color:blue"> |-cnn_local_stride: 3</span>
# <span style="color:cyan"> |-dense_activation: relu</span>
# <span style="color:blue"> |-dense_dropout: 0.0</span>
# <span style="color:cyan"> |-first_global_cnn_filters: 8</span>
# <span style="color:blue"> |-first_local_cnn_filters: 16</span>
# <span style="color:cyan"> |-further_global_cnn_filters: 32</span>
# <span style="color:blue"> |-further_global_cnn_layers: 1</span>
# <span style="color:cyan"> |-further_local_cnn_filters: 96</span>
# <span style="color:blue"> |-learning_rate: 0.0001</span>
# <span style="color:cyan"> |-number_of_dense_layers: 2</span>
# <span style="color:blue"> |-size_of_dense_layers: 512</span>
# Epoch 1/10
# 840/840 - 6s - loss: 0.2488 - tp: 1236.0000 - fp: 276.0000 - tn: 29121.0000 - fn: 2961.0000 - accuracy: 0.9036 - precision: 0.8175 - recall: 0.2945 - auc: 0.9164 - val_loss: 0.1801 - val_tp: 394.0000 - val_fp: 78.0000 - val_tn: 5821.0000 - val_fn: 426.0000 - val_accuracy: 0.9250 - val_precision: 0.8347 - val_recall: 0.4805 - val_auc: 0.9565
# Epoch 2/10
# 840/840 - 5s - loss: 0.1886 - tp: 2041.0000 - fp: 484.0000 - tn: 23014.0000 - fn: 1336.0000 - accuracy: 0.9323 - precision: 0.8083 - recall: 0.6044 - auc: 0.9529 - val_loss: 0.1698 - val_tp: 445.0000 - val_fp: 86.0000 - val_tn: 5813.0000 - val_fn: 375.0000 - val_accuracy: 0.9314 - val_precision: 0.8380 - val_recall: 0.5427 - val_auc: 0.9595
# Epoch 3/10
# 840/840 - 5s - loss: 0.1701 - tp: 2430.0000 - fp: 541.0000 - tn: 22957.0000 - fn: 947.0000 - accuracy: 0.9446 - precision: 0.8179 - recall: 0.7196 - auc: 0.9605 - val_loss: 0.1565 - val_tp: 580.0000 - val_fp: 139.0000 - val_tn: 5760.0000 - val_fn: 240.0000 - val_accuracy: 0.9436 - val_precision: 0.8067 - val_recall: 0.7073 - val_auc: 0.9622
# Epoch 4/10
# 840/840 - 5s - loss: 0.1559 - tp: 2604.0000 - fp: 540.0000 - tn: 22958.0000 - fn: 773.0000 - accuracy: 0.9511 - precision: 0.8282 - recall: 0.7711 - auc: 0.9650 - val_loss: 0.1447 - val_tp: 664.0000 - val_fp: 152.0000 - val_tn: 5747.0000 - val_fn: 156.0000 - val_accuracy: 0.9542 - val_precision: 0.8137 - val_recall: 0.8098 - val_auc: 0.9649
# Epoch 5/10
# 840/840 - 5s - loss: 0.1433 - tp: 2691.0000 - fp: 489.0000 - tn: 23009.0000 - fn: 686.0000 - accuracy: 0.9563 - precision: 0.8462 - recall: 0.7969 - auc: 0.9687 - val_loss: 0.1391 - val_tp: 628.0000 - val_fp: 116.0000 - val_tn: 5783.0000 - val_fn: 192.0000 - val_accuracy: 0.9542 - val_precision: 0.8441 - val_recall: 0.7659 - val_auc: 0.9666
# Epoch 6/10
# 840/840 - 5s - loss: 0.1303 - tp: 2766.0000 - fp: 466.0000 - tn: 23032.0000 - fn: 611.0000 - accuracy: 0.9599 - precision: 0.8558 - recall: 0.8191 - auc: 0.9726 - val_loss: 0.1357 - val_tp: 638.0000 - val_fp: 122.0000 - val_tn: 5777.0000 - val_fn: 182.0000 - val_accuracy: 0.9548 - val_precision: 0.8395 - val_recall: 0.7780 - val_auc: 0.9672
# Epoch 7/10
# 840/840 - 5s - loss: 0.1210 - tp: 2825.0000 - fp: 431.0000 - tn: 23067.0000 - fn: 552.0000 - accuracy: 0.9634 - precision: 0.8676 - recall: 0.8365 - auc: 0.9752 - val_loss: 0.1303 - val_tp: 670.0000 - val_fp: 136.0000 - val_tn: 5763.0000 - val_fn: 150.0000 - val_accuracy: 0.9574 - val_precision: 0.8313 - val_recall: 0.8171 - val_auc: 0.9676
# Epoch 8/10
# 840/840 - 5s - loss: 0.1100 - tp: 2874.0000 - fp: 412.0000 - tn: 23086.0000 - fn: 503.0000 - accuracy: 0.9660 - precision: 0.8746 - recall: 0.8511 - auc: 0.9795 - val_loss: 0.1332 - val_tp: 649.0000 - val_fp: 119.0000 - val_tn: 5780.0000 - val_fn: 171.0000 - val_accuracy: 0.9568 - val_precision: 0.8451 - val_recall: 0.7915 - val_auc: 0.9651
# Epoch 9/10
# 840/840 - 5s - loss: 0.1013 - tp: 2908.0000 - fp: 386.0000 - tn: 23112.0000 - fn: 469.0000 - accuracy: 0.9682 - precision: 0.8828 - recall: 0.8611 - auc: 0.9821 - val_loss: 0.1328 - val_tp: 674.0000 - val_fp: 145.0000 - val_tn: 5754.0000 - val_fn: 146.0000 - val_accuracy: 0.9567 - val_precision: 0.8230 - val_recall: 0.8220 - val_auc: 0.9659
# Epoch 10/10
# Restoring model weights from the end of the best epoch.
# 840/840 - 5s - loss: 0.0936 - tp: 2976.0000 - fp: 351.0000 - tn: 23147.0000 - fn: 401.0000 - accuracy: 0.9720 - precision: 0.8945 - recall: 0.8813 - auc: 0.9842 - val_loss: 0.1389 - val_tp: 618.0000 - val_fp: 105.0000 - val_tn: 5794.0000 - val_fn: 202.0000 - val_accuracy: 0.9543 - val_precision: 0.8548 - val_recall: 0.7537 - val_auc: 0.9645
# Epoch 00010: early stopping
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 98abeedc9e680a1ec83e37b0af1934cd</span>
# <span style="color:cyan"> |-Score: 0.9574341177940369</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-batch_size: 32</span>
# <span style="color:blue"> |-cnn_activation: relu</span>
# <span style="color:cyan"> |-cnn_global_kernel: 3</span>
# <span style="color:blue"> |-cnn_global_maxpool: 3</span>
# <span style="color:cyan"> |-cnn_global_stride: 1</span>
# <span style="color:blue"> |-cnn_local_kernel: 3</span>
# <span style="color:cyan"> |-cnn_local_maxpool: 3</span>
# <span style="color:blue"> |-cnn_local_stride: 2</span>
# <span style="color:cyan"> |-dense_activation: relu</span>
# <span style="color:blue"> |-dense_dropout: 0.5</span>
# <span style="color:cyan"> |-first_global_cnn_filters: 8</span>
# <span style="color:blue"> |-first_local_cnn_filters: 16</span>
# <span style="color:cyan"> |-further_global_cnn_filters: 16</span>
# <span style="color:blue"> |-further_global_cnn_layers: 1</span>
# <span style="color:cyan"> |-further_local_cnn_filters: 32</span>
# <span style="color:blue"> |-learning_rate: 0.0001</span>
# <span style="color:cyan"> |-number_of_dense_layers: 2</span>
# <span style="color:blue"> |-size_of_dense_layers: 64</span>
# Epoch 1/10
# 840/840 - 6s - loss: 0.2039 - tp: 2355.0000 - fp: 618.0000 - tn: 28779.0000 - fn: 1842.0000 - accuracy: 0.9268 - precision: 0.7921 - recall: 0.5611 - auc: 0.9385 - val_loss: 0.1530 - val_tp: 535.0000 - val_fp: 137.0000 - val_tn: 5762.0000 - val_fn: 285.0000 - val_accuracy: 0.9372 - val_precision: 0.7961 - val_recall: 0.6524 - val_auc: 0.9596
# Epoch 2/10
# 840/840 - 5s - loss: 0.1391 - tp: 2613.0000 - fp: 625.0000 - tn: 22873.0000 - fn: 764.0000 - accuracy: 0.9483 - precision: 0.8070 - recall: 0.7738 - auc: 0.9655 - val_loss: 0.1371 - val_tp: 667.0000 - val_fp: 186.0000 - val_tn: 5713.0000 - val_fn: 153.0000 - val_accuracy: 0.9495 - val_precision: 0.7819 - val_recall: 0.8134 - val_auc: 0.9658
# Epoch 3/10
# 840/840 - 5s - loss: 0.1211 - tp: 2749.0000 - fp: 528.0000 - tn: 22970.0000 - fn: 628.0000 - accuracy: 0.9570 - precision: 0.8389 - recall: 0.8140 - auc: 0.9724 - val_loss: 0.1282 - val_tp: 627.0000 - val_fp: 114.0000 - val_tn: 5785.0000 - val_fn: 193.0000 - val_accuracy: 0.9543 - val_precision: 0.8462 - val_recall: 0.7646 - val_auc: 0.9676
# Epoch 4/10
# 840/840 - 5s - loss: 0.1073 - tp: 2830.0000 - fp: 432.0000 - tn: 23066.0000 - fn: 547.0000 - accuracy: 0.9636 - precision: 0.8676 - recall: 0.8380 - auc: 0.9770 - val_loss: 0.1299 - val_tp: 612.0000 - val_fp: 98.0000 - val_tn: 5801.0000 - val_fn: 208.0000 - val_accuracy: 0.9545 - val_precision: 0.8620 - val_recall: 0.7463 - val_auc: 0.9669
# Epoch 5/10
# 840/840 - 5s - loss: 0.0951 - tp: 2884.0000 - fp: 363.0000 - tn: 23135.0000 - fn: 493.0000 - accuracy: 0.9681 - precision: 0.8882 - recall: 0.8540 - auc: 0.9809 - val_loss: 0.1276 - val_tp: 639.0000 - val_fp: 115.0000 - val_tn: 5784.0000 - val_fn: 181.0000 - val_accuracy: 0.9559 - val_precision: 0.8475 - val_recall: 0.7793 - val_auc: 0.9666
# Epoch 6/10
# 840/840 - 5s - loss: 0.0828 - tp: 2968.0000 - fp: 305.0000 - tn: 23193.0000 - fn: 409.0000 - accuracy: 0.9734 - precision: 0.9068 - recall: 0.8789 - auc: 0.9851 - val_loss: 0.1416 - val_tp: 583.0000 - val_fp: 82.0000 - val_tn: 5817.0000 - val_fn: 237.0000 - val_accuracy: 0.9525 - val_precision: 0.8767 - val_recall: 0.7110 - val_auc: 0.9650
# Epoch 7/10
# 840/840 - 5s - loss: 0.0744 - tp: 3006.0000 - fp: 261.0000 - tn: 23237.0000 - fn: 371.0000 - accuracy: 0.9765 - precision: 0.9201 - recall: 0.8901 - auc: 0.9875 - val_loss: 0.1289 - val_tp: 648.0000 - val_fp: 132.0000 - val_tn: 5767.0000 - val_fn: 172.0000 - val_accuracy: 0.9548 - val_precision: 0.8308 - val_recall: 0.7902 - val_auc: 0.9669
# Epoch 8/10
# Restoring model weights from the end of the best epoch.
# 840/840 - 5s - loss: 0.0630 - tp: 3054.0000 - fp: 214.0000 - tn: 23284.0000 - fn: 323.0000 - accuracy: 0.9800 - precision: 0.9345 - recall: 0.9044 - auc: 0.9908 - val_loss: 0.1424 - val_tp: 622.0000 - val_fp: 117.0000 - val_tn: 5782.0000 - val_fn: 198.0000 - val_accuracy: 0.9531 - val_precision: 0.8417 - val_recall: 0.7585 - val_auc: 0.9630
# Epoch 00008: early stopping
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 7e26137b7011d522249c54b225c176c7</span>
# <span style="color:cyan"> |-Score: 0.9559458494186401</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-batch_size: 32</span>
# <span style="color:blue"> |-cnn_activation: relu</span>
# <span style="color:cyan"> |-cnn_global_kernel: 5</span>
# <span style="color:blue"> |-cnn_global_maxpool: 3</span>
# <span style="color:cyan"> |-cnn_global_stride: 1</span>
# <span style="color:blue"> |-cnn_local_kernel: 5</span>
# <span style="color:cyan"> |-cnn_local_maxpool: 3</span>
# <span style="color:blue"> |-cnn_local_stride: 2</span>
# <span style="color:cyan"> |-dense_activation: relu</span>
# <span style="color:blue"> |-dense_dropout: 0.0</span>
# <span style="color:cyan"> |-first_global_cnn_filters: 8</span>
# <span style="color:blue"> |-first_local_cnn_filters: 8</span>
# <span style="color:cyan"> |-further_global_cnn_filters: 16</span>
# <span style="color:blue"> |-further_global_cnn_layers: 1</span>
# <span style="color:cyan"> |-further_local_cnn_filters: 16</span>
# <span style="color:blue"> |-learning_rate: 0.0001</span>
# <span style="color:cyan"> |-number_of_dense_layers: 2</span>
# <span style="color:blue"> |-size_of_dense_layers: 64</span>
# Epoch 1/10
# 840/840 - 8s - loss: 0.3120 - tp: 716.0000 - fp: 821.0000 - tn: 28576.0000 - fn: 3481.0000 - accuracy: 0.8719 - precision: 0.4658 - recall: 0.1706 - auc: 0.8669 - val_loss: 0.1902 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 5899.0000 - val_fn: 820.0000 - val_accuracy: 0.8780 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.9500
# Epoch 2/10
# 840/840 - 8s - loss: 0.2076 - tp: 319.0000 - fp: 86.0000 - tn: 23412.0000 - fn: 3058.0000 - accuracy: 0.8830 - precision: 0.7877 - recall: 0.0945 - auc: 0.9425 - val_loss: 0.1791 - val_tp: 466.0000 - val_fp: 92.0000 - val_tn: 5807.0000 - val_fn: 354.0000 - val_accuracy: 0.9336 - val_precision: 0.8351 - val_recall: 0.5683 - val_auc: 0.9559
# Epoch 3/10
# 840/840 - 8s - loss: 0.1897 - tp: 2111.0000 - fp: 412.0000 - tn: 23086.0000 - fn: 1266.0000 - accuracy: 0.9376 - precision: 0.8367 - recall: 0.6251 - auc: 0.9531 - val_loss: 0.1732 - val_tp: 505.0000 - val_fp: 83.0000 - val_tn: 5816.0000 - val_fn: 315.0000 - val_accuracy: 0.9408 - val_precision: 0.8588 - val_recall: 0.6159 - val_auc: 0.9609
# Epoch 4/10
# 840/840 - 8s - loss: 0.1818 - tp: 2307.0000 - fp: 451.0000 - tn: 23047.0000 - fn: 1070.0000 - accuracy: 0.9434 - precision: 0.8365 - recall: 0.6832 - auc: 0.9577 - val_loss: 0.1699 - val_tp: 572.0000 - val_fp: 121.0000 - val_tn: 5778.0000 - val_fn: 248.0000 - val_accuracy: 0.9451 - val_precision: 0.8254 - val_recall: 0.6976 - val_auc: 0.9609
# Epoch 5/10
# 840/840 - 8s - loss: 0.1737 - tp: 2390.0000 - fp: 463.0000 - tn: 23035.0000 - fn: 987.0000 - accuracy: 0.9460 - precision: 0.8377 - recall: 0.7077 - auc: 0.9620 - val_loss: 0.1665 - val_tp: 575.0000 - val_fp: 122.0000 - val_tn: 5777.0000 - val_fn: 245.0000 - val_accuracy: 0.9454 - val_precision: 0.8250 - val_recall: 0.7012 - val_auc: 0.9622
# Epoch 6/10
# 840/840 - 8s - loss: 0.1662 - tp: 2508.0000 - fp: 476.0000 - tn: 23022.0000 - fn: 869.0000 - accuracy: 0.9500 - precision: 0.8405 - recall: 0.7427 - auc: 0.9649 - val_loss: 0.1646 - val_tp: 551.0000 - val_fp: 102.0000 - val_tn: 5797.0000 - val_fn: 269.0000 - val_accuracy: 0.9448 - val_precision: 0.8438 - val_recall: 0.6720 - val_auc: 0.9635
# Epoch 7/10
# 840/840 - 8s - loss: 0.1637 - tp: 2577.0000 - fp: 436.0000 - tn: 23062.0000 - fn: 800.0000 - accuracy: 0.9540 - precision: 0.8553 - recall: 0.7631 - auc: 0.9679 - val_loss: 0.1667 - val_tp: 635.0000 - val_fp: 176.0000 - val_tn: 5723.0000 - val_fn: 185.0000 - val_accuracy: 0.9463 - val_precision: 0.7830 - val_recall: 0.7744 - val_auc: 0.9628
# Epoch 8/10
# 840/840 - 8s - loss: 0.1547 - tp: 2621.0000 - fp: 404.0000 - tn: 23094.0000 - fn: 756.0000 - accuracy: 0.9568 - precision: 0.8664 - recall: 0.7761 - auc: 0.9730 - val_loss: 0.1601 - val_tp: 670.0000 - val_fp: 185.0000 - val_tn: 5714.0000 - val_fn: 150.0000 - val_accuracy: 0.9501 - val_precision: 0.7836 - val_recall: 0.8171 - val_auc: 0.9644
# Epoch 9/10
# 840/840 - 8s - loss: 0.1428 - tp: 2720.0000 - fp: 376.0000 - tn: 23122.0000 - fn: 657.0000 - accuracy: 0.9616 - precision: 0.8786 - recall: 0.8054 - auc: 0.9767 - val_loss: 0.1556 - val_tp: 631.0000 - val_fp: 136.0000 - val_tn: 5763.0000 - val_fn: 189.0000 - val_accuracy: 0.9516 - val_precision: 0.8227 - val_recall: 0.7695 - val_auc: 0.9674
# Epoch 10/10
# 840/840 - 8s - loss: 0.1366 - tp: 2779.0000 - fp: 369.0000 - tn: 23129.0000 - fn: 598.0000 - accuracy: 0.9640 - precision: 0.8828 - recall: 0.8229 - auc: 0.9793 - val_loss: 0.1554 - val_tp: 675.0000 - val_fp: 190.0000 - val_tn: 5709.0000 - val_fn: 145.0000 - val_accuracy: 0.9501 - val_precision: 0.7803 - val_recall: 0.8232 - val_auc: 0.9671
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 9f090b6727a7c2d00d6d052c1316aec0</span>
# <span style="color:cyan"> |-Score: 0.9516296982765198</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-batch_size: 32</span>
# <span style="color:blue"> |-cnn_activation: relu</span>
# <span style="color:cyan"> |-cnn_global_kernel: 3</span>
# <span style="color:blue"> |-cnn_global_maxpool: 7</span>
# <span style="color:cyan"> |-cnn_global_stride: 1</span>
# <span style="color:blue"> |-cnn_local_kernel: 3</span>
# <span style="color:cyan"> |-cnn_local_maxpool: 5</span>
# <span style="color:blue"> |-cnn_local_stride: 3</span>
# <span style="color:cyan"> |-dense_activation: relu</span>
# <span style="color:blue"> |-dense_dropout: 0.5</span>
# <span style="color:cyan"> |-first_global_cnn_filters: 16</span>
# <span style="color:blue"> |-first_local_cnn_filters: 16</span>
# <span style="color:cyan"> |-further_global_cnn_filters: 48</span>
# <span style="color:blue"> |-further_global_cnn_layers: 1</span>
# <span style="color:cyan"> |-further_local_cnn_filters: 16</span>
# <span style="color:blue"> |-learning_rate: 0.0001</span>
# <span style="color:cyan"> |-number_of_dense_layers: 3</span>
# <span style="color:blue"> |-size_of_dense_layers: 64</span>
# INFO:tensorflow:Oracle triggered exit
# Start 1605873326.444573
# End 1605879199.9277453
# Duration (hours) 1.6315231034490798

# %%
# Get the optimal hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials = 1)[0]

# reassembles model and then you retrain it
model=tuner.hypermodel.build(best_hps)

print(model.summary())
print(tuner.search_space_summary())

#you don't use below - you rebuild model with best hyperparameters and then retrain
#best_model=tuner.get_best_models(num_models=1)[0]

print(best_hps.get('learning_rate'),best_hps.get('size_of_dense_layers'))
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 201, 1)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 2001, 1)]    0
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 197, 32)      192         input_1[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 1997, 8)      48          input_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 66, 32)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 666, 8)       0           conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 62, 128)      20608       max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 662, 128)     5248        max_pooling1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 21, 128)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 221, 128)     0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 17, 128)      82048       max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 217, 128)     82048       max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 6, 128)       0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 73, 128)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 768)          0           max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 9344)         0           max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 10112)        0           flatten_1[0][0]
#                                                                  flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          5177856     concatenate[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          262656      dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          262656      dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 512)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            513         dropout_2[0][0]
# ==================================================================================================
# Total params: 5,893,873
# Trainable params: 5,893,873
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# <span style="color:#4527A0"><h1 style="font-size:18px">Search space summary</h1></span>
# <span style="color:cyan"> |-Default search space size: 18</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">first_global_cnn_filters (Int)</h2></span>
# <span style="color:cyan"> |-default: None</span>
# <span style="color:blue"> |-max_value: 32</span>
# <span style="color:cyan"> |-min_value: 8</span>
# <span style="color:blue"> |-sampling: None</span>
# <span style="color:cyan"> |-step: 8</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">further_global_cnn_filters (Int)</h2></span>
# <span style="color:cyan"> |-default: None</span>
# <span style="color:blue"> |-max_value: 128</span>
# <span style="color:cyan"> |-min_value: 16</span>
# <span style="color:blue"> |-sampling: None</span>
# <span style="color:cyan"> |-step: 16</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">cnn_global_kernel (Int)</h2></span>
# <span style="color:cyan"> |-default: None</span>
# <span style="color:blue"> |-max_value: 5</span>
# <span style="color:cyan"> |-min_value: 3</span>
# <span style="color:blue"> |-sampling: None</span>
# <span style="color:cyan"> |-step: 2</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">cnn_global_maxpool (Int)</h2></span>
# <span style="color:cyan"> |-default: None</span>
# <span style="color:blue"> |-max_value: 7</span>
# <span style="color:cyan"> |-min_value: 3</span>
# <span style="color:blue"> |-sampling: None</span>
# <span style="color:cyan"> |-step: 2</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">cnn_global_stride (Int)</h2></span>
# <span style="color:cyan"> |-default: None</span>
# <span style="color:blue"> |-max_value: 3</span>
# <span style="color:cyan"> |-min_value: 1</span>
# <span style="color:blue"> |-sampling: None</span>
# <span style="color:cyan"> |-step: 1</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">first_local_cnn_filters (Int)</h2></span>
# <span style="color:cyan"> |-default: None</span>
# <span style="color:blue"> |-max_value: 32</span>
# <span style="color:cyan"> |-min_value: 8</span>
# <span style="color:blue"> |-sampling: None</span>
# <span style="color:cyan"> |-step: 8</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">further_local_cnn_filters (Int)</h2></span>
# <span style="color:cyan"> |-default: None</span>
# <span style="color:blue"> |-max_value: 128</span>
# <span style="color:cyan"> |-min_value: 16</span>
# <span style="color:blue"> |-sampling: None</span>
# <span style="color:cyan"> |-step: 16</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">cnn_local_kernel (Int)</h2></span>
# <span style="color:cyan"> |-default: None</span>
# <span style="color:blue"> |-max_value: 5</span>
# <span style="color:cyan"> |-min_value: 3</span>
# <span style="color:blue"> |-sampling: None</span>
# <span style="color:cyan"> |-step: 2</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">cnn_local_maxpool (Int)</h2></span>
# <span style="color:cyan"> |-default: None</span>
# <span style="color:blue"> |-max_value: 7</span>
# <span style="color:cyan"> |-min_value: 3</span>
# <span style="color:blue"> |-sampling: None</span>
# <span style="color:cyan"> |-step: 2</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">cnn_local_stride (Int)</h2></span>
# <span style="color:cyan"> |-default: None</span>
# <span style="color:blue"> |-max_value: 3</span>
# <span style="color:cyan"> |-min_value: 1</span>
# <span style="color:blue"> |-sampling: None</span>
# <span style="color:cyan"> |-step: 1</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">cnn_activation (Choice)</h2></span>
# <span style="color:cyan"> |-default: relu</span>
# <span style="color:blue"> |-ordered: False</span>
# <span style="color:cyan"> |-values: ['relu']</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">further_global_cnn_layers (Int)</h2></span>
# <span style="color:cyan"> |-default: None</span>
# <span style="color:blue"> |-max_value: 3</span>
# <span style="color:cyan"> |-min_value: 1</span>
# <span style="color:blue"> |-sampling: None</span>
# <span style="color:cyan"> |-step: 1</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">number_of_dense_layers (Int)</h2></span>
# <span style="color:cyan"> |-default: None</span>
# <span style="color:blue"> |-max_value: 5</span>
# <span style="color:cyan"> |-min_value: 2</span>
# <span style="color:blue"> |-sampling: None</span>
# <span style="color:cyan"> |-step: 1</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">size_of_dense_layers (Int)</h2></span>
# <span style="color:cyan"> |-default: None</span>
# <span style="color:blue"> |-max_value: 512</span>
# <span style="color:cyan"> |-min_value: 64</span>
# <span style="color:blue"> |-sampling: None</span>
# <span style="color:cyan"> |-step: 64</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">dense_activation (Choice)</h2></span>
# <span style="color:cyan"> |-default: relu</span>
# <span style="color:blue"> |-ordered: False</span>
# <span style="color:cyan"> |-values: ['relu']</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">dense_dropout (Choice)</h2></span>
# <span style="color:cyan"> |-default: 0.0</span>
# <span style="color:blue"> |-ordered: True</span>
# <span style="color:cyan"> |-values: [0.0, 0.2, 0.5]</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">learning_rate (Choice)</h2></span>
# <span style="color:cyan"> |-default: 0.0001</span>
# <span style="color:blue"> |-ordered: True</span>
# <span style="color:cyan"> |-values: [0.0001, 1e-05, 1e-06]</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">batch_size (Int)</h2></span>
# <span style="color:cyan"> |-default: None</span>
# <span style="color:blue"> |-max_value: 256</span>
# <span style="color:cyan"> |-min_value: 32</span>
# <span style="color:blue"> |-sampling: None</span>
# <span style="color:cyan"> |-step: 32</span>
# None
# 0.0001 512

# %%
def load_model(model_name):
    model_name='best_tuned_hp_model_v3'
    model = tf.keras.models.load_model(os.path.join(MODEL_DIR,model_name))
    return model
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 201, 1)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 2001, 1)]    0
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 197, 32)      192         input_1[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 1997, 8)      48          input_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 66, 32)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 666, 8)       0           conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 62, 128)      20608       max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 662, 128)     5248        max_pooling1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 21, 128)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 221, 128)     0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 17, 128)      82048       max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 217, 128)     82048       max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 6, 128)       0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 73, 128)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 768)          0           max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 9344)         0           max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 10112)        0           flatten_1[0][0]
#                                                                  flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          5177856     concatenate[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          262656      dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          262656      dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 512)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            513         dropout_2[0][0]
# ==================================================================================================
# Total params: 5,893,873
# Trainable params: 5,893,873
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#change learning rate
from keras import backend as K
# To get learning rate
print(K.get_value(model.optimizer.lr))
# To set learning rate
K.set_value(model.optimizer.lr, 1e-05)
print(K.get_value(model.optimizer.lr))

tf.keras.__version__ # 2.0.2
# Out:
# 1e-06
# 1e-05
# '2.3.0-tf'

# %%
#this retrains model with best hyperparameters
EPOCHS=50
BATCH_SIZE=96

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy', 
    verbose=1,
    patience=20,
    mode='max',
    restore_best_weights=True)

tf.keras.backend.clear_session()
history=model.fit([x_local_train,x_global_train],
                  Y_train,
                  validation_data=([x_local_val,x_global_val],Y_val),
                  epochs=EPOCHS,
                  batch_size=BATCH_SIZE,
                  callbacks=[early_stopping],
                  verbose=2)
# Out:
# Epoch 1/50
# 280/280 - 5s - loss: 0.1459 - tp: 2581.0000 - fp: 601.0000 - tn: 22875.0000 - fn: 818.0000 - accuracy: 0.9472 - precision: 0.8111 - recall: 0.7593 - auc: 0.9608 - val_loss: 0.1432 - val_tp: 601.0000 - val_fp: 127.0000 - val_tn: 5794.0000 - val_fn: 197.0000 - val_accuracy: 0.9518 - val_precision: 0.8255 - val_recall: 0.7531 - val_auc: 0.9722
# Epoch 2/50
# 280/280 - 5s - loss: 0.1388 - tp: 2627.0000 - fp: 584.0000 - tn: 22892.0000 - fn: 772.0000 - accuracy: 0.9495 - precision: 0.8181 - recall: 0.7729 - auc: 0.9635 - val_loss: 0.1395 - val_tp: 627.0000 - val_fp: 146.0000 - val_tn: 5775.0000 - val_fn: 171.0000 - val_accuracy: 0.9528 - val_precision: 0.8111 - val_recall: 0.7857 - val_auc: 0.9738
# Epoch 3/50
# 280/280 - 5s - loss: 0.1326 - tp: 2695.0000 - fp: 553.0000 - tn: 22923.0000 - fn: 704.0000 - accuracy: 0.9532 - precision: 0.8297 - recall: 0.7929 - auc: 0.9656 - val_loss: 0.1377 - val_tp: 659.0000 - val_fp: 175.0000 - val_tn: 5746.0000 - val_fn: 139.0000 - val_accuracy: 0.9533 - val_precision: 0.7902 - val_recall: 0.8258 - val_auc: 0.9755
# Epoch 4/50
# 280/280 - 5s - loss: 0.1290 - tp: 2710.0000 - fp: 527.0000 - tn: 22949.0000 - fn: 689.0000 - accuracy: 0.9548 - precision: 0.8372 - recall: 0.7973 - auc: 0.9670 - val_loss: 0.1315 - val_tp: 638.0000 - val_fp: 126.0000 - val_tn: 5795.0000 - val_fn: 160.0000 - val_accuracy: 0.9574 - val_precision: 0.8351 - val_recall: 0.7995 - val_auc: 0.9762
# Epoch 5/50
# 280/280 - 5s - loss: 0.1230 - tp: 2762.0000 - fp: 507.0000 - tn: 22969.0000 - fn: 637.0000 - accuracy: 0.9574 - precision: 0.8449 - recall: 0.8126 - auc: 0.9689 - val_loss: 0.1309 - val_tp: 599.0000 - val_fp: 82.0000 - val_tn: 5839.0000 - val_fn: 199.0000 - val_accuracy: 0.9582 - val_precision: 0.8796 - val_recall: 0.7506 - val_auc: 0.9765
# Epoch 6/50
# 280/280 - 5s - loss: 0.1190 - tp: 2763.0000 - fp: 463.0000 - tn: 23013.0000 - fn: 636.0000 - accuracy: 0.9591 - precision: 0.8565 - recall: 0.8129 - auc: 0.9705 - val_loss: 0.1373 - val_tp: 698.0000 - val_fp: 211.0000 - val_tn: 5710.0000 - val_fn: 100.0000 - val_accuracy: 0.9537 - val_precision: 0.7679 - val_recall: 0.8747 - val_auc: 0.9779
# Epoch 7/50
# 280/280 - 5s - loss: 0.1168 - tp: 2802.0000 - fp: 482.0000 - tn: 22994.0000 - fn: 597.0000 - accuracy: 0.9599 - precision: 0.8532 - recall: 0.8244 - auc: 0.9706 - val_loss: 0.1272 - val_tp: 660.0000 - val_fp: 126.0000 - val_tn: 5795.0000 - val_fn: 138.0000 - val_accuracy: 0.9607 - val_precision: 0.8397 - val_recall: 0.8271 - val_auc: 0.9779
# Epoch 8/50
# 280/280 - 5s - loss: 0.1136 - tp: 2813.0000 - fp: 447.0000 - tn: 23029.0000 - fn: 586.0000 - accuracy: 0.9616 - precision: 0.8629 - recall: 0.8276 - auc: 0.9725 - val_loss: 0.1282 - val_tp: 681.0000 - val_fp: 154.0000 - val_tn: 5767.0000 - val_fn: 117.0000 - val_accuracy: 0.9597 - val_precision: 0.8156 - val_recall: 0.8534 - val_auc: 0.9789
# Epoch 9/50
# 280/280 - 5s - loss: 0.1126 - tp: 2811.0000 - fp: 424.0000 - tn: 23052.0000 - fn: 588.0000 - accuracy: 0.9623 - precision: 0.8689 - recall: 0.8270 - auc: 0.9723 - val_loss: 0.1252 - val_tp: 602.0000 - val_fp: 81.0000 - val_tn: 5840.0000 - val_fn: 196.0000 - val_accuracy: 0.9588 - val_precision: 0.8814 - val_recall: 0.7544 - val_auc: 0.9770
# Epoch 10/50
# 280/280 - 5s - loss: 0.1088 - tp: 2858.0000 - fp: 419.0000 - tn: 23057.0000 - fn: 541.0000 - accuracy: 0.9643 - precision: 0.8721 - recall: 0.8408 - auc: 0.9736 - val_loss: 0.1324 - val_tp: 699.0000 - val_fp: 202.0000 - val_tn: 5719.0000 - val_fn: 99.0000 - val_accuracy: 0.9552 - val_precision: 0.7758 - val_recall: 0.8759 - val_auc: 0.9791
# Epoch 11/50
# 280/280 - 5s - loss: 0.1075 - tp: 2839.0000 - fp: 407.0000 - tn: 23069.0000 - fn: 560.0000 - accuracy: 0.9640 - precision: 0.8746 - recall: 0.8352 - auc: 0.9738 - val_loss: 0.1211 - val_tp: 627.0000 - val_fp: 92.0000 - val_tn: 5829.0000 - val_fn: 171.0000 - val_accuracy: 0.9609 - val_precision: 0.8720 - val_recall: 0.7857 - val_auc: 0.9773
# Epoch 12/50
# 280/280 - 5s - loss: 0.1059 - tp: 2845.0000 - fp: 397.0000 - tn: 23079.0000 - fn: 554.0000 - accuracy: 0.9646 - precision: 0.8775 - recall: 0.8370 - auc: 0.9750 - val_loss: 0.1214 - val_tp: 615.0000 - val_fp: 81.0000 - val_tn: 5840.0000 - val_fn: 183.0000 - val_accuracy: 0.9607 - val_precision: 0.8836 - val_recall: 0.7707 - val_auc: 0.9775
# Epoch 13/50
# 280/280 - 5s - loss: 0.1039 - tp: 2856.0000 - fp: 404.0000 - tn: 23072.0000 - fn: 543.0000 - accuracy: 0.9648 - precision: 0.8761 - recall: 0.8402 - auc: 0.9760 - val_loss: 0.1214 - val_tp: 662.0000 - val_fp: 126.0000 - val_tn: 5795.0000 - val_fn: 136.0000 - val_accuracy: 0.9610 - val_precision: 0.8401 - val_recall: 0.8296 - val_auc: 0.9792
# Epoch 14/50
# 280/280 - 5s - loss: 0.1027 - tp: 2885.0000 - fp: 380.0000 - tn: 23096.0000 - fn: 514.0000 - accuracy: 0.9667 - precision: 0.8836 - recall: 0.8488 - auc: 0.9763 - val_loss: 0.1232 - val_tp: 666.0000 - val_fp: 136.0000 - val_tn: 5785.0000 - val_fn: 132.0000 - val_accuracy: 0.9601 - val_precision: 0.8304 - val_recall: 0.8346 - val_auc: 0.9788
# Epoch 15/50
# 280/280 - 5s - loss: 0.1010 - tp: 2884.0000 - fp: 380.0000 - tn: 23096.0000 - fn: 515.0000 - accuracy: 0.9667 - precision: 0.8836 - recall: 0.8485 - auc: 0.9769 - val_loss: 0.1223 - val_tp: 662.0000 - val_fp: 126.0000 - val_tn: 5795.0000 - val_fn: 136.0000 - val_accuracy: 0.9610 - val_precision: 0.8401 - val_recall: 0.8296 - val_auc: 0.9782
# Epoch 16/50
# 280/280 - 5s - loss: 0.1000 - tp: 2892.0000 - fp: 382.0000 - tn: 23094.0000 - fn: 507.0000 - accuracy: 0.9669 - precision: 0.8833 - recall: 0.8508 - auc: 0.9774 - val_loss: 0.1218 - val_tp: 668.0000 - val_fp: 125.0000 - val_tn: 5796.0000 - val_fn: 130.0000 - val_accuracy: 0.9620 - val_precision: 0.8424 - val_recall: 0.8371 - val_auc: 0.9782
# Epoch 17/50
# 280/280 - 5s - loss: 0.0995 - tp: 2889.0000 - fp: 372.0000 - tn: 23104.0000 - fn: 510.0000 - accuracy: 0.9672 - precision: 0.8859 - recall: 0.8500 - auc: 0.9773 - val_loss: 0.1201 - val_tp: 665.0000 - val_fp: 120.0000 - val_tn: 5801.0000 - val_fn: 133.0000 - val_accuracy: 0.9623 - val_precision: 0.8471 - val_recall: 0.8333 - val_auc: 0.9786
# Epoch 18/50
# 280/280 - 5s - loss: 0.0975 - tp: 2904.0000 - fp: 374.0000 - tn: 23102.0000 - fn: 495.0000 - accuracy: 0.9677 - precision: 0.8859 - recall: 0.8544 - auc: 0.9790 - val_loss: 0.1202 - val_tp: 614.0000 - val_fp: 77.0000 - val_tn: 5844.0000 - val_fn: 184.0000 - val_accuracy: 0.9612 - val_precision: 0.8886 - val_recall: 0.7694 - val_auc: 0.9772
# Epoch 19/50
# 280/280 - 5s - loss: 0.0962 - tp: 2908.0000 - fp: 360.0000 - tn: 23116.0000 - fn: 491.0000 - accuracy: 0.9683 - precision: 0.8898 - recall: 0.8555 - auc: 0.9793 - val_loss: 0.1203 - val_tp: 663.0000 - val_fp: 119.0000 - val_tn: 5802.0000 - val_fn: 135.0000 - val_accuracy: 0.9622 - val_precision: 0.8478 - val_recall: 0.8308 - val_auc: 0.9788
# Epoch 20/50
# 280/280 - 5s - loss: 0.0960 - tp: 2917.0000 - fp: 379.0000 - tn: 23097.0000 - fn: 482.0000 - accuracy: 0.9680 - precision: 0.8850 - recall: 0.8582 - auc: 0.9792 - val_loss: 0.1240 - val_tp: 686.0000 - val_fp: 145.0000 - val_tn: 5776.0000 - val_fn: 112.0000 - val_accuracy: 0.9618 - val_precision: 0.8255 - val_recall: 0.8596 - val_auc: 0.9786
# Epoch 21/50
# 280/280 - 5s - loss: 0.0935 - tp: 2943.0000 - fp: 363.0000 - tn: 23113.0000 - fn: 456.0000 - accuracy: 0.9695 - precision: 0.8902 - recall: 0.8658 - auc: 0.9802 - val_loss: 0.1202 - val_tp: 665.0000 - val_fp: 117.0000 - val_tn: 5804.0000 - val_fn: 133.0000 - val_accuracy: 0.9628 - val_precision: 0.8504 - val_recall: 0.8333 - val_auc: 0.9782
# Epoch 22/50
# 280/280 - 5s - loss: 0.0926 - tp: 2940.0000 - fp: 352.0000 - tn: 23124.0000 - fn: 459.0000 - accuracy: 0.9698 - precision: 0.8931 - recall: 0.8650 - auc: 0.9801 - val_loss: 0.1220 - val_tp: 676.0000 - val_fp: 133.0000 - val_tn: 5788.0000 - val_fn: 122.0000 - val_accuracy: 0.9620 - val_precision: 0.8356 - val_recall: 0.8471 - val_auc: 0.9776
# Epoch 23/50
# 280/280 - 5s - loss: 0.0916 - tp: 2942.0000 - fp: 357.0000 - tn: 23119.0000 - fn: 457.0000 - accuracy: 0.9697 - precision: 0.8918 - recall: 0.8655 - auc: 0.9809 - val_loss: 0.1206 - val_tp: 634.0000 - val_fp: 89.0000 - val_tn: 5832.0000 - val_fn: 164.0000 - val_accuracy: 0.9623 - val_precision: 0.8769 - val_recall: 0.7945 - val_auc: 0.9771
# Epoch 24/50
# 280/280 - 5s - loss: 0.0900 - tp: 2950.0000 - fp: 342.0000 - tn: 23134.0000 - fn: 449.0000 - accuracy: 0.9706 - precision: 0.8961 - recall: 0.8679 - auc: 0.9815 - val_loss: 0.1225 - val_tp: 672.0000 - val_fp: 125.0000 - val_tn: 5796.0000 - val_fn: 126.0000 - val_accuracy: 0.9626 - val_precision: 0.8432 - val_recall: 0.8421 - val_auc: 0.9777
# Epoch 25/50
# 280/280 - 5s - loss: 0.0893 - tp: 2964.0000 - fp: 342.0000 - tn: 23134.0000 - fn: 435.0000 - accuracy: 0.9711 - precision: 0.8966 - recall: 0.8720 - auc: 0.9821 - val_loss: 0.1231 - val_tp: 612.0000 - val_fp: 80.0000 - val_tn: 5841.0000 - val_fn: 186.0000 - val_accuracy: 0.9604 - val_precision: 0.8844 - val_recall: 0.7669 - val_auc: 0.9761
# Epoch 26/50
# 280/280 - 5s - loss: 0.0874 - tp: 2962.0000 - fp: 323.0000 - tn: 23153.0000 - fn: 437.0000 - accuracy: 0.9717 - precision: 0.9017 - recall: 0.8714 - auc: 0.9828 - val_loss: 0.1234 - val_tp: 667.0000 - val_fp: 115.0000 - val_tn: 5806.0000 - val_fn: 131.0000 - val_accuracy: 0.9634 - val_precision: 0.8529 - val_recall: 0.8358 - val_auc: 0.9759
# Epoch 27/50
# 280/280 - 5s - loss: 0.0875 - tp: 2960.0000 - fp: 336.0000 - tn: 23140.0000 - fn: 439.0000 - accuracy: 0.9712 - precision: 0.8981 - recall: 0.8708 - auc: 0.9824 - val_loss: 0.1223 - val_tp: 629.0000 - val_fp: 96.0000 - val_tn: 5825.0000 - val_fn: 169.0000 - val_accuracy: 0.9606 - val_precision: 0.8676 - val_recall: 0.7882 - val_auc: 0.9720
# Epoch 28/50
# 280/280 - 5s - loss: 0.0850 - tp: 2976.0000 - fp: 321.0000 - tn: 23155.0000 - fn: 423.0000 - accuracy: 0.9723 - precision: 0.9026 - recall: 0.8756 - auc: 0.9834 - val_loss: 0.1245 - val_tp: 677.0000 - val_fp: 132.0000 - val_tn: 5789.0000 - val_fn: 121.0000 - val_accuracy: 0.9623 - val_precision: 0.8368 - val_recall: 0.8484 - val_auc: 0.9770
# Epoch 29/50
# 280/280 - 5s - loss: 0.0849 - tp: 2972.0000 - fp: 327.0000 - tn: 23149.0000 - fn: 427.0000 - accuracy: 0.9719 - precision: 0.9009 - recall: 0.8744 - auc: 0.9833 - val_loss: 0.1231 - val_tp: 673.0000 - val_fp: 133.0000 - val_tn: 5788.0000 - val_fn: 125.0000 - val_accuracy: 0.9616 - val_precision: 0.8350 - val_recall: 0.8434 - val_auc: 0.9772
# Epoch 30/50
# 280/280 - 5s - loss: 0.0830 - tp: 2982.0000 - fp: 310.0000 - tn: 23166.0000 - fn: 417.0000 - accuracy: 0.9729 - precision: 0.9058 - recall: 0.8773 - auc: 0.9836 - val_loss: 0.1220 - val_tp: 664.0000 - val_fp: 115.0000 - val_tn: 5806.0000 - val_fn: 134.0000 - val_accuracy: 0.9629 - val_precision: 0.8524 - val_recall: 0.8321 - val_auc: 0.9769
# Epoch 31/50
# 280/280 - 5s - loss: 0.0819 - tp: 3003.0000 - fp: 307.0000 - tn: 23169.0000 - fn: 396.0000 - accuracy: 0.9738 - precision: 0.9073 - recall: 0.8835 - auc: 0.9839 - val_loss: 0.1297 - val_tp: 600.0000 - val_fp: 69.0000 - val_tn: 5852.0000 - val_fn: 198.0000 - val_accuracy: 0.9603 - val_precision: 0.8969 - val_recall: 0.7519 - val_auc: 0.9688
# Epoch 32/50
# 280/280 - 5s - loss: 0.0814 - tp: 3003.0000 - fp: 303.0000 - tn: 23173.0000 - fn: 396.0000 - accuracy: 0.9740 - precision: 0.9083 - recall: 0.8835 - auc: 0.9847 - val_loss: 0.1240 - val_tp: 681.0000 - val_fp: 148.0000 - val_tn: 5773.0000 - val_fn: 117.0000 - val_accuracy: 0.9606 - val_precision: 0.8215 - val_recall: 0.8534 - val_auc: 0.9762
# Epoch 33/50
# 280/280 - 5s - loss: 0.0793 - tp: 3009.0000 - fp: 297.0000 - tn: 23179.0000 - fn: 390.0000 - accuracy: 0.9744 - precision: 0.9102 - recall: 0.8853 - auc: 0.9853 - val_loss: 0.1237 - val_tp: 645.0000 - val_fp: 103.0000 - val_tn: 5818.0000 - val_fn: 153.0000 - val_accuracy: 0.9619 - val_precision: 0.8623 - val_recall: 0.8083 - val_auc: 0.9750
# Epoch 34/50
# 280/280 - 5s - loss: 0.0776 - tp: 3015.0000 - fp: 290.0000 - tn: 23186.0000 - fn: 384.0000 - accuracy: 0.9749 - precision: 0.9123 - recall: 0.8870 - auc: 0.9857 - val_loss: 0.1217 - val_tp: 652.0000 - val_fp: 105.0000 - val_tn: 5816.0000 - val_fn: 146.0000 - val_accuracy: 0.9626 - val_precision: 0.8613 - val_recall: 0.8170 - val_auc: 0.9746
# Epoch 35/50
# 280/280 - 5s - loss: 0.0759 - tp: 3029.0000 - fp: 286.0000 - tn: 23190.0000 - fn: 370.0000 - accuracy: 0.9756 - precision: 0.9137 - recall: 0.8911 - auc: 0.9861 - val_loss: 0.1234 - val_tp: 649.0000 - val_fp: 100.0000 - val_tn: 5821.0000 - val_fn: 149.0000 - val_accuracy: 0.9629 - val_precision: 0.8665 - val_recall: 0.8133 - val_auc: 0.9744
# Epoch 36/50
# 280/280 - 5s - loss: 0.0753 - tp: 3032.0000 - fp: 259.0000 - tn: 23217.0000 - fn: 367.0000 - accuracy: 0.9767 - precision: 0.9213 - recall: 0.8920 - auc: 0.9863 - val_loss: 0.1274 - val_tp: 693.0000 - val_fp: 152.0000 - val_tn: 5769.0000 - val_fn: 105.0000 - val_accuracy: 0.9618 - val_precision: 0.8201 - val_recall: 0.8684 - val_auc: 0.9759
# Epoch 37/50
# 280/280 - 5s - loss: 0.0737 - tp: 3048.0000 - fp: 261.0000 - tn: 23215.0000 - fn: 351.0000 - accuracy: 0.9772 - precision: 0.9211 - recall: 0.8967 - auc: 0.9871 - val_loss: 0.1236 - val_tp: 683.0000 - val_fp: 145.0000 - val_tn: 5776.0000 - val_fn: 115.0000 - val_accuracy: 0.9613 - val_precision: 0.8249 - val_recall: 0.8559 - val_auc: 0.9749
# Epoch 38/50
# 280/280 - 5s - loss: 0.0723 - tp: 3049.0000 - fp: 249.0000 - tn: 23227.0000 - fn: 350.0000 - accuracy: 0.9777 - precision: 0.9245 - recall: 0.8970 - auc: 0.9873 - val_loss: 0.1290 - val_tp: 698.0000 - val_fp: 180.0000 - val_tn: 5741.0000 - val_fn: 100.0000 - val_accuracy: 0.9583 - val_precision: 0.7950 - val_recall: 0.8747 - val_auc: 0.9750
# Epoch 39/50
# 280/280 - 5s - loss: 0.0736 - tp: 3025.0000 - fp: 272.0000 - tn: 23204.0000 - fn: 374.0000 - accuracy: 0.9760 - precision: 0.9175 - recall: 0.8900 - auc: 0.9873 - val_loss: 0.1158 - val_tp: 672.0000 - val_fp: 130.0000 - val_tn: 5791.0000 - val_fn: 126.0000 - val_accuracy: 0.9619 - val_precision: 0.8379 - val_recall: 0.8421 - val_auc: 0.9747
# Epoch 40/50
# 280/280 - 5s - loss: 0.0695 - tp: 3060.0000 - fp: 236.0000 - tn: 23240.0000 - fn: 339.0000 - accuracy: 0.9786 - precision: 0.9284 - recall: 0.9003 - auc: 0.9881 - val_loss: 0.1377 - val_tp: 702.0000 - val_fp: 212.0000 - val_tn: 5709.0000 - val_fn: 96.0000 - val_accuracy: 0.9542 - val_precision: 0.7681 - val_recall: 0.8797 - val_auc: 0.9739
# Epoch 41/50
# 280/280 - 5s - loss: 0.0682 - tp: 3062.0000 - fp: 228.0000 - tn: 23248.0000 - fn: 337.0000 - accuracy: 0.9790 - precision: 0.9307 - recall: 0.9009 - auc: 0.9886 - val_loss: 0.1168 - val_tp: 662.0000 - val_fp: 113.0000 - val_tn: 5808.0000 - val_fn: 136.0000 - val_accuracy: 0.9629 - val_precision: 0.8542 - val_recall: 0.8296 - val_auc: 0.9736
# Epoch 42/50
# 280/280 - 5s - loss: 0.0671 - tp: 3075.0000 - fp: 226.0000 - tn: 23250.0000 - fn: 324.0000 - accuracy: 0.9795 - precision: 0.9315 - recall: 0.9047 - auc: 0.9886 - val_loss: 0.1153 - val_tp: 662.0000 - val_fp: 124.0000 - val_tn: 5797.0000 - val_fn: 136.0000 - val_accuracy: 0.9613 - val_precision: 0.8422 - val_recall: 0.8296 - val_auc: 0.9735
# Epoch 43/50
# 280/280 - 5s - loss: 0.0650 - tp: 3097.0000 - fp: 205.0000 - tn: 23271.0000 - fn: 302.0000 - accuracy: 0.9811 - precision: 0.9379 - recall: 0.9112 - auc: 0.9893 - val_loss: 0.1144 - val_tp: 614.0000 - val_fp: 81.0000 - val_tn: 5840.0000 - val_fn: 184.0000 - val_accuracy: 0.9606 - val_precision: 0.8835 - val_recall: 0.7694 - val_auc: 0.9716
# Epoch 44/50
# 280/280 - 5s - loss: 0.0638 - tp: 3087.0000 - fp: 216.0000 - tn: 23260.0000 - fn: 312.0000 - accuracy: 0.9804 - precision: 0.9346 - recall: 0.9082 - auc: 0.9897 - val_loss: 0.1131 - val_tp: 636.0000 - val_fp: 100.0000 - val_tn: 5821.0000 - val_fn: 162.0000 - val_accuracy: 0.9610 - val_precision: 0.8641 - val_recall: 0.7970 - val_auc: 0.9714
# Epoch 45/50
# 280/280 - 5s - loss: 0.0638 - tp: 3092.0000 - fp: 220.0000 - tn: 23256.0000 - fn: 307.0000 - accuracy: 0.9804 - precision: 0.9336 - recall: 0.9097 - auc: 0.9897 - val_loss: 0.1103 - val_tp: 648.0000 - val_fp: 101.0000 - val_tn: 5820.0000 - val_fn: 150.0000 - val_accuracy: 0.9626 - val_precision: 0.8652 - val_recall: 0.8120 - val_auc: 0.9723
# Epoch 46/50
# Restoring model weights from the end of the best epoch.
# 280/280 - 5s - loss: 0.0601 - tp: 3117.0000 - fp: 193.0000 - tn: 23283.0000 - fn: 282.0000 - accuracy: 0.9823 - precision: 0.9417 - recall: 0.9170 - auc: 0.9905 - val_loss: 0.1110 - val_tp: 657.0000 - val_fp: 114.0000 - val_tn: 5807.0000 - val_fn: 141.0000 - val_accuracy: 0.9620 - val_precision: 0.8521 - val_recall: 0.8233 - val_auc: 0.9722
# Epoch 00046: early stopping

# %%
model_results(model)
# Out:
# Not Planets Properly Categorized (True Negatives):  5829
# Not Planets Categorized as Planets Detected (False Positives):  92
# Planets Missed (False Negatives):  150
# Planets Properly Categorized (True Positives):  648
# Total Planets:  798
# Accuracy:  0.9639827355261199
# Not Planets Properly Categorized (True Negatives):  5806
# Not Planets Categorized as Planets Detected (False Positives):  115
# Planets Missed (False Negatives):  131
# Planets Properly Categorized (True Positives):  667
# Total Planets:  798
# Accuracy:  0.9633874088406013
# Not Planets Properly Categorized (True Negatives):  5760
# Not Planets Categorized as Planets Detected (False Positives):  161
# Planets Missed (False Negatives):  108
# Planets Properly Categorized (True Positives):  690
# Total Planets:  798
# Accuracy:  0.9599642803988688

# %% [markdown]
# ### LSTM Model

# %%
def make_lstm_model():
    
    input_local = tf.keras.layers.Input(shape=[x_local_train.shape[1],1])
    input_global=tf.keras.layers.Input(shape=[x_global_train.shape[1],1])
    
    k_global=tf.keras.layers.LSTM(128)(input_global)
    k_local=tf.keras.layers.LSTM(128)(input_local)
     
    #flatten and concatenate
    #k_global=tf.keras.layers.Flatten()(k_global)
    #k_local=tf.keras.layers.Flatten()(k_local)
    k = tf.keras.layers.concatenate([k_local, k_global])
    
    #dense layers
    k=tf.keras.layers.Dense(256,activation='relu')(k)
    k=tf.keras.layers.Dropout(0.5)(k)
    k=tf.keras.layers.Dense(256,activation='relu')(k)
    
    
    #output layer        
    output=tf.keras.layers.Dense(1,activation='sigmoid')(k)

    model=tf.keras.Model(inputs=[input_local,input_global],outputs=output)

    learning_rate=1e-3
    
    model.compile(loss=tf.keras.losses.BinaryCrossentropy()
                  ,optimizer=tf.keras.optimizers.Adam(learning_rate),
                  metrics=METRICS)
    return model

# %%
EPOCHS=25
BATCH_SIZE=128

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy', 
    verbose=1,
    patience=20,
    mode='max',
    restore_best_weights=True)

model=make_lstm_model()

tf.keras.backend.clear_session()
history=model.fit([x_local_train,x_global_train],
                  Y_train,
                  validation_data=([x_local_val,x_global_val],Y_val),
                  epochs=EPOCHS,
                  batch_size=BATCH_SIZE,
                  callbacks=[early_stopping],
                  verbose=2)
# Out:
# Epoch 1/25
# 210/210 - 27s - loss: 0.3239 - tp: 555.0000 - fp: 233.0000 - tn: 29164.0000 - fn: 3642.0000 - accuracy: 0.8847 - precision: 0.7043 - recall: 0.1322 - auc: 0.8325 - val_loss: 0.2591 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 5921.0000 - val_fn: 798.0000 - val_accuracy: 0.8812 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8609
# Epoch 2/25
# 210/210 - 26s - loss: 0.2684 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 23476.0000 - fn: 3399.0000 - accuracy: 0.8735 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.8682 - val_loss: 0.2421 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 5921.0000 - val_fn: 798.0000 - val_accuracy: 0.8812 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8807
# Epoch 3/25
# 210/210 - 27s - loss: 0.2677 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 23476.0000 - fn: 3399.0000 - accuracy: 0.8735 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.8697 - val_loss: 0.2477 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 5921.0000 - val_fn: 798.0000 - val_accuracy: 0.8812 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8756
# Epoch 4/25
# 210/210 - 27s - loss: 0.2563 - tp: 184.0000 - fp: 170.0000 - tn: 23306.0000 - fn: 3215.0000 - accuracy: 0.8740 - precision: 0.5198 - recall: 0.0541 - auc: 0.8818 - val_loss: 0.2389 - val_tp: 7.0000 - val_fp: 45.0000 - val_tn: 5876.0000 - val_fn: 791.0000 - val_accuracy: 0.8756 - val_precision: 0.1346 - val_recall: 0.0088 - val_auc: 0.8958
# Epoch 5/25
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-116-bc7578652287> in <module>
#      18                   batch_size=BATCH_SIZE,
#      19                   callbacks=[early_stopping],
# ---> 20                   verbose=2)
#
# ~/anaconda3/envs/thesis/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~/anaconda3/envs/thesis/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# ~/anaconda3/envs/thesis/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~/anaconda3/envs/thesis/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/envs/thesis/lib/python3.6/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~/anaconda3/envs/thesis/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/anaconda3/envs/thesis/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# ~/anaconda3/envs/thesis/lib/python3.6/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# ~/anaconda3/envs/thesis/lib/python3.6/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
model_results(model)
# Out:
# Not Planets Properly Categorized (True Negatives):  5856
# Not Planets Categorized as Planets Detected (False Positives):  65
# Planets Missed (False Negatives):  367
# Planets Properly Categorized (True Positives):  431
# Total Planets:  798
# Accuracy:  0.9357047179639827
# Not Planets Properly Categorized (True Negatives):  5775
# Not Planets Categorized as Planets Detected (False Positives):  146
# Planets Missed (False Negatives):  251
# Planets Properly Categorized (True Positives):  547
# Total Planets:  798
# Accuracy:  0.9409138264622712
# Not Planets Properly Categorized (True Negatives):  5699
# Not Planets Categorized as Planets Detected (False Positives):  222
# Planets Missed (False Negatives):  187
# Planets Properly Categorized (True Positives):  611
# Total Planets:  798
# Accuracy:  0.9391278464057151

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 201, 1)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 2001, 1)]    0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 128)          66560       input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 128)          66560       input_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 256)          0           lstm_1[0][0]
#                                                                  lstm[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          65792       concatenate[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          65792       dropout[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            257         dense_1[0][0]
# ==================================================================================================
# Total params: 264,961
# Trainable params: 264,961
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### CNN_LSTM

# %%
def make_cnn_lstm_model():
    
    input_local = tf.keras.layers.Input(shape=[x_local_train.shape[1],1])
    input_global=tf.keras.layers.Input(shape=[x_global_train.shape[1],1])
    
    
    k_global=tf.keras.layers.Conv1D(filters=16,kernel_size=5,activation='relu')(input_global)
    k_global=tf.keras.layers.MaxPooling1D(pool_size=5,strides=2,padding='same')(k_global)
    k_global=tf.keras.layers.Conv1D(filters=32,kernel_size=5,activation='relu')(k_global)
    k_global=tf.keras.layers.MaxPooling1D(pool_size=5,strides=2,padding='same')(k_global)    
    k_global=tf.keras.layers.Conv1D(filters=64,kernel_size=5,activation='relu')(k_global)
    k_global=tf.keras.layers.MaxPooling1D(pool_size=5,strides=2,padding='same')(k_global)    
    
    
    k_local=tf.keras.layers.Conv1D(filters=16,kernel_size=5,activation='relu')(input_local)
    k_local=tf.keras.layers.MaxPooling1D(pool_size=7,strides=2,padding='same')(k_local)
    k_local=tf.keras.layers.Conv1D(filters=32,kernel_size=5,activation='relu')(k_local)
    k_local=tf.keras.layers.MaxPooling1D(pool_size=7,strides=2,padding='same')(k_local)
    
    
       
    #LSTM
    k_global=tf.keras.layers.LSTM(256)(k_global)
    k_local=tf.keras.layers.LSTM(256)(k_local)
    
    #concatenate
    k =tf.keras.layers.concatenate([k_local, k_global])
    
    
    #dense layers
    k=tf.keras.layers.Dense(512,activation='relu')(k)
    k=tf.keras.layers.Dropout(0.4)(k)
    k=tf.keras.layers.Dense(512,activation='relu')(k)
    k=tf.keras.layers.Dropout(0.4)(k)
    k=tf.keras.layers.Dense(512,activation='relu')(k)
    k=tf.keras.layers.Dropout(0.4)(k)
    k=tf.keras.layers.Dense(512,activation='relu')(k)
    
    
    #output layer        
    output=tf.keras.layers.Dense(1,activation='sigmoid')(k)

    model=tf.keras.Model(inputs=[input_local,input_global],outputs=output)

    learning_rate=1e-5
    
    model.compile(loss=tf.keras.losses.BinaryCrossentropy()
                  ,optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
                  metrics=METRICS)
    return model

# %%
EPOCHS=200
BATCH_SIZE=96

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy', 
    verbose=1,
    patience=15,
    mode='max',
    restore_best_weights=True)

model=make_cnn_lstm_model()
print(model.summary())

tf.keras.backend.clear_session()
history=model.fit([x_local_train,x_global_train],
                  Y_train,
                  validation_data=([x_local_val,x_global_val],Y_val),
                  epochs=EPOCHS,
                  batch_size=BATCH_SIZE,
                  callbacks=[early_stopping],
                  verbose=2)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 2001, 1)]    0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 1997, 16)     96          input_2[0][0]
# __________________________________________________________________________________________________
# input_1 (InputLayer)            [(None, 201, 1)]     0
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 999, 16)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 197, 16)      96          input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 995, 32)      2592        max_pooling1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 99, 16)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 498, 32)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 95, 32)       2592        max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 494, 64)      10304       max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 48, 32)       0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 247, 64)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 256)          295936      max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 256)          328704      max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 512)          0           lstm_1[0][0]
#                                                                  lstm[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          262656      concatenate[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          262656      dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          262656      dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 512)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 512)          262656      dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            513         dense_3[0][0]
# ==================================================================================================
# Total params: 1,691,457
# Trainable params: 1,691,457
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/200
# 280/280 - 14s - loss: 0.4569 - tp: 658.0000 - fp: 230.0000 - tn: 29167.0000 - fn: 3539.0000 - accuracy: 0.8878 - precision: 0.7410 - recall: 0.1568 - auc: 0.7141 - val_loss: 0.3022 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 5921.0000 - val_fn: 798.0000 - val_accuracy: 0.8812 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8282
# Epoch 2/200
# 280/280 - 13s - loss: 0.3023 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 23476.0000 - fn: 3399.0000 - accuracy: 0.8735 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.8229 - val_loss: 0.2773 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 5921.0000 - val_fn: 798.0000 - val_accuracy: 0.8812 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8420
# Epoch 3/200
# 280/280 - 13s - loss: 0.2848 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 23476.0000 - fn: 3399.0000 - accuracy: 0.8735 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.8364 - val_loss: 0.2638 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 5921.0000 - val_fn: 798.0000 - val_accuracy: 0.8812 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8455
# Epoch 4/200
# 280/280 - 13s - loss: 0.2745 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 23476.0000 - fn: 3399.0000 - accuracy: 0.8735 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.8463 - val_loss: 0.2561 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 5921.0000 - val_fn: 798.0000 - val_accuracy: 0.8812 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8617
# Epoch 5/200
# 280/280 - 13s - loss: 0.2628 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 23476.0000 - fn: 3399.0000 - accuracy: 0.8735 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.8734 - val_loss: 0.2470 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 5921.0000 - val_fn: 798.0000 - val_accuracy: 0.8812 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8971
# Epoch 6/200
# 280/280 - 13s - loss: 0.2445 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 23476.0000 - fn: 3399.0000 - accuracy: 0.8735 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.9018 - val_loss: 0.2278 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 5921.0000 - val_fn: 798.0000 - val_accuracy: 0.8812 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.9076
# Epoch 7/200
# 280/280 - 13s - loss: 0.2351 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 23476.0000 - fn: 3399.0000 - accuracy: 0.8735 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.9085 - val_loss: 0.2195 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 5921.0000 - val_fn: 798.0000 - val_accuracy: 0.8812 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.9140
# Epoch 8/200
# 280/280 - 13s - loss: 0.2296 - tp: 5.0000 - fp: 0.0000e+00 - tn: 23476.0000 - fn: 3394.0000 - accuracy: 0.8737 - precision: 1.0000 - recall: 0.0015 - auc: 0.9133 - val_loss: 0.2209 - val_tp: 361.0000 - val_fp: 269.0000 - val_tn: 5652.0000 - val_fn: 437.0000 - val_accuracy: 0.8949 - val_precision: 0.5730 - val_recall: 0.4524 - val_auc: 0.9173
# Epoch 9/200
# 280/280 - 13s - loss: 0.2269 - tp: 109.0000 - fp: 54.0000 - tn: 23422.0000 - fn: 3290.0000 - accuracy: 0.8756 - precision: 0.6687 - recall: 0.0321 - auc: 0.9164 - val_loss: 0.2125 - val_tp: 292.0000 - val_fp: 210.0000 - val_tn: 5711.0000 - val_fn: 506.0000 - val_accuracy: 0.8934 - val_precision: 0.5817 - val_recall: 0.3659 - val_auc: 0.9197
# Epoch 10/200
# 280/280 - 13s - loss: 0.2232 - tp: 695.0000 - fp: 333.0000 - tn: 23143.0000 - fn: 2704.0000 - accuracy: 0.8870 - precision: 0.6761 - recall: 0.2045 - auc: 0.9206 - val_loss: 0.2135 - val_tp: 454.0000 - val_fp: 288.0000 - val_tn: 5633.0000 - val_fn: 344.0000 - val_accuracy: 0.9059 - val_precision: 0.6119 - val_recall: 0.5689 - val_auc: 0.9235
# Epoch 11/200
# 280/280 - 13s - loss: 0.2206 - tp: 1350.0000 - fp: 641.0000 - tn: 22835.0000 - fn: 2049.0000 - accuracy: 0.8999 - precision: 0.6781 - recall: 0.3972 - auc: 0.9224 - val_loss: 0.2090 - val_tp: 409.0000 - val_fp: 230.0000 - val_tn: 5691.0000 - val_fn: 389.0000 - val_accuracy: 0.9079 - val_precision: 0.6401 - val_recall: 0.5125 - val_auc: 0.9250
# Epoch 12/200
# 280/280 - 13s - loss: 0.2187 - tp: 1656.0000 - fp: 781.0000 - tn: 22695.0000 - fn: 1743.0000 - accuracy: 0.9061 - precision: 0.6795 - recall: 0.4872 - auc: 0.9246 - val_loss: 0.2053 - val_tp: 412.0000 - val_fp: 211.0000 - val_tn: 5710.0000 - val_fn: 386.0000 - val_accuracy: 0.9111 - val_precision: 0.6613 - val_recall: 0.5163 - val_auc: 0.9273
# Epoch 13/200
# 280/280 - 13s - loss: 0.2137 - tp: 1753.0000 - fp: 749.0000 - tn: 22727.0000 - fn: 1646.0000 - accuracy: 0.9109 - precision: 0.7006 - recall: 0.5157 - auc: 0.9287 - val_loss: 0.2059 - val_tp: 517.0000 - val_fp: 266.0000 - val_tn: 5655.0000 - val_fn: 281.0000 - val_accuracy: 0.9186 - val_precision: 0.6603 - val_recall: 0.6479 - val_auc: 0.9295
# Epoch 14/200
# 280/280 - 13s - loss: 0.2126 - tp: 1962.0000 - fp: 867.0000 - tn: 22609.0000 - fn: 1437.0000 - accuracy: 0.9143 - precision: 0.6935 - recall: 0.5772 - auc: 0.9279 - val_loss: 0.1999 - val_tp: 485.0000 - val_fp: 212.0000 - val_tn: 5709.0000 - val_fn: 313.0000 - val_accuracy: 0.9219 - val_precision: 0.6958 - val_recall: 0.6078 - val_auc: 0.9311
# Epoch 15/200
# 280/280 - 13s - loss: 0.2083 - tp: 2050.0000 - fp: 895.0000 - tn: 22581.0000 - fn: 1349.0000 - accuracy: 0.9165 - precision: 0.6961 - recall: 0.6031 - auc: 0.9313 - val_loss: 0.1966 - val_tp: 531.0000 - val_fp: 250.0000 - val_tn: 5671.0000 - val_fn: 267.0000 - val_accuracy: 0.9231 - val_precision: 0.6799 - val_recall: 0.6654 - val_auc: 0.9330
# Epoch 16/200
# 280/280 - 13s - loss: 0.2059 - tp: 2117.0000 - fp: 960.0000 - tn: 22516.0000 - fn: 1282.0000 - accuracy: 0.9166 - precision: 0.6880 - recall: 0.6228 - auc: 0.9305 - val_loss: 0.2019 - val_tp: 581.0000 - val_fp: 369.0000 - val_tn: 5552.0000 - val_fn: 217.0000 - val_accuracy: 0.9128 - val_precision: 0.6116 - val_recall: 0.7281 - val_auc: 0.9311
# Epoch 17/200
# 280/280 - 13s - loss: 0.2038 - tp: 2144.0000 - fp: 968.0000 - tn: 22508.0000 - fn: 1255.0000 - accuracy: 0.9173 - precision: 0.6889 - recall: 0.6308 - auc: 0.9313 - val_loss: 0.1936 - val_tp: 549.0000 - val_fp: 270.0000 - val_tn: 5651.0000 - val_fn: 249.0000 - val_accuracy: 0.9228 - val_precision: 0.6703 - val_recall: 0.6880 - val_auc: 0.9368
# Epoch 18/200
# 280/280 - 13s - loss: 0.2009 - tp: 2181.0000 - fp: 939.0000 - tn: 22537.0000 - fn: 1218.0000 - accuracy: 0.9197 - precision: 0.6990 - recall: 0.6417 - auc: 0.9323 - val_loss: 0.1915 - val_tp: 563.0000 - val_fp: 291.0000 - val_tn: 5630.0000 - val_fn: 235.0000 - val_accuracy: 0.9217 - val_precision: 0.6593 - val_recall: 0.7055 - val_auc: 0.9366
# Epoch 19/200
# 280/280 - 13s - loss: 0.1988 - tp: 2192.0000 - fp: 917.0000 - tn: 22559.0000 - fn: 1207.0000 - accuracy: 0.9210 - precision: 0.7050 - recall: 0.6449 - auc: 0.9329 - val_loss: 0.1851 - val_tp: 517.0000 - val_fp: 206.0000 - val_tn: 5715.0000 - val_fn: 281.0000 - val_accuracy: 0.9275 - val_precision: 0.7151 - val_recall: 0.6479 - val_auc: 0.9398
# Epoch 20/200
# 280/280 - 13s - loss: 0.1976 - tp: 2181.0000 - fp: 930.0000 - tn: 22546.0000 - fn: 1218.0000 - accuracy: 0.9201 - precision: 0.7011 - recall: 0.6417 - auc: 0.9338 - val_loss: 0.1825 - val_tp: 505.0000 - val_fp: 179.0000 - val_tn: 5742.0000 - val_fn: 293.0000 - val_accuracy: 0.9298 - val_precision: 0.7383 - val_recall: 0.6328 - val_auc: 0.9407
# Epoch 21/200
# 280/280 - 13s - loss: 0.1948 - tp: 2187.0000 - fp: 881.0000 - tn: 22595.0000 - fn: 1212.0000 - accuracy: 0.9221 - precision: 0.7128 - recall: 0.6434 - auc: 0.9350 - val_loss: 0.1807 - val_tp: 522.0000 - val_fp: 194.0000 - val_tn: 5727.0000 - val_fn: 276.0000 - val_accuracy: 0.9300 - val_precision: 0.7291 - val_recall: 0.6541 - val_auc: 0.9410
# Epoch 22/200
# 280/280 - 13s - loss: 0.1935 - tp: 2192.0000 - fp: 855.0000 - tn: 22621.0000 - fn: 1207.0000 - accuracy: 0.9233 - precision: 0.7194 - recall: 0.6449 - auc: 0.9363 - val_loss: 0.1803 - val_tp: 547.0000 - val_fp: 221.0000 - val_tn: 5700.0000 - val_fn: 251.0000 - val_accuracy: 0.9298 - val_precision: 0.7122 - val_recall: 0.6855 - val_auc: 0.9425
# Epoch 23/200
# 280/280 - 13s - loss: 0.1912 - tp: 2225.0000 - fp: 863.0000 - tn: 22613.0000 - fn: 1174.0000 - accuracy: 0.9242 - precision: 0.7205 - recall: 0.6546 - auc: 0.9381 - val_loss: 0.1776 - val_tp: 459.0000 - val_fp: 133.0000 - val_tn: 5788.0000 - val_fn: 339.0000 - val_accuracy: 0.9298 - val_precision: 0.7753 - val_recall: 0.5752 - val_auc: 0.9441
# Epoch 24/200
# 280/280 - 13s - loss: 0.1890 - tp: 2236.0000 - fp: 841.0000 - tn: 22635.0000 - fn: 1163.0000 - accuracy: 0.9254 - precision: 0.7267 - recall: 0.6578 - auc: 0.9387 - val_loss: 0.1765 - val_tp: 561.0000 - val_fp: 218.0000 - val_tn: 5703.0000 - val_fn: 237.0000 - val_accuracy: 0.9323 - val_precision: 0.7202 - val_recall: 0.7030 - val_auc: 0.9441
# Epoch 25/200
# 280/280 - 13s - loss: 0.1874 - tp: 2220.0000 - fp: 819.0000 - tn: 22657.0000 - fn: 1179.0000 - accuracy: 0.9257 - precision: 0.7305 - recall: 0.6531 - auc: 0.9398 - val_loss: 0.1744 - val_tp: 563.0000 - val_fp: 217.0000 - val_tn: 5704.0000 - val_fn: 235.0000 - val_accuracy: 0.9327 - val_precision: 0.7218 - val_recall: 0.7055 - val_auc: 0.9460
# Epoch 26/200
# 280/280 - 13s - loss: 0.1854 - tp: 2245.0000 - fp: 789.0000 - tn: 22687.0000 - fn: 1154.0000 - accuracy: 0.9277 - precision: 0.7399 - recall: 0.6605 - auc: 0.9408 - val_loss: 0.1732 - val_tp: 578.0000 - val_fp: 232.0000 - val_tn: 5689.0000 - val_fn: 220.0000 - val_accuracy: 0.9327 - val_precision: 0.7136 - val_recall: 0.7243 - val_auc: 0.9476
# Epoch 27/200
# 280/280 - 13s - loss: 0.1832 - tp: 2260.0000 - fp: 779.0000 - tn: 22697.0000 - fn: 1139.0000 - accuracy: 0.9286 - precision: 0.7437 - recall: 0.6649 - auc: 0.9426 - val_loss: 0.1737 - val_tp: 577.0000 - val_fp: 234.0000 - val_tn: 5687.0000 - val_fn: 221.0000 - val_accuracy: 0.9323 - val_precision: 0.7115 - val_recall: 0.7231 - val_auc: 0.9479
# Epoch 28/200
# 280/280 - 13s - loss: 0.1815 - tp: 2274.0000 - fp: 783.0000 - tn: 22693.0000 - fn: 1125.0000 - accuracy: 0.9290 - precision: 0.7439 - recall: 0.6690 - auc: 0.9434 - val_loss: 0.1683 - val_tp: 567.0000 - val_fp: 204.0000 - val_tn: 5717.0000 - val_fn: 231.0000 - val_accuracy: 0.9353 - val_precision: 0.7354 - val_recall: 0.7105 - val_auc: 0.9496
# Epoch 29/200
# 280/280 - 13s - loss: 0.1784 - tp: 2290.0000 - fp: 772.0000 - tn: 22704.0000 - fn: 1109.0000 - accuracy: 0.9300 - precision: 0.7479 - recall: 0.6737 - auc: 0.9453 - val_loss: 0.1644 - val_tp: 510.0000 - val_fp: 141.0000 - val_tn: 5780.0000 - val_fn: 288.0000 - val_accuracy: 0.9362 - val_precision: 0.7834 - val_recall: 0.6391 - val_auc: 0.9516
# Epoch 30/200
# 280/280 - 13s - loss: 0.1778 - tp: 2283.0000 - fp: 742.0000 - tn: 22734.0000 - fn: 1116.0000 - accuracy: 0.9309 - precision: 0.7547 - recall: 0.6717 - auc: 0.9455 - val_loss: 0.1699 - val_tp: 599.0000 - val_fp: 235.0000 - val_tn: 5686.0000 - val_fn: 199.0000 - val_accuracy: 0.9354 - val_precision: 0.7182 - val_recall: 0.7506 - val_auc: 0.9527
# Epoch 31/200
# 280/280 - 13s - loss: 0.1780 - tp: 2266.0000 - fp: 755.0000 - tn: 22721.0000 - fn: 1133.0000 - accuracy: 0.9297 - precision: 0.7501 - recall: 0.6667 - auc: 0.9460 - val_loss: 0.1657 - val_tp: 588.0000 - val_fp: 220.0000 - val_tn: 5701.0000 - val_fn: 210.0000 - val_accuracy: 0.9360 - val_precision: 0.7277 - val_recall: 0.7368 - val_auc: 0.9525
# Epoch 32/200
# 280/280 - 13s - loss: 0.1761 - tp: 2310.0000 - fp: 739.0000 - tn: 22737.0000 - fn: 1089.0000 - accuracy: 0.9320 - precision: 0.7576 - recall: 0.6796 - auc: 0.9465 - val_loss: 0.1588 - val_tp: 555.0000 - val_fp: 162.0000 - val_tn: 5759.0000 - val_fn: 243.0000 - val_accuracy: 0.9397 - val_precision: 0.7741 - val_recall: 0.6955 - val_auc: 0.9537
# Epoch 33/200
# 280/280 - 13s - loss: 0.1726 - tp: 2330.0000 - fp: 722.0000 - tn: 22754.0000 - fn: 1069.0000 - accuracy: 0.9334 - precision: 0.7634 - recall: 0.6855 - auc: 0.9490 - val_loss: 0.1585 - val_tp: 534.0000 - val_fp: 152.0000 - val_tn: 5769.0000 - val_fn: 264.0000 - val_accuracy: 0.9381 - val_precision: 0.7784 - val_recall: 0.6692 - val_auc: 0.9545
# Epoch 34/200
# 280/280 - 13s - loss: 0.1719 - tp: 2331.0000 - fp: 698.0000 - tn: 22778.0000 - fn: 1068.0000 - accuracy: 0.9343 - precision: 0.7696 - recall: 0.6858 - auc: 0.9494 - val_loss: 0.1572 - val_tp: 568.0000 - val_fp: 175.0000 - val_tn: 5746.0000 - val_fn: 230.0000 - val_accuracy: 0.9397 - val_precision: 0.7645 - val_recall: 0.7118 - val_auc: 0.9555
# Epoch 35/200
# 280/280 - 13s - loss: 0.1708 - tp: 2348.0000 - fp: 703.0000 - tn: 22773.0000 - fn: 1051.0000 - accuracy: 0.9347 - precision: 0.7696 - recall: 0.6908 - auc: 0.9496 - val_loss: 0.1629 - val_tp: 606.0000 - val_fp: 226.0000 - val_tn: 5695.0000 - val_fn: 192.0000 - val_accuracy: 0.9378 - val_precision: 0.7284 - val_recall: 0.7594 - val_auc: 0.9553
# Epoch 36/200
# 280/280 - 13s - loss: 0.1686 - tp: 2340.0000 - fp: 693.0000 - tn: 22783.0000 - fn: 1059.0000 - accuracy: 0.9348 - precision: 0.7715 - recall: 0.6884 - auc: 0.9515 - val_loss: 0.1556 - val_tp: 557.0000 - val_fp: 140.0000 - val_tn: 5781.0000 - val_fn: 241.0000 - val_accuracy: 0.9433 - val_precision: 0.7991 - val_recall: 0.6980 - val_auc: 0.9580
# Epoch 37/200
# 280/280 - 13s - loss: 0.1675 - tp: 2347.0000 - fp: 692.0000 - tn: 22784.0000 - fn: 1052.0000 - accuracy: 0.9351 - precision: 0.7723 - recall: 0.6905 - auc: 0.9522 - val_loss: 0.1592 - val_tp: 609.0000 - val_fp: 226.0000 - val_tn: 5695.0000 - val_fn: 189.0000 - val_accuracy: 0.9382 - val_precision: 0.7293 - val_recall: 0.7632 - val_auc: 0.9568
# Epoch 38/200
# 280/280 - 13s - loss: 0.1677 - tp: 2353.0000 - fp: 681.0000 - tn: 22795.0000 - fn: 1046.0000 - accuracy: 0.9357 - precision: 0.7755 - recall: 0.6923 - auc: 0.9514 - val_loss: 0.1525 - val_tp: 586.0000 - val_fp: 182.0000 - val_tn: 5739.0000 - val_fn: 212.0000 - val_accuracy: 0.9414 - val_precision: 0.7630 - val_recall: 0.7343 - val_auc: 0.9584
# Epoch 39/200
# 280/280 - 13s - loss: 0.1657 - tp: 2347.0000 - fp: 679.0000 - tn: 22797.0000 - fn: 1052.0000 - accuracy: 0.9356 - precision: 0.7756 - recall: 0.6905 - auc: 0.9526 - val_loss: 0.1524 - val_tp: 595.0000 - val_fp: 192.0000 - val_tn: 5729.0000 - val_fn: 203.0000 - val_accuracy: 0.9412 - val_precision: 0.7560 - val_recall: 0.7456 - val_auc: 0.9595
# Epoch 40/200
# 280/280 - 13s - loss: 0.1642 - tp: 2368.0000 - fp: 653.0000 - tn: 22823.0000 - fn: 1031.0000 - accuracy: 0.9373 - precision: 0.7838 - recall: 0.6967 - auc: 0.9538 - val_loss: 0.1494 - val_tp: 589.0000 - val_fp: 173.0000 - val_tn: 5748.0000 - val_fn: 209.0000 - val_accuracy: 0.9431 - val_precision: 0.7730 - val_recall: 0.7381 - val_auc: 0.9601
# Epoch 41/200
# 280/280 - 13s - loss: 0.1631 - tp: 2378.0000 - fp: 663.0000 - tn: 22813.0000 - fn: 1021.0000 - accuracy: 0.9373 - precision: 0.7820 - recall: 0.6996 - auc: 0.9538 - val_loss: 0.1480 - val_tp: 561.0000 - val_fp: 154.0000 - val_tn: 5767.0000 - val_fn: 237.0000 - val_accuracy: 0.9418 - val_precision: 0.7846 - val_recall: 0.7030 - val_auc: 0.9603
# Epoch 42/200
# 280/280 - 13s - loss: 0.1616 - tp: 2381.0000 - fp: 637.0000 - tn: 22839.0000 - fn: 1018.0000 - accuracy: 0.9384 - precision: 0.7889 - recall: 0.7005 - auc: 0.9544 - val_loss: 0.1462 - val_tp: 525.0000 - val_fp: 97.0000 - val_tn: 5824.0000 - val_fn: 273.0000 - val_accuracy: 0.9449 - val_precision: 0.8441 - val_recall: 0.6579 - val_auc: 0.9615
# Epoch 43/200
# 280/280 - 13s - loss: 0.1607 - tp: 2399.0000 - fp: 641.0000 - tn: 22835.0000 - fn: 1000.0000 - accuracy: 0.9389 - precision: 0.7891 - recall: 0.7058 - auc: 0.9549 - val_loss: 0.1483 - val_tp: 590.0000 - val_fp: 183.0000 - val_tn: 5738.0000 - val_fn: 208.0000 - val_accuracy: 0.9418 - val_precision: 0.7633 - val_recall: 0.7393 - val_auc: 0.9614
# Epoch 44/200
# 280/280 - 13s - loss: 0.1606 - tp: 2381.0000 - fp: 652.0000 - tn: 22824.0000 - fn: 1018.0000 - accuracy: 0.9379 - precision: 0.7850 - recall: 0.7005 - auc: 0.9553 - val_loss: 0.1759 - val_tp: 658.0000 - val_fp: 307.0000 - val_tn: 5614.0000 - val_fn: 140.0000 - val_accuracy: 0.9335 - val_precision: 0.6819 - val_recall: 0.8246 - val_auc: 0.9581
# Epoch 45/200
# 280/280 - 13s - loss: 0.1584 - tp: 2417.0000 - fp: 655.0000 - tn: 22821.0000 - fn: 982.0000 - accuracy: 0.9391 - precision: 0.7868 - recall: 0.7111 - auc: 0.9565 - val_loss: 0.1420 - val_tp: 537.0000 - val_fp: 105.0000 - val_tn: 5816.0000 - val_fn: 261.0000 - val_accuracy: 0.9455 - val_precision: 0.8364 - val_recall: 0.6729 - val_auc: 0.9629
# Epoch 46/200
# 280/280 - 13s - loss: 0.1584 - tp: 2384.0000 - fp: 617.0000 - tn: 22859.0000 - fn: 1015.0000 - accuracy: 0.9393 - precision: 0.7944 - recall: 0.7014 - auc: 0.9563 - val_loss: 0.1409 - val_tp: 586.0000 - val_fp: 141.0000 - val_tn: 5780.0000 - val_fn: 212.0000 - val_accuracy: 0.9475 - val_precision: 0.8061 - val_recall: 0.7343 - val_auc: 0.9635
# Epoch 47/200
# 280/280 - 13s - loss: 0.1569 - tp: 2399.0000 - fp: 620.0000 - tn: 22856.0000 - fn: 1000.0000 - accuracy: 0.9397 - precision: 0.7946 - recall: 0.7058 - auc: 0.9577 - val_loss: 0.1448 - val_tp: 620.0000 - val_fp: 190.0000 - val_tn: 5731.0000 - val_fn: 178.0000 - val_accuracy: 0.9452 - val_precision: 0.7654 - val_recall: 0.7769 - val_auc: 0.9643
# Epoch 48/200
# 280/280 - 13s - loss: 0.1560 - tp: 2438.0000 - fp: 637.0000 - tn: 22839.0000 - fn: 961.0000 - accuracy: 0.9405 - precision: 0.7928 - recall: 0.7173 - auc: 0.9569 - val_loss: 0.1419 - val_tp: 592.0000 - val_fp: 161.0000 - val_tn: 5760.0000 - val_fn: 206.0000 - val_accuracy: 0.9454 - val_precision: 0.7862 - val_recall: 0.7419 - val_auc: 0.9639
# Epoch 49/200
# 280/280 - 13s - loss: 0.1550 - tp: 2420.0000 - fp: 597.0000 - tn: 22879.0000 - fn: 979.0000 - accuracy: 0.9414 - precision: 0.8021 - recall: 0.7120 - auc: 0.9578 - val_loss: 0.1445 - val_tp: 608.0000 - val_fp: 193.0000 - val_tn: 5728.0000 - val_fn: 190.0000 - val_accuracy: 0.9430 - val_precision: 0.7591 - val_recall: 0.7619 - val_auc: 0.9640
# Epoch 50/200
# 280/280 - 13s - loss: 0.1522 - tp: 2444.0000 - fp: 625.0000 - tn: 22851.0000 - fn: 955.0000 - accuracy: 0.9412 - precision: 0.7964 - recall: 0.7190 - auc: 0.9588 - val_loss: 0.1382 - val_tp: 585.0000 - val_fp: 152.0000 - val_tn: 5769.0000 - val_fn: 213.0000 - val_accuracy: 0.9457 - val_precision: 0.7938 - val_recall: 0.7331 - val_auc: 0.9653
# Epoch 51/200
# 280/280 - 13s - loss: 0.1531 - tp: 2453.0000 - fp: 626.0000 - tn: 22850.0000 - fn: 946.0000 - accuracy: 0.9415 - precision: 0.7967 - recall: 0.7217 - auc: 0.9581 - val_loss: 0.1402 - val_tp: 586.0000 - val_fp: 164.0000 - val_tn: 5757.0000 - val_fn: 212.0000 - val_accuracy: 0.9440 - val_precision: 0.7813 - val_recall: 0.7343 - val_auc: 0.9644
# Epoch 52/200
# 280/280 - 13s - loss: 0.1507 - tp: 2465.0000 - fp: 611.0000 - tn: 22865.0000 - fn: 934.0000 - accuracy: 0.9425 - precision: 0.8014 - recall: 0.7252 - auc: 0.9602 - val_loss: 0.1402 - val_tp: 629.0000 - val_fp: 185.0000 - val_tn: 5736.0000 - val_fn: 169.0000 - val_accuracy: 0.9473 - val_precision: 0.7727 - val_recall: 0.7882 - val_auc: 0.9652
# Epoch 53/200
# 280/280 - 13s - loss: 0.1504 - tp: 2474.0000 - fp: 599.0000 - tn: 22877.0000 - fn: 925.0000 - accuracy: 0.9433 - precision: 0.8051 - recall: 0.7279 - auc: 0.9598 - val_loss: 0.1382 - val_tp: 619.0000 - val_fp: 171.0000 - val_tn: 5750.0000 - val_fn: 179.0000 - val_accuracy: 0.9479 - val_precision: 0.7835 - val_recall: 0.7757 - val_auc: 0.9661
# Epoch 54/200
# 280/280 - 13s - loss: 0.1499 - tp: 2465.0000 - fp: 613.0000 - tn: 22863.0000 - fn: 934.0000 - accuracy: 0.9424 - precision: 0.8008 - recall: 0.7252 - auc: 0.9600 - val_loss: 0.1403 - val_tp: 604.0000 - val_fp: 190.0000 - val_tn: 5731.0000 - val_fn: 194.0000 - val_accuracy: 0.9428 - val_precision: 0.7607 - val_recall: 0.7569 - val_auc: 0.9649
# Epoch 55/200
# 280/280 - 13s - loss: 0.1498 - tp: 2485.0000 - fp: 633.0000 - tn: 22843.0000 - fn: 914.0000 - accuracy: 0.9424 - precision: 0.7970 - recall: 0.7311 - auc: 0.9607 - val_loss: 0.1400 - val_tp: 606.0000 - val_fp: 187.0000 - val_tn: 5734.0000 - val_fn: 192.0000 - val_accuracy: 0.9436 - val_precision: 0.7642 - val_recall: 0.7594 - val_auc: 0.9659
# Epoch 56/200
# 280/280 - 13s - loss: 0.1479 - tp: 2477.0000 - fp: 616.0000 - tn: 22860.0000 - fn: 922.0000 - accuracy: 0.9428 - precision: 0.8008 - recall: 0.7287 - auc: 0.9619 - val_loss: 0.1340 - val_tp: 585.0000 - val_fp: 129.0000 - val_tn: 5792.0000 - val_fn: 213.0000 - val_accuracy: 0.9491 - val_precision: 0.8193 - val_recall: 0.7331 - val_auc: 0.9670
# Epoch 57/200
# 280/280 - 13s - loss: 0.1470 - tp: 2480.0000 - fp: 602.0000 - tn: 22874.0000 - fn: 919.0000 - accuracy: 0.9434 - precision: 0.8047 - recall: 0.7296 - auc: 0.9616 - val_loss: 0.1410 - val_tp: 645.0000 - val_fp: 225.0000 - val_tn: 5696.0000 - val_fn: 153.0000 - val_accuracy: 0.9437 - val_precision: 0.7414 - val_recall: 0.8083 - val_auc: 0.9670
# Epoch 58/200
# 280/280 - 13s - loss: 0.1473 - tp: 2508.0000 - fp: 608.0000 - tn: 22868.0000 - fn: 891.0000 - accuracy: 0.9442 - precision: 0.8049 - recall: 0.7379 - auc: 0.9619 - val_loss: 0.1377 - val_tp: 635.0000 - val_fp: 205.0000 - val_tn: 5716.0000 - val_fn: 163.0000 - val_accuracy: 0.9452 - val_precision: 0.7560 - val_recall: 0.7957 - val_auc: 0.9673
# Epoch 59/200
# 280/280 - 13s - loss: 0.1473 - tp: 2513.0000 - fp: 636.0000 - tn: 22840.0000 - fn: 886.0000 - accuracy: 0.9434 - precision: 0.7980 - recall: 0.7393 - auc: 0.9612 - val_loss: 0.1411 - val_tp: 529.0000 - val_fp: 106.0000 - val_tn: 5815.0000 - val_fn: 269.0000 - val_accuracy: 0.9442 - val_precision: 0.8331 - val_recall: 0.6629 - val_auc: 0.9659
# Epoch 60/200
# 280/280 - 13s - loss: 0.1456 - tp: 2539.0000 - fp: 610.0000 - tn: 22866.0000 - fn: 860.0000 - accuracy: 0.9453 - precision: 0.8063 - recall: 0.7470 - auc: 0.9618 - val_loss: 0.1348 - val_tp: 634.0000 - val_fp: 188.0000 - val_tn: 5733.0000 - val_fn: 164.0000 - val_accuracy: 0.9476 - val_precision: 0.7713 - val_recall: 0.7945 - val_auc: 0.9677
# Epoch 61/200
# 280/280 - 13s - loss: 0.1452 - tp: 2526.0000 - fp: 621.0000 - tn: 22855.0000 - fn: 873.0000 - accuracy: 0.9444 - precision: 0.8027 - recall: 0.7432 - auc: 0.9624 - val_loss: 0.1326 - val_tp: 587.0000 - val_fp: 125.0000 - val_tn: 5796.0000 - val_fn: 211.0000 - val_accuracy: 0.9500 - val_precision: 0.8244 - val_recall: 0.7356 - val_auc: 0.9680
# Epoch 62/200
# 280/280 - 13s - loss: 0.1462 - tp: 2555.0000 - fp: 648.0000 - tn: 22828.0000 - fn: 844.0000 - accuracy: 0.9445 - precision: 0.7977 - recall: 0.7517 - auc: 0.9621 - val_loss: 0.1369 - val_tp: 544.0000 - val_fp: 102.0000 - val_tn: 5819.0000 - val_fn: 254.0000 - val_accuracy: 0.9470 - val_precision: 0.8421 - val_recall: 0.6817 - val_auc: 0.9673
# Epoch 63/200
# 280/280 - 13s - loss: 0.1451 - tp: 2534.0000 - fp: 616.0000 - tn: 22860.0000 - fn: 865.0000 - accuracy: 0.9449 - precision: 0.8044 - recall: 0.7455 - auc: 0.9626 - val_loss: 0.1348 - val_tp: 634.0000 - val_fp: 191.0000 - val_tn: 5730.0000 - val_fn: 164.0000 - val_accuracy: 0.9472 - val_precision: 0.7685 - val_recall: 0.7945 - val_auc: 0.9681
# Epoch 64/200
# 280/280 - 13s - loss: 0.1438 - tp: 2532.0000 - fp: 618.0000 - tn: 22858.0000 - fn: 867.0000 - accuracy: 0.9447 - precision: 0.8038 - recall: 0.7449 - auc: 0.9633 - val_loss: 0.1328 - val_tp: 606.0000 - val_fp: 148.0000 - val_tn: 5773.0000 - val_fn: 192.0000 - val_accuracy: 0.9494 - val_precision: 0.8037 - val_recall: 0.7594 - val_auc: 0.9682
# Epoch 65/200
# 280/280 - 13s - loss: 0.1428 - tp: 2530.0000 - fp: 597.0000 - tn: 22879.0000 - fn: 869.0000 - accuracy: 0.9455 - precision: 0.8091 - recall: 0.7443 - auc: 0.9635 - val_loss: 0.1310 - val_tp: 601.0000 - val_fp: 136.0000 - val_tn: 5785.0000 - val_fn: 197.0000 - val_accuracy: 0.9504 - val_precision: 0.8155 - val_recall: 0.7531 - val_auc: 0.9686
# Epoch 66/200
# 280/280 - 13s - loss: 0.1424 - tp: 2546.0000 - fp: 597.0000 - tn: 22879.0000 - fn: 853.0000 - accuracy: 0.9460 - precision: 0.8101 - recall: 0.7490 - auc: 0.9627 - val_loss: 0.1357 - val_tp: 652.0000 - val_fp: 207.0000 - val_tn: 5714.0000 - val_fn: 146.0000 - val_accuracy: 0.9475 - val_precision: 0.7590 - val_recall: 0.8170 - val_auc: 0.9688
# Epoch 67/200
# 280/280 - 13s - loss: 0.1422 - tp: 2563.0000 - fp: 593.0000 - tn: 22883.0000 - fn: 836.0000 - accuracy: 0.9468 - precision: 0.8121 - recall: 0.7540 - auc: 0.9630 - val_loss: 0.1443 - val_tp: 686.0000 - val_fp: 264.0000 - val_tn: 5657.0000 - val_fn: 112.0000 - val_accuracy: 0.9440 - val_precision: 0.7221 - val_recall: 0.8596 - val_auc: 0.9687
# Epoch 68/200
# 280/280 - 13s - loss: 0.1423 - tp: 2545.0000 - fp: 616.0000 - tn: 22860.0000 - fn: 854.0000 - accuracy: 0.9453 - precision: 0.8051 - recall: 0.7487 - auc: 0.9630 - val_loss: 0.1374 - val_tp: 662.0000 - val_fp: 213.0000 - val_tn: 5708.0000 - val_fn: 136.0000 - val_accuracy: 0.9481 - val_precision: 0.7566 - val_recall: 0.8296 - val_auc: 0.9689
# Epoch 69/200
# 280/280 - 13s - loss: 0.1405 - tp: 2554.0000 - fp: 595.0000 - tn: 22881.0000 - fn: 845.0000 - accuracy: 0.9464 - precision: 0.8111 - recall: 0.7514 - auc: 0.9643 - val_loss: 0.1293 - val_tp: 619.0000 - val_fp: 149.0000 - val_tn: 5772.0000 - val_fn: 179.0000 - val_accuracy: 0.9512 - val_precision: 0.8060 - val_recall: 0.7757 - val_auc: 0.9689
# Epoch 70/200
# 280/280 - 13s - loss: 0.1408 - tp: 2569.0000 - fp: 590.0000 - tn: 22886.0000 - fn: 830.0000 - accuracy: 0.9472 - precision: 0.8132 - recall: 0.7558 - auc: 0.9638 - val_loss: 0.1300 - val_tp: 628.0000 - val_fp: 164.0000 - val_tn: 5757.0000 - val_fn: 170.0000 - val_accuracy: 0.9503 - val_precision: 0.7929 - val_recall: 0.7870 - val_auc: 0.9689
# Epoch 71/200
# 280/280 - 13s - loss: 0.1396 - tp: 2563.0000 - fp: 598.0000 - tn: 22878.0000 - fn: 836.0000 - accuracy: 0.9466 - precision: 0.8108 - recall: 0.7540 - auc: 0.9644 - val_loss: 0.1340 - val_tp: 657.0000 - val_fp: 184.0000 - val_tn: 5737.0000 - val_fn: 141.0000 - val_accuracy: 0.9516 - val_precision: 0.7812 - val_recall: 0.8233 - val_auc: 0.9692
# Epoch 72/200
# 280/280 - 13s - loss: 0.1393 - tp: 2575.0000 - fp: 597.0000 - tn: 22879.0000 - fn: 824.0000 - accuracy: 0.9471 - precision: 0.8118 - recall: 0.7576 - auc: 0.9644 - val_loss: 0.1286 - val_tp: 572.0000 - val_fp: 99.0000 - val_tn: 5822.0000 - val_fn: 226.0000 - val_accuracy: 0.9516 - val_precision: 0.8525 - val_recall: 0.7168 - val_auc: 0.9699
# Epoch 73/200
# 280/280 - 13s - loss: 0.1389 - tp: 2575.0000 - fp: 585.0000 - tn: 22891.0000 - fn: 824.0000 - accuracy: 0.9476 - precision: 0.8149 - recall: 0.7576 - auc: 0.9651 - val_loss: 0.1281 - val_tp: 616.0000 - val_fp: 143.0000 - val_tn: 5778.0000 - val_fn: 182.0000 - val_accuracy: 0.9516 - val_precision: 0.8116 - val_recall: 0.7719 - val_auc: 0.9696
# Epoch 74/200
# 280/280 - 13s - loss: 0.1392 - tp: 2566.0000 - fp: 593.0000 - tn: 22883.0000 - fn: 833.0000 - accuracy: 0.9469 - precision: 0.8123 - recall: 0.7549 - auc: 0.9647 - val_loss: 0.1442 - val_tp: 692.0000 - val_fp: 268.0000 - val_tn: 5653.0000 - val_fn: 106.0000 - val_accuracy: 0.9443 - val_precision: 0.7208 - val_recall: 0.8672 - val_auc: 0.9698
# Epoch 75/200
# 280/280 - 13s - loss: 0.1385 - tp: 2605.0000 - fp: 592.0000 - tn: 22884.0000 - fn: 794.0000 - accuracy: 0.9484 - precision: 0.8148 - recall: 0.7664 - auc: 0.9645 - val_loss: 0.1283 - val_tp: 617.0000 - val_fp: 149.0000 - val_tn: 5772.0000 - val_fn: 181.0000 - val_accuracy: 0.9509 - val_precision: 0.8055 - val_recall: 0.7732 - val_auc: 0.9701
# Epoch 76/200
# 280/280 - 13s - loss: 0.1378 - tp: 2604.0000 - fp: 597.0000 - tn: 22879.0000 - fn: 795.0000 - accuracy: 0.9482 - precision: 0.8135 - recall: 0.7661 - auc: 0.9652 - val_loss: 0.1285 - val_tp: 631.0000 - val_fp: 154.0000 - val_tn: 5767.0000 - val_fn: 167.0000 - val_accuracy: 0.9522 - val_precision: 0.8038 - val_recall: 0.7907 - val_auc: 0.9695
# Epoch 77/200
# 280/280 - 13s - loss: 0.1371 - tp: 2604.0000 - fp: 585.0000 - tn: 22891.0000 - fn: 795.0000 - accuracy: 0.9487 - precision: 0.8166 - recall: 0.7661 - auc: 0.9655 - val_loss: 0.1247 - val_tp: 616.0000 - val_fp: 131.0000 - val_tn: 5790.0000 - val_fn: 182.0000 - val_accuracy: 0.9534 - val_precision: 0.8246 - val_recall: 0.7719 - val_auc: 0.9702
# Epoch 78/200
# 280/280 - 13s - loss: 0.1370 - tp: 2589.0000 - fp: 576.0000 - tn: 22900.0000 - fn: 810.0000 - accuracy: 0.9484 - precision: 0.8180 - recall: 0.7617 - auc: 0.9656 - val_loss: 0.1279 - val_tp: 606.0000 - val_fp: 134.0000 - val_tn: 5787.0000 - val_fn: 192.0000 - val_accuracy: 0.9515 - val_precision: 0.8189 - val_recall: 0.7594 - val_auc: 0.9697
# Epoch 79/200
# 280/280 - 13s - loss: 0.1360 - tp: 2599.0000 - fp: 567.0000 - tn: 22909.0000 - fn: 800.0000 - accuracy: 0.9491 - precision: 0.8209 - recall: 0.7646 - auc: 0.9653 - val_loss: 0.1311 - val_tp: 644.0000 - val_fp: 182.0000 - val_tn: 5739.0000 - val_fn: 154.0000 - val_accuracy: 0.9500 - val_precision: 0.7797 - val_recall: 0.8070 - val_auc: 0.9699
# Epoch 80/200
# 280/280 - 13s - loss: 0.1363 - tp: 2609.0000 - fp: 580.0000 - tn: 22896.0000 - fn: 790.0000 - accuracy: 0.9490 - precision: 0.8181 - recall: 0.7676 - auc: 0.9659 - val_loss: 0.1277 - val_tp: 646.0000 - val_fp: 172.0000 - val_tn: 5749.0000 - val_fn: 152.0000 - val_accuracy: 0.9518 - val_precision: 0.7897 - val_recall: 0.8095 - val_auc: 0.9704
# Epoch 81/200
# 280/280 - 13s - loss: 0.1354 - tp: 2607.0000 - fp: 575.0000 - tn: 22901.0000 - fn: 792.0000 - accuracy: 0.9491 - precision: 0.8193 - recall: 0.7670 - auc: 0.9667 - val_loss: 0.1298 - val_tp: 672.0000 - val_fp: 193.0000 - val_tn: 5728.0000 - val_fn: 126.0000 - val_accuracy: 0.9525 - val_precision: 0.7769 - val_recall: 0.8421 - val_auc: 0.9710
# Epoch 82/200
# 280/280 - 13s - loss: 0.1360 - tp: 2624.0000 - fp: 582.0000 - tn: 22894.0000 - fn: 775.0000 - accuracy: 0.9495 - precision: 0.8185 - recall: 0.7720 - auc: 0.9654 - val_loss: 0.1253 - val_tp: 656.0000 - val_fp: 165.0000 - val_tn: 5756.0000 - val_fn: 142.0000 - val_accuracy: 0.9543 - val_precision: 0.7990 - val_recall: 0.8221 - val_auc: 0.9710
# Epoch 83/200
# 280/280 - 13s - loss: 0.1351 - tp: 2630.0000 - fp: 585.0000 - tn: 22891.0000 - fn: 769.0000 - accuracy: 0.9496 - precision: 0.8180 - recall: 0.7738 - auc: 0.9661 - val_loss: 0.1260 - val_tp: 650.0000 - val_fp: 165.0000 - val_tn: 5756.0000 - val_fn: 148.0000 - val_accuracy: 0.9534 - val_precision: 0.7975 - val_recall: 0.8145 - val_auc: 0.9705
# Epoch 84/200
# 280/280 - 13s - loss: 0.1346 - tp: 2630.0000 - fp: 571.0000 - tn: 22905.0000 - fn: 769.0000 - accuracy: 0.9501 - precision: 0.8216 - recall: 0.7738 - auc: 0.9663 - val_loss: 0.1294 - val_tp: 663.0000 - val_fp: 187.0000 - val_tn: 5734.0000 - val_fn: 135.0000 - val_accuracy: 0.9521 - val_precision: 0.7800 - val_recall: 0.8308 - val_auc: 0.9702
# Epoch 85/200
# 280/280 - 13s - loss: 0.1349 - tp: 2642.0000 - fp: 588.0000 - tn: 22888.0000 - fn: 757.0000 - accuracy: 0.9500 - precision: 0.8180 - recall: 0.7773 - auc: 0.9661 - val_loss: 0.1273 - val_tp: 670.0000 - val_fp: 173.0000 - val_tn: 5748.0000 - val_fn: 128.0000 - val_accuracy: 0.9552 - val_precision: 0.7948 - val_recall: 0.8396 - val_auc: 0.9709
# Epoch 86/200
# 280/280 - 13s - loss: 0.1337 - tp: 2625.0000 - fp: 571.0000 - tn: 22905.0000 - fn: 774.0000 - accuracy: 0.9500 - precision: 0.8213 - recall: 0.7723 - auc: 0.9665 - val_loss: 0.1299 - val_tp: 635.0000 - val_fp: 188.0000 - val_tn: 5733.0000 - val_fn: 163.0000 - val_accuracy: 0.9478 - val_precision: 0.7716 - val_recall: 0.7957 - val_auc: 0.9693
# Epoch 87/200
# 280/280 - 13s - loss: 0.1344 - tp: 2627.0000 - fp: 586.0000 - tn: 22890.0000 - fn: 772.0000 - accuracy: 0.9495 - precision: 0.8176 - recall: 0.7729 - auc: 0.9670 - val_loss: 0.1252 - val_tp: 609.0000 - val_fp: 114.0000 - val_tn: 5807.0000 - val_fn: 189.0000 - val_accuracy: 0.9549 - val_precision: 0.8423 - val_recall: 0.7632 - val_auc: 0.9711
# Epoch 88/200
# 280/280 - 13s - loss: 0.1338 - tp: 2623.0000 - fp: 569.0000 - tn: 22907.0000 - fn: 776.0000 - accuracy: 0.9500 - precision: 0.8217 - recall: 0.7717 - auc: 0.9666 - val_loss: 0.1361 - val_tp: 693.0000 - val_fp: 232.0000 - val_tn: 5689.0000 - val_fn: 105.0000 - val_accuracy: 0.9498 - val_precision: 0.7492 - val_recall: 0.8684 - val_auc: 0.9715
# Epoch 89/200
# 280/280 - 13s - loss: 0.1337 - tp: 2616.0000 - fp: 556.0000 - tn: 22920.0000 - fn: 783.0000 - accuracy: 0.9502 - precision: 0.8247 - recall: 0.7696 - auc: 0.9658 - val_loss: 0.1241 - val_tp: 634.0000 - val_fp: 139.0000 - val_tn: 5782.0000 - val_fn: 164.0000 - val_accuracy: 0.9549 - val_precision: 0.8202 - val_recall: 0.7945 - val_auc: 0.9710
# Epoch 90/200
# 280/280 - 13s - loss: 0.1338 - tp: 2627.0000 - fp: 572.0000 - tn: 22904.0000 - fn: 772.0000 - accuracy: 0.9500 - precision: 0.8212 - recall: 0.7729 - auc: 0.9665 - val_loss: 0.1270 - val_tp: 646.0000 - val_fp: 169.0000 - val_tn: 5752.0000 - val_fn: 152.0000 - val_accuracy: 0.9522 - val_precision: 0.7926 - val_recall: 0.8095 - val_auc: 0.9709
# Epoch 91/200
# 280/280 - 13s - loss: 0.1317 - tp: 2645.0000 - fp: 548.0000 - tn: 22928.0000 - fn: 754.0000 - accuracy: 0.9516 - precision: 0.8284 - recall: 0.7782 - auc: 0.9676 - val_loss: 0.1232 - val_tp: 616.0000 - val_fp: 118.0000 - val_tn: 5803.0000 - val_fn: 182.0000 - val_accuracy: 0.9554 - val_precision: 0.8392 - val_recall: 0.7719 - val_auc: 0.9716
# Epoch 92/200
# 280/280 - 13s - loss: 0.1333 - tp: 2640.0000 - fp: 578.0000 - tn: 22898.0000 - fn: 759.0000 - accuracy: 0.9503 - precision: 0.8204 - recall: 0.7767 - auc: 0.9671 - val_loss: 0.1241 - val_tp: 659.0000 - val_fp: 157.0000 - val_tn: 5764.0000 - val_fn: 139.0000 - val_accuracy: 0.9559 - val_precision: 0.8076 - val_recall: 0.8258 - val_auc: 0.9719
# Epoch 93/200
# 280/280 - 13s - loss: 0.1340 - tp: 2637.0000 - fp: 549.0000 - tn: 22927.0000 - fn: 762.0000 - accuracy: 0.9512 - precision: 0.8277 - recall: 0.7758 - auc: 0.9659 - val_loss: 0.1271 - val_tp: 672.0000 - val_fp: 178.0000 - val_tn: 5743.0000 - val_fn: 126.0000 - val_accuracy: 0.9548 - val_precision: 0.7906 - val_recall: 0.8421 - val_auc: 0.9719
# Epoch 94/200
# 280/280 - 13s - loss: 0.1327 - tp: 2637.0000 - fp: 542.0000 - tn: 22934.0000 - fn: 762.0000 - accuracy: 0.9515 - precision: 0.8295 - recall: 0.7758 - auc: 0.9662 - val_loss: 0.1270 - val_tp: 666.0000 - val_fp: 183.0000 - val_tn: 5738.0000 - val_fn: 132.0000 - val_accuracy: 0.9531 - val_precision: 0.7845 - val_recall: 0.8346 - val_auc: 0.9712
# Epoch 95/200
# 280/280 - 13s - loss: 0.1315 - tp: 2645.0000 - fp: 565.0000 - tn: 22911.0000 - fn: 754.0000 - accuracy: 0.9509 - precision: 0.8240 - recall: 0.7782 - auc: 0.9682 - val_loss: 0.1237 - val_tp: 624.0000 - val_fp: 124.0000 - val_tn: 5797.0000 - val_fn: 174.0000 - val_accuracy: 0.9556 - val_precision: 0.8342 - val_recall: 0.7820 - val_auc: 0.9706
# Epoch 96/200
# 280/280 - 13s - loss: 0.1314 - tp: 2633.0000 - fp: 558.0000 - tn: 22918.0000 - fn: 766.0000 - accuracy: 0.9507 - precision: 0.8251 - recall: 0.7746 - auc: 0.9668 - val_loss: 0.1286 - val_tp: 674.0000 - val_fp: 201.0000 - val_tn: 5720.0000 - val_fn: 124.0000 - val_accuracy: 0.9516 - val_precision: 0.7703 - val_recall: 0.8446 - val_auc: 0.9717
# Epoch 97/200
# 280/280 - 13s - loss: 0.1317 - tp: 2640.0000 - fp: 564.0000 - tn: 22912.0000 - fn: 759.0000 - accuracy: 0.9508 - precision: 0.8240 - recall: 0.7767 - auc: 0.9671 - val_loss: 0.1280 - val_tp: 600.0000 - val_fp: 111.0000 - val_tn: 5810.0000 - val_fn: 198.0000 - val_accuracy: 0.9540 - val_precision: 0.8439 - val_recall: 0.7519 - val_auc: 0.9694
# Epoch 98/200
# 280/280 - 13s - loss: 0.1316 - tp: 2663.0000 - fp: 586.0000 - tn: 22890.0000 - fn: 736.0000 - accuracy: 0.9508 - precision: 0.8196 - recall: 0.7835 - auc: 0.9674 - val_loss: 0.1215 - val_tp: 638.0000 - val_fp: 146.0000 - val_tn: 5775.0000 - val_fn: 160.0000 - val_accuracy: 0.9545 - val_precision: 0.8138 - val_recall: 0.7995 - val_auc: 0.9719
# Epoch 99/200
# 280/280 - 13s - loss: 0.1308 - tp: 2675.0000 - fp: 573.0000 - tn: 22903.0000 - fn: 724.0000 - accuracy: 0.9517 - precision: 0.8236 - recall: 0.7870 - auc: 0.9676 - val_loss: 0.1229 - val_tp: 650.0000 - val_fp: 158.0000 - val_tn: 5763.0000 - val_fn: 148.0000 - val_accuracy: 0.9545 - val_precision: 0.8045 - val_recall: 0.8145 - val_auc: 0.9718
# Epoch 100/200
# 280/280 - 13s - loss: 0.1295 - tp: 2663.0000 - fp: 555.0000 - tn: 22921.0000 - fn: 736.0000 - accuracy: 0.9520 - precision: 0.8275 - recall: 0.7835 - auc: 0.9684 - val_loss: 0.1204 - val_tp: 600.0000 - val_fp: 96.0000 - val_tn: 5825.0000 - val_fn: 198.0000 - val_accuracy: 0.9562 - val_precision: 0.8621 - val_recall: 0.7519 - val_auc: 0.9722
# Epoch 101/200
# 280/280 - 13s - loss: 0.1308 - tp: 2646.0000 - fp: 561.0000 - tn: 22915.0000 - fn: 753.0000 - accuracy: 0.9511 - precision: 0.8251 - recall: 0.7785 - auc: 0.9677 - val_loss: 0.1220 - val_tp: 615.0000 - val_fp: 111.0000 - val_tn: 5810.0000 - val_fn: 183.0000 - val_accuracy: 0.9562 - val_precision: 0.8471 - val_recall: 0.7707 - val_auc: 0.9715
# Epoch 102/200
# 280/280 - 13s - loss: 0.1303 - tp: 2660.0000 - fp: 560.0000 - tn: 22916.0000 - fn: 739.0000 - accuracy: 0.9517 - precision: 0.8261 - recall: 0.7826 - auc: 0.9684 - val_loss: 0.1196 - val_tp: 651.0000 - val_fp: 141.0000 - val_tn: 5780.0000 - val_fn: 147.0000 - val_accuracy: 0.9571 - val_precision: 0.8220 - val_recall: 0.8158 - val_auc: 0.9723
# Epoch 103/200
# 280/280 - 13s - loss: 0.1315 - tp: 2659.0000 - fp: 601.0000 - tn: 22875.0000 - fn: 740.0000 - accuracy: 0.9501 - precision: 0.8156 - recall: 0.7823 - auc: 0.9679 - val_loss: 0.1231 - val_tp: 577.0000 - val_fp: 77.0000 - val_tn: 5844.0000 - val_fn: 221.0000 - val_accuracy: 0.9556 - val_precision: 0.8823 - val_recall: 0.7231 - val_auc: 0.9719
# Epoch 104/200
# 280/280 - 13s - loss: 0.1290 - tp: 2674.0000 - fp: 542.0000 - tn: 22934.0000 - fn: 725.0000 - accuracy: 0.9529 - precision: 0.8315 - recall: 0.7867 - auc: 0.9690 - val_loss: 0.1215 - val_tp: 649.0000 - val_fp: 149.0000 - val_tn: 5772.0000 - val_fn: 149.0000 - val_accuracy: 0.9556 - val_precision: 0.8133 - val_recall: 0.8133 - val_auc: 0.9720
# Epoch 105/200
# 280/280 - 13s - loss: 0.1309 - tp: 2655.0000 - fp: 571.0000 - tn: 22905.0000 - fn: 744.0000 - accuracy: 0.9511 - precision: 0.8230 - recall: 0.7811 - auc: 0.9676 - val_loss: 0.1282 - val_tp: 688.0000 - val_fp: 209.0000 - val_tn: 5712.0000 - val_fn: 110.0000 - val_accuracy: 0.9525 - val_precision: 0.7670 - val_recall: 0.8622 - val_auc: 0.9725
# Epoch 106/200
# 280/280 - 13s - loss: 0.1309 - tp: 2658.0000 - fp: 568.0000 - tn: 22908.0000 - fn: 741.0000 - accuracy: 0.9513 - precision: 0.8239 - recall: 0.7820 - auc: 0.9671 - val_loss: 0.1220 - val_tp: 656.0000 - val_fp: 151.0000 - val_tn: 5770.0000 - val_fn: 142.0000 - val_accuracy: 0.9564 - val_precision: 0.8129 - val_recall: 0.8221 - val_auc: 0.9725
# Epoch 107/200
# 280/280 - 13s - loss: 0.1297 - tp: 2669.0000 - fp: 578.0000 - tn: 22898.0000 - fn: 730.0000 - accuracy: 0.9513 - precision: 0.8220 - recall: 0.7852 - auc: 0.9686 - val_loss: 0.1202 - val_tp: 652.0000 - val_fp: 151.0000 - val_tn: 5770.0000 - val_fn: 146.0000 - val_accuracy: 0.9558 - val_precision: 0.8120 - val_recall: 0.8170 - val_auc: 0.9723
# Epoch 108/200
# 280/280 - 13s - loss: 0.1286 - tp: 2686.0000 - fp: 554.0000 - tn: 22922.0000 - fn: 713.0000 - accuracy: 0.9529 - precision: 0.8290 - recall: 0.7902 - auc: 0.9684 - val_loss: 0.1194 - val_tp: 608.0000 - val_fp: 98.0000 - val_tn: 5823.0000 - val_fn: 190.0000 - val_accuracy: 0.9571 - val_precision: 0.8612 - val_recall: 0.7619 - val_auc: 0.9719
# Epoch 109/200
# 280/280 - 13s - loss: 0.1287 - tp: 2676.0000 - fp: 530.0000 - tn: 22946.0000 - fn: 723.0000 - accuracy: 0.9534 - precision: 0.8347 - recall: 0.7873 - auc: 0.9680 - val_loss: 0.1224 - val_tp: 663.0000 - val_fp: 153.0000 - val_tn: 5768.0000 - val_fn: 135.0000 - val_accuracy: 0.9571 - val_precision: 0.8125 - val_recall: 0.8308 - val_auc: 0.9722
# Epoch 110/200
# 280/280 - 13s - loss: 0.1282 - tp: 2683.0000 - fp: 559.0000 - tn: 22917.0000 - fn: 716.0000 - accuracy: 0.9526 - precision: 0.8276 - recall: 0.7893 - auc: 0.9690 - val_loss: 0.1184 - val_tp: 658.0000 - val_fp: 142.0000 - val_tn: 5779.0000 - val_fn: 140.0000 - val_accuracy: 0.9580 - val_precision: 0.8225 - val_recall: 0.8246 - val_auc: 0.9726
# Epoch 111/200
# 280/280 - 13s - loss: 0.1268 - tp: 2689.0000 - fp: 527.0000 - tn: 22949.0000 - fn: 710.0000 - accuracy: 0.9540 - precision: 0.8361 - recall: 0.7911 - auc: 0.9696 - val_loss: 0.1243 - val_tp: 680.0000 - val_fp: 173.0000 - val_tn: 5748.0000 - val_fn: 118.0000 - val_accuracy: 0.9567 - val_precision: 0.7972 - val_recall: 0.8521 - val_auc: 0.9725
# Epoch 112/200
# 280/280 - 13s - loss: 0.1278 - tp: 2684.0000 - fp: 542.0000 - tn: 22934.0000 - fn: 715.0000 - accuracy: 0.9532 - precision: 0.8320 - recall: 0.7896 - auc: 0.9692 - val_loss: 0.1339 - val_tp: 527.0000 - val_fp: 61.0000 - val_tn: 5860.0000 - val_fn: 271.0000 - val_accuracy: 0.9506 - val_precision: 0.8963 - val_recall: 0.6604 - val_auc: 0.9704
# Epoch 113/200
# 280/280 - 13s - loss: 0.1285 - tp: 2689.0000 - fp: 553.0000 - tn: 22923.0000 - fn: 710.0000 - accuracy: 0.9530 - precision: 0.8294 - recall: 0.7911 - auc: 0.9692 - val_loss: 0.1216 - val_tp: 642.0000 - val_fp: 135.0000 - val_tn: 5786.0000 - val_fn: 156.0000 - val_accuracy: 0.9567 - val_precision: 0.8263 - val_recall: 0.8045 - val_auc: 0.9721
# Epoch 114/200
# 280/280 - 13s - loss: 0.1282 - tp: 2699.0000 - fp: 559.0000 - tn: 22917.0000 - fn: 700.0000 - accuracy: 0.9532 - precision: 0.8284 - recall: 0.7941 - auc: 0.9694 - val_loss: 0.1196 - val_tp: 612.0000 - val_fp: 97.0000 - val_tn: 5824.0000 - val_fn: 186.0000 - val_accuracy: 0.9579 - val_precision: 0.8632 - val_recall: 0.7669 - val_auc: 0.9723
# Epoch 115/200
# 280/280 - 13s - loss: 0.1271 - tp: 2677.0000 - fp: 524.0000 - tn: 22952.0000 - fn: 722.0000 - accuracy: 0.9536 - precision: 0.8363 - recall: 0.7876 - auc: 0.9688 - val_loss: 0.1435 - val_tp: 712.0000 - val_fp: 277.0000 - val_tn: 5644.0000 - val_fn: 86.0000 - val_accuracy: 0.9460 - val_precision: 0.7199 - val_recall: 0.8922 - val_auc: 0.9726
# Epoch 116/200
# 280/280 - 13s - loss: 0.1283 - tp: 2672.0000 - fp: 541.0000 - tn: 22935.0000 - fn: 727.0000 - accuracy: 0.9528 - precision: 0.8316 - recall: 0.7861 - auc: 0.9687 - val_loss: 0.1234 - val_tp: 586.0000 - val_fp: 81.0000 - val_tn: 5840.0000 - val_fn: 212.0000 - val_accuracy: 0.9564 - val_precision: 0.8786 - val_recall: 0.7343 - val_auc: 0.9720
# Epoch 117/200
# 280/280 - 13s - loss: 0.1281 - tp: 2680.0000 - fp: 583.0000 - tn: 22893.0000 - fn: 719.0000 - accuracy: 0.9516 - precision: 0.8213 - recall: 0.7885 - auc: 0.9692 - val_loss: 0.1248 - val_tp: 684.0000 - val_fp: 188.0000 - val_tn: 5733.0000 - val_fn: 114.0000 - val_accuracy: 0.9551 - val_precision: 0.7844 - val_recall: 0.8571 - val_auc: 0.9729
# Epoch 118/200
# 280/280 - 13s - loss: 0.1256 - tp: 2681.0000 - fp: 518.0000 - tn: 22958.0000 - fn: 718.0000 - accuracy: 0.9540 - precision: 0.8381 - recall: 0.7888 - auc: 0.9693 - val_loss: 0.1173 - val_tp: 634.0000 - val_fp: 118.0000 - val_tn: 5803.0000 - val_fn: 164.0000 - val_accuracy: 0.9580 - val_precision: 0.8431 - val_recall: 0.7945 - val_auc: 0.9729
# Epoch 119/200
# 280/280 - 13s - loss: 0.1270 - tp: 2694.0000 - fp: 539.0000 - tn: 22937.0000 - fn: 705.0000 - accuracy: 0.9537 - precision: 0.8333 - recall: 0.7926 - auc: 0.9691 - val_loss: 0.1179 - val_tp: 646.0000 - val_fp: 139.0000 - val_tn: 5782.0000 - val_fn: 152.0000 - val_accuracy: 0.9567 - val_precision: 0.8229 - val_recall: 0.8095 - val_auc: 0.9729
# Epoch 120/200
# ...
# Epoch 151/200
# 280/280 - 13s - loss: 0.1198 - tp: 2756.0000 - fp: 522.0000 - tn: 22954.0000 - fn: 643.0000 - accuracy: 0.9567 - precision: 0.8408 - recall: 0.8108 - auc: 0.9719 - val_loss: 0.1172 - val_tp: 634.0000 - val_fp: 102.0000 - val_tn: 5819.0000 - val_fn: 164.0000 - val_accuracy: 0.9604 - val_precision: 0.8614 - val_recall: 0.7945 - val_auc: 0.9725
# Epoch 152/200
# 280/280 - 13s - loss: 0.1195 - tp: 2766.0000 - fp: 524.0000 - tn: 22952.0000 - fn: 633.0000 - accuracy: 0.9569 - precision: 0.8407 - recall: 0.8138 - auc: 0.9713 - val_loss: 0.1152 - val_tp: 671.0000 - val_fp: 135.0000 - val_tn: 5786.0000 - val_fn: 127.0000 - val_accuracy: 0.9610 - val_precision: 0.8325 - val_recall: 0.8409 - val_auc: 0.9738
# Epoch 153/200
# 280/280 - 13s - loss: 0.1209 - tp: 2741.0000 - fp: 515.0000 - tn: 22961.0000 - fn: 658.0000 - accuracy: 0.9564 - precision: 0.8418 - recall: 0.8064 - auc: 0.9721 - val_loss: 0.1142 - val_tp: 670.0000 - val_fp: 133.0000 - val_tn: 5788.0000 - val_fn: 128.0000 - val_accuracy: 0.9612 - val_precision: 0.8344 - val_recall: 0.8396 - val_auc: 0.9737
# Epoch 154/200
# 280/280 - 13s - loss: 0.1196 - tp: 2760.0000 - fp: 512.0000 - tn: 22964.0000 - fn: 639.0000 - accuracy: 0.9572 - precision: 0.8435 - recall: 0.8120 - auc: 0.9719 - val_loss: 0.1135 - val_tp: 647.0000 - val_fp: 109.0000 - val_tn: 5812.0000 - val_fn: 151.0000 - val_accuracy: 0.9613 - val_precision: 0.8558 - val_recall: 0.8108 - val_auc: 0.9733
# Epoch 155/200
# 280/280 - 13s - loss: 0.1203 - tp: 2765.0000 - fp: 529.0000 - tn: 22947.0000 - fn: 634.0000 - accuracy: 0.9567 - precision: 0.8394 - recall: 0.8135 - auc: 0.9720 - val_loss: 0.1302 - val_tp: 717.0000 - val_fp: 247.0000 - val_tn: 5674.0000 - val_fn: 81.0000 - val_accuracy: 0.9512 - val_precision: 0.7438 - val_recall: 0.8985 - val_auc: 0.9741
# Epoch 156/200
# 280/280 - 13s - loss: 0.1205 - tp: 2769.0000 - fp: 518.0000 - tn: 22958.0000 - fn: 630.0000 - accuracy: 0.9573 - precision: 0.8424 - recall: 0.8147 - auc: 0.9714 - val_loss: 0.1139 - val_tp: 670.0000 - val_fp: 134.0000 - val_tn: 5787.0000 - val_fn: 128.0000 - val_accuracy: 0.9610 - val_precision: 0.8333 - val_recall: 0.8396 - val_auc: 0.9738
# Epoch 157/200
# 280/280 - 13s - loss: 0.1201 - tp: 2763.0000 - fp: 517.0000 - tn: 22959.0000 - fn: 636.0000 - accuracy: 0.9571 - precision: 0.8424 - recall: 0.8129 - auc: 0.9719 - val_loss: 0.1208 - val_tp: 699.0000 - val_fp: 196.0000 - val_tn: 5725.0000 - val_fn: 99.0000 - val_accuracy: 0.9561 - val_precision: 0.7810 - val_recall: 0.8759 - val_auc: 0.9732
# Epoch 158/200
# 280/280 - 13s - loss: 0.1205 - tp: 2764.0000 - fp: 515.0000 - tn: 22961.0000 - fn: 635.0000 - accuracy: 0.9572 - precision: 0.8429 - recall: 0.8132 - auc: 0.9718 - val_loss: 0.1146 - val_tp: 658.0000 - val_fp: 118.0000 - val_tn: 5803.0000 - val_fn: 140.0000 - val_accuracy: 0.9616 - val_precision: 0.8479 - val_recall: 0.8246 - val_auc: 0.9732
# Epoch 159/200
# 280/280 - 13s - loss: 0.1191 - tp: 2774.0000 - fp: 510.0000 - tn: 22966.0000 - fn: 625.0000 - accuracy: 0.9578 - precision: 0.8447 - recall: 0.8161 - auc: 0.9722 - val_loss: 0.1142 - val_tp: 687.0000 - val_fp: 145.0000 - val_tn: 5776.0000 - val_fn: 111.0000 - val_accuracy: 0.9619 - val_precision: 0.8257 - val_recall: 0.8609 - val_auc: 0.9743
# Epoch 160/200
# 280/280 - 13s - loss: 0.1190 - tp: 2770.0000 - fp: 526.0000 - tn: 22950.0000 - fn: 629.0000 - accuracy: 0.9570 - precision: 0.8404 - recall: 0.8149 - auc: 0.9731 - val_loss: 0.1143 - val_tp: 680.0000 - val_fp: 135.0000 - val_tn: 5786.0000 - val_fn: 118.0000 - val_accuracy: 0.9623 - val_precision: 0.8344 - val_recall: 0.8521 - val_auc: 0.9745
# Epoch 161/200
# 280/280 - 13s - loss: 0.1198 - tp: 2774.0000 - fp: 519.0000 - tn: 22957.0000 - fn: 625.0000 - accuracy: 0.9574 - precision: 0.8424 - recall: 0.8161 - auc: 0.9718 - val_loss: 0.1147 - val_tp: 659.0000 - val_fp: 135.0000 - val_tn: 5786.0000 - val_fn: 139.0000 - val_accuracy: 0.9592 - val_precision: 0.8300 - val_recall: 0.8258 - val_auc: 0.9732
# Epoch 162/200
# 280/280 - 13s - loss: 0.1186 - tp: 2751.0000 - fp: 534.0000 - tn: 22942.0000 - fn: 648.0000 - accuracy: 0.9560 - precision: 0.8374 - recall: 0.8094 - auc: 0.9728 - val_loss: 0.1222 - val_tp: 708.0000 - val_fp: 212.0000 - val_tn: 5709.0000 - val_fn: 90.0000 - val_accuracy: 0.9551 - val_precision: 0.7696 - val_recall: 0.8872 - val_auc: 0.9746
# Epoch 163/200
# 280/280 - 13s - loss: 0.1198 - tp: 2763.0000 - fp: 519.0000 - tn: 22957.0000 - fn: 636.0000 - accuracy: 0.9570 - precision: 0.8419 - recall: 0.8129 - auc: 0.9728 - val_loss: 0.1120 - val_tp: 657.0000 - val_fp: 114.0000 - val_tn: 5807.0000 - val_fn: 141.0000 - val_accuracy: 0.9620 - val_precision: 0.8521 - val_recall: 0.8233 - val_auc: 0.9741
# Epoch 164/200
# 280/280 - 13s - loss: 0.1181 - tp: 2779.0000 - fp: 523.0000 - tn: 22953.0000 - fn: 620.0000 - accuracy: 0.9575 - precision: 0.8416 - recall: 0.8176 - auc: 0.9736 - val_loss: 0.1105 - val_tp: 642.0000 - val_fp: 95.0000 - val_tn: 5826.0000 - val_fn: 156.0000 - val_accuracy: 0.9626 - val_precision: 0.8711 - val_recall: 0.8045 - val_auc: 0.9736
# Epoch 165/200
# 280/280 - 13s - loss: 0.1191 - tp: 2765.0000 - fp: 511.0000 - tn: 22965.0000 - fn: 634.0000 - accuracy: 0.9574 - precision: 0.8440 - recall: 0.8135 - auc: 0.9722 - val_loss: 0.1151 - val_tp: 688.0000 - val_fp: 166.0000 - val_tn: 5755.0000 - val_fn: 110.0000 - val_accuracy: 0.9589 - val_precision: 0.8056 - val_recall: 0.8622 - val_auc: 0.9729
# Epoch 166/200
# 280/280 - 13s - loss: 0.1178 - tp: 2786.0000 - fp: 503.0000 - tn: 22973.0000 - fn: 613.0000 - accuracy: 0.9585 - precision: 0.8471 - recall: 0.8197 - auc: 0.9723 - val_loss: 0.1129 - val_tp: 678.0000 - val_fp: 137.0000 - val_tn: 5784.0000 - val_fn: 120.0000 - val_accuracy: 0.9618 - val_precision: 0.8319 - val_recall: 0.8496 - val_auc: 0.9739
# Epoch 167/200
# 280/280 - 13s - loss: 0.1179 - tp: 2770.0000 - fp: 507.0000 - tn: 22969.0000 - fn: 629.0000 - accuracy: 0.9577 - precision: 0.8453 - recall: 0.8149 - auc: 0.9732 - val_loss: 0.1199 - val_tp: 708.0000 - val_fp: 194.0000 - val_tn: 5727.0000 - val_fn: 90.0000 - val_accuracy: 0.9577 - val_precision: 0.7849 - val_recall: 0.8872 - val_auc: 0.9741
# Epoch 168/200
# 280/280 - 13s - loss: 0.1190 - tp: 2773.0000 - fp: 500.0000 - tn: 22976.0000 - fn: 626.0000 - accuracy: 0.9581 - precision: 0.8472 - recall: 0.8158 - auc: 0.9723 - val_loss: 0.1136 - val_tp: 674.0000 - val_fp: 137.0000 - val_tn: 5784.0000 - val_fn: 124.0000 - val_accuracy: 0.9612 - val_precision: 0.8311 - val_recall: 0.8446 - val_auc: 0.9735
# Epoch 169/200
# 280/280 - 13s - loss: 0.1171 - tp: 2787.0000 - fp: 529.0000 - tn: 22947.0000 - fn: 612.0000 - accuracy: 0.9575 - precision: 0.8405 - recall: 0.8199 - auc: 0.9731 - val_loss: 0.1151 - val_tp: 609.0000 - val_fp: 83.0000 - val_tn: 5838.0000 - val_fn: 189.0000 - val_accuracy: 0.9595 - val_precision: 0.8801 - val_recall: 0.7632 - val_auc: 0.9728
# Epoch 170/200
# 280/280 - 13s - loss: 0.1191 - tp: 2793.0000 - fp: 520.0000 - tn: 22956.0000 - fn: 606.0000 - accuracy: 0.9581 - precision: 0.8430 - recall: 0.8217 - auc: 0.9723 - val_loss: 0.1175 - val_tp: 705.0000 - val_fp: 169.0000 - val_tn: 5752.0000 - val_fn: 93.0000 - val_accuracy: 0.9610 - val_precision: 0.8066 - val_recall: 0.8835 - val_auc: 0.9745
# Epoch 171/200
# 280/280 - 13s - loss: 0.1174 - tp: 2767.0000 - fp: 512.0000 - tn: 22964.0000 - fn: 632.0000 - accuracy: 0.9574 - precision: 0.8439 - recall: 0.8141 - auc: 0.9734 - val_loss: 0.1113 - val_tp: 650.0000 - val_fp: 103.0000 - val_tn: 5818.0000 - val_fn: 148.0000 - val_accuracy: 0.9626 - val_precision: 0.8632 - val_recall: 0.8145 - val_auc: 0.9738
# Epoch 172/200
# 280/280 - 13s - loss: 0.1197 - tp: 2755.0000 - fp: 534.0000 - tn: 22942.0000 - fn: 644.0000 - accuracy: 0.9562 - precision: 0.8376 - recall: 0.8105 - auc: 0.9723 - val_loss: 0.1123 - val_tp: 649.0000 - val_fp: 110.0000 - val_tn: 5811.0000 - val_fn: 149.0000 - val_accuracy: 0.9615 - val_precision: 0.8551 - val_recall: 0.8133 - val_auc: 0.9734
# Epoch 173/200
# 280/280 - 13s - loss: 0.1176 - tp: 2780.0000 - fp: 510.0000 - tn: 22966.0000 - fn: 619.0000 - accuracy: 0.9580 - precision: 0.8450 - recall: 0.8179 - auc: 0.9730 - val_loss: 0.1118 - val_tp: 627.0000 - val_fp: 92.0000 - val_tn: 5829.0000 - val_fn: 171.0000 - val_accuracy: 0.9609 - val_precision: 0.8720 - val_recall: 0.7857 - val_auc: 0.9734
# Epoch 174/200
# 280/280 - 13s - loss: 0.1163 - tp: 2782.0000 - fp: 511.0000 - tn: 22965.0000 - fn: 617.0000 - accuracy: 0.9580 - precision: 0.8448 - recall: 0.8185 - auc: 0.9742 - val_loss: 0.1148 - val_tp: 689.0000 - val_fp: 145.0000 - val_tn: 5776.0000 - val_fn: 109.0000 - val_accuracy: 0.9622 - val_precision: 0.8261 - val_recall: 0.8634 - val_auc: 0.9751
# Epoch 175/200
# 280/280 - 13s - loss: 0.1194 - tp: 2762.0000 - fp: 535.0000 - tn: 22941.0000 - fn: 637.0000 - accuracy: 0.9564 - precision: 0.8377 - recall: 0.8126 - auc: 0.9723 - val_loss: 0.1098 - val_tp: 659.0000 - val_fp: 113.0000 - val_tn: 5808.0000 - val_fn: 139.0000 - val_accuracy: 0.9625 - val_precision: 0.8536 - val_recall: 0.8258 - val_auc: 0.9742
# Epoch 176/200
# 280/280 - 13s - loss: 0.1161 - tp: 2797.0000 - fp: 497.0000 - tn: 22979.0000 - fn: 602.0000 - accuracy: 0.9591 - precision: 0.8491 - recall: 0.8229 - auc: 0.9732 - val_loss: 0.1188 - val_tp: 699.0000 - val_fp: 191.0000 - val_tn: 5730.0000 - val_fn: 99.0000 - val_accuracy: 0.9568 - val_precision: 0.7854 - val_recall: 0.8759 - val_auc: 0.9741
# Epoch 177/200
# 280/280 - 13s - loss: 0.1170 - tp: 2795.0000 - fp: 517.0000 - tn: 22959.0000 - fn: 604.0000 - accuracy: 0.9583 - precision: 0.8439 - recall: 0.8223 - auc: 0.9735 - val_loss: 0.1149 - val_tp: 684.0000 - val_fp: 153.0000 - val_tn: 5768.0000 - val_fn: 114.0000 - val_accuracy: 0.9603 - val_precision: 0.8172 - val_recall: 0.8571 - val_auc: 0.9729
# Epoch 178/200
# 280/280 - 13s - loss: 0.1168 - tp: 2788.0000 - fp: 497.0000 - tn: 22979.0000 - fn: 611.0000 - accuracy: 0.9588 - precision: 0.8487 - recall: 0.8202 - auc: 0.9725 - val_loss: 0.1154 - val_tp: 669.0000 - val_fp: 132.0000 - val_tn: 5789.0000 - val_fn: 129.0000 - val_accuracy: 0.9612 - val_precision: 0.8352 - val_recall: 0.8383 - val_auc: 0.9728
# Epoch 179/200
# 280/280 - 13s - loss: 0.1167 - tp: 2794.0000 - fp: 505.0000 - tn: 22971.0000 - fn: 605.0000 - accuracy: 0.9587 - precision: 0.8469 - recall: 0.8220 - auc: 0.9731 - val_loss: 0.1120 - val_tp: 679.0000 - val_fp: 125.0000 - val_tn: 5796.0000 - val_fn: 119.0000 - val_accuracy: 0.9637 - val_precision: 0.8445 - val_recall: 0.8509 - val_auc: 0.9737
# Epoch 180/200
# 280/280 - 13s - loss: 0.1165 - tp: 2802.0000 - fp: 520.0000 - tn: 22956.0000 - fn: 597.0000 - accuracy: 0.9584 - precision: 0.8435 - recall: 0.8244 - auc: 0.9733 - val_loss: 0.1173 - val_tp: 703.0000 - val_fp: 178.0000 - val_tn: 5743.0000 - val_fn: 95.0000 - val_accuracy: 0.9594 - val_precision: 0.7980 - val_recall: 0.8810 - val_auc: 0.9744
# Epoch 181/200
# 280/280 - 13s - loss: 0.1156 - tp: 2788.0000 - fp: 504.0000 - tn: 22972.0000 - fn: 611.0000 - accuracy: 0.9585 - precision: 0.8469 - recall: 0.8202 - auc: 0.9741 - val_loss: 0.1195 - val_tp: 699.0000 - val_fp: 195.0000 - val_tn: 5726.0000 - val_fn: 99.0000 - val_accuracy: 0.9562 - val_precision: 0.7819 - val_recall: 0.8759 - val_auc: 0.9736
# Epoch 182/200
# 280/280 - 13s - loss: 0.1173 - tp: 2780.0000 - fp: 509.0000 - tn: 22967.0000 - fn: 619.0000 - accuracy: 0.9580 - precision: 0.8452 - recall: 0.8179 - auc: 0.9735 - val_loss: 0.1118 - val_tp: 624.0000 - val_fp: 90.0000 - val_tn: 5831.0000 - val_fn: 174.0000 - val_accuracy: 0.9607 - val_precision: 0.8739 - val_recall: 0.7820 - val_auc: 0.9726
# Epoch 183/200
# 280/280 - 13s - loss: 0.1154 - tp: 2809.0000 - fp: 520.0000 - tn: 22956.0000 - fn: 590.0000 - accuracy: 0.9587 - precision: 0.8438 - recall: 0.8264 - auc: 0.9741 - val_loss: 0.1160 - val_tp: 679.0000 - val_fp: 168.0000 - val_tn: 5753.0000 - val_fn: 119.0000 - val_accuracy: 0.9573 - val_precision: 0.8017 - val_recall: 0.8509 - val_auc: 0.9727
# Epoch 184/200
# 280/280 - 13s - loss: 0.1163 - tp: 2805.0000 - fp: 513.0000 - tn: 22963.0000 - fn: 594.0000 - accuracy: 0.9588 - precision: 0.8454 - recall: 0.8252 - auc: 0.9731 - val_loss: 0.1107 - val_tp: 668.0000 - val_fp: 119.0000 - val_tn: 5802.0000 - val_fn: 130.0000 - val_accuracy: 0.9629 - val_precision: 0.8488 - val_recall: 0.8371 - val_auc: 0.9745
# Epoch 185/200
# 280/280 - 13s - loss: 0.1153 - tp: 2807.0000 - fp: 493.0000 - tn: 22983.0000 - fn: 592.0000 - accuracy: 0.9596 - precision: 0.8506 - recall: 0.8258 - auc: 0.9736 - val_loss: 0.1104 - val_tp: 672.0000 - val_fp: 118.0000 - val_tn: 5803.0000 - val_fn: 126.0000 - val_accuracy: 0.9637 - val_precision: 0.8506 - val_recall: 0.8421 - val_auc: 0.9742
# Epoch 186/200
# 280/280 - 13s - loss: 0.1168 - tp: 2789.0000 - fp: 515.0000 - tn: 22961.0000 - fn: 610.0000 - accuracy: 0.9581 - precision: 0.8441 - recall: 0.8205 - auc: 0.9739 - val_loss: 0.1114 - val_tp: 621.0000 - val_fp: 89.0000 - val_tn: 5832.0000 - val_fn: 177.0000 - val_accuracy: 0.9604 - val_precision: 0.8746 - val_recall: 0.7782 - val_auc: 0.9735
# Epoch 187/200
# 280/280 - 13s - loss: 0.1150 - tp: 2795.0000 - fp: 504.0000 - tn: 22972.0000 - fn: 604.0000 - accuracy: 0.9588 - precision: 0.8472 - recall: 0.8223 - auc: 0.9738 - val_loss: 0.1162 - val_tp: 700.0000 - val_fp: 168.0000 - val_tn: 5753.0000 - val_fn: 98.0000 - val_accuracy: 0.9604 - val_precision: 0.8065 - val_recall: 0.8772 - val_auc: 0.9747
# Epoch 188/200
# 280/280 - 13s - loss: 0.1175 - tp: 2784.0000 - fp: 520.0000 - tn: 22956.0000 - fn: 615.0000 - accuracy: 0.9578 - precision: 0.8426 - recall: 0.8191 - auc: 0.9732 - val_loss: 0.1129 - val_tp: 680.0000 - val_fp: 150.0000 - val_tn: 5771.0000 - val_fn: 118.0000 - val_accuracy: 0.9601 - val_precision: 0.8193 - val_recall: 0.8521 - val_auc: 0.9728
# Epoch 189/200
# 280/280 - 13s - loss: 0.1160 - tp: 2814.0000 - fp: 519.0000 - tn: 22957.0000 - fn: 585.0000 - accuracy: 0.9589 - precision: 0.8443 - recall: 0.8279 - auc: 0.9733 - val_loss: 0.1135 - val_tp: 686.0000 - val_fp: 155.0000 - val_tn: 5766.0000 - val_fn: 112.0000 - val_accuracy: 0.9603 - val_precision: 0.8157 - val_recall: 0.8596 - val_auc: 0.9738
# Epoch 190/200
# 280/280 - 13s - loss: 0.1156 - tp: 2799.0000 - fp: 519.0000 - tn: 22957.0000 - fn: 600.0000 - accuracy: 0.9584 - precision: 0.8436 - recall: 0.8235 - auc: 0.9743 - val_loss: 0.1132 - val_tp: 694.0000 - val_fp: 158.0000 - val_tn: 5763.0000 - val_fn: 104.0000 - val_accuracy: 0.9610 - val_precision: 0.8146 - val_recall: 0.8697 - val_auc: 0.9753
# Epoch 191/200
# 280/280 - 13s - loss: 0.1177 - tp: 2780.0000 - fp: 521.0000 - tn: 22955.0000 - fn: 619.0000 - accuracy: 0.9576 - precision: 0.8422 - recall: 0.8179 - auc: 0.9735 - val_loss: 0.1123 - val_tp: 680.0000 - val_fp: 135.0000 - val_tn: 5786.0000 - val_fn: 118.0000 - val_accuracy: 0.9623 - val_precision: 0.8344 - val_recall: 0.8521 - val_auc: 0.9742
# Epoch 192/200
# 280/280 - 13s - loss: 0.1144 - tp: 2801.0000 - fp: 489.0000 - tn: 22987.0000 - fn: 598.0000 - accuracy: 0.9596 - precision: 0.8514 - recall: 0.8241 - auc: 0.9741 - val_loss: 0.1167 - val_tp: 698.0000 - val_fp: 178.0000 - val_tn: 5743.0000 - val_fn: 100.0000 - val_accuracy: 0.9586 - val_precision: 0.7968 - val_recall: 0.8747 - val_auc: 0.9741
# Epoch 193/200
# 280/280 - 13s - loss: 0.1152 - tp: 2815.0000 - fp: 501.0000 - tn: 22975.0000 - fn: 584.0000 - accuracy: 0.9596 - precision: 0.8489 - recall: 0.8282 - auc: 0.9732 - val_loss: 0.1153 - val_tp: 702.0000 - val_fp: 169.0000 - val_tn: 5752.0000 - val_fn: 96.0000 - val_accuracy: 0.9606 - val_precision: 0.8060 - val_recall: 0.8797 - val_auc: 0.9751
# Epoch 194/200
# Restoring model weights from the end of the best epoch.
# 280/280 - 13s - loss: 0.1148 - tp: 2801.0000 - fp: 493.0000 - tn: 22983.0000 - fn: 598.0000 - accuracy: 0.9594 - precision: 0.8503 - recall: 0.8241 - auc: 0.9746 - val_loss: 0.1114 - val_tp: 632.0000 - val_fp: 91.0000 - val_tn: 5830.0000 - val_fn: 166.0000 - val_accuracy: 0.9618 - val_precision: 0.8741 - val_recall: 0.7920 - val_auc: 0.9739
# Epoch 00194: early stopping

# %%
model_results(model)
model.summary()
# Out:
# Not Planets Properly Categorized (True Negatives):  5817
# Not Planets Categorized as Planets Detected (False Positives):  104
# Planets Missed (False Negatives):  148
# Planets Properly Categorized (True Positives):  650
# Total Planets:  798
# Accuracy:  0.9624944188123232
# Not Planets Properly Categorized (True Negatives):  5796
# Not Planets Categorized as Planets Detected (False Positives):  125
# Planets Missed (False Negatives):  119
# Planets Properly Categorized (True Positives):  679
# Total Planets:  798
# Accuracy:  0.9636850721833606
# Not Planets Properly Categorized (True Negatives):  5753
# Not Planets Categorized as Planets Detected (False Positives):  168
# Planets Missed (False Negatives):  102
# Planets Properly Categorized (True Positives):  696
# Total Planets:  798
# Accuracy:  0.9598154487274893
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 2001, 1)]    0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 1997, 16)     96          input_2[0][0]
# __________________________________________________________________________________________________
# input_1 (InputLayer)            [(None, 201, 1)]     0
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 999, 16)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 197, 16)      96          input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 995, 32)      2592        max_pooling1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 99, 16)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 498, 32)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 95, 32)       2592        max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 494, 64)      10304       max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 48, 32)       0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 247, 64)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 256)          295936      max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 256)          328704      max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 512)          0           lstm_1[0][0]
#                                                                  lstm[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          262656      concatenate[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          262656      dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          262656      dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 512)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 512)          262656      dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            513         dense_3[0][0]
# ==================================================================================================
# Total params: 1,691,457
# Trainable params: 1,691,457
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#save model
model_name='best_cnn_lstm_model'
save_model(model_name)
# Out:
# INFO:tensorflow:Assets written to: models/best_cnn_lstm_model/assets

# %%
#create output file
model=load_model('best_cnn_lstm_model')
model_name='w2p_cnn_lstm'
processed_final=create_prediction_output(model,model_name)
# Out:
# Predictions shape from w2p model: (33594, 1)
# Original Y shape: (33594,)
# Not Planets Properly Categorized (True Negatives):  28837
# Not Planets Categorized as Planets Detected (False Positives):  560
# Planets Missed (False Negatives):  863
# Planets Properly Categorized (True Positives):  3334
# Total Planets:  4197
# Accuracy:  0.9576412454604989
# processed_final shape: (34032, 88)
# w2p_disposition: FALSE POSITIVE    30138
# CONFIRMED          3894
# Name: w2p_disposition, dtype: int64
# koi disposition: FALSE POSITIVE    29835
# CONFIRMED          4197
# Name: koi_disposition, dtype: int64
# koi pdisposition: FALSE POSITIVE    29841
# CANDIDATE          4191
# Name: koi_pdisposition, dtype: int64
# koi pdisposition: FALSE POSITIVE    29841
# CANDIDATE          4191
# Name: koi_pdisposition, dtype: int64
# AV disposition: FALSE POSITIVE    30270
# CONFIRMED          3762
# Name: av_disposition, dtype: int64
#           kepid  tce_plnt_num koi_disposition  w2p_score w2p_disposition  \
# 0       2304168             2  FALSE POSITIVE    0.00165  FALSE POSITIVE
# 1       2304235             1  FALSE POSITIVE    0.02288  FALSE POSITIVE
# 2       2304566             1  FALSE POSITIVE    0.03161  FALSE POSITIVE
# 3       2304320             1       CONFIRMED    0.94477       CONFIRMED
# 4       2303365             2  FALSE POSITIVE    0.00480  FALSE POSITIVE
# ...         ...           ...             ...        ...             ...
# 34027  11912947             6  FALSE POSITIVE    0.00365  FALSE POSITIVE
# 34028  11922283             3  FALSE POSITIVE    0.00257  FALSE POSITIVE
# 34029  11922283             4  FALSE POSITIVE    0.12248  FALSE POSITIVE
# 34030  11922290             1  FALSE POSITIVE    0.31634  FALSE POSITIVE
# 34031  11922648             1  FALSE POSITIVE    0.68884       CONFIRMED
#
#        koi_score koi_pdisposition  av_disposition  av_vf_pc
# 0        0.00000   FALSE POSITIVE  FALSE POSITIVE   0.00099
# 1        0.00000   FALSE POSITIVE  FALSE POSITIVE   0.00390
# 2        0.00000   FALSE POSITIVE  FALSE POSITIVE   0.00566
# 3        0.99800        CANDIDATE       CONFIRMED   0.97850
# 4        0.00000   FALSE POSITIVE  FALSE POSITIVE   0.00000
# ...          ...              ...             ...       ...
# 34027    0.00000   FALSE POSITIVE  FALSE POSITIVE   0.00000
# 34028    0.00000   FALSE POSITIVE  FALSE POSITIVE   0.00000
# 34029    0.00000   FALSE POSITIVE  FALSE POSITIVE   0.00000
# 34030    0.04200   FALSE POSITIVE  FALSE POSITIVE   0.00000
# 34031    0.00000   FALSE POSITIVE  FALSE POSITIVE   0.18905
#
# [34032 rows x 9 columns]
# Accuracy after adding back non-processed kepids: 0.9581864127879642

# %% [markdown]
# ### Show results of different hyperparameter tuning models

# %%
import json
import hiplot as hip

vis_data = []
rootdir = 'w2p_optimization'
for subdirs, dirs, files in os.walk(rootdir):
    for file in files:
        if file.endswith("trial.json"):
          with open(subdirs + '/' + file, 'r') as json_file:
            data = json_file.read()
          vis_data.append(json.loads(data))

MAX_TRIALS=100

data = [{'learning_rate': vis_data[idx]['hyperparameters']['values']['learning_rate'],
         'batch_size': vis_data[idx]['hyperparameters']['values']['batch_size'], 
         'number_of_dense_layers':vis_data[idx]['hyperparameters']['values']['number_of_dense_layers'], 
         'further_global_cnn_layers':vis_data[idx]['hyperparameters']['values']['further_global_cnn_layers'], 
         'cnn_global_kernel':vis_data[idx]['hyperparameters']['values']['cnn_global_kernel'],
         'cnn_global_maxpool':vis_data[idx]['hyperparameters']['values']['cnn_global_maxpool'],
         'cnn_global_stride':vis_data[idx]['hyperparameters']['values']['cnn_global_stride'],
         'cnn_global_maxpool':vis_data[idx]['hyperparameters']['values']['cnn_global_maxpool'],
         'first_local_cnn_filters':vis_data[idx]['hyperparameters']['values']['first_local_cnn_filters'],
         'further_local_cnn_filters':vis_data[idx]['hyperparameters']['values']['further_local_cnn_filters'],
         'cnn_local_kernel':vis_data[idx]['hyperparameters']['values']['cnn_local_kernel'],
         'cnn_local_maxpool':vis_data[idx]['hyperparameters']['values']['cnn_local_maxpool'],
         'cnn_local_stride':vis_data[idx]['hyperparameters']['values']['cnn_local_stride'],
         'size_of_dense_layers':vis_data[idx]['hyperparameters']['values']['size_of_dense_layers'],
         'dense_dropout':vis_data[idx]['hyperparameters']['values']['dense_dropout'],
         'first_global_cnn_filters':vis_data[idx]['hyperparameters']['values']['first_global_cnn_filters'],         
         #'units': vis_data[idx]['hyperparameters']['values']['units'], 
         #'dense_activation': vis_data[idx]['hyperparameters']['values']['dense_activation'], 
         #'learning_rate': vis_data[idx]['hyperparameters']['values']['learning_rate'], 
         #'loss': vis_data[idx]['metrics']['metrics']['loss']['observations'][0]['value'],  
         #'val_loss': vis_data[idx]['metrics']['metrics']['val_loss']['observations'][0]['value'], 
         #'accuracy': vis_data[idx]['metrics']['metrics']['accuracy']['observations'][0]['value'],
         'val_accuracy': vis_data[idx]['metrics']['metrics']['val_accuracy']['observations'][0]['value'],
         'val_auc': vis_data[idx]['metrics']['metrics']['val_auc']['observations'][0]['value'],
         'val_loss': vis_data[idx]['metrics']['metrics']['val_loss']['observations'][0]['value'],
        } 
        for idx in range(MAX_TRIALS)] 
        
hip.Experiment.from_iterable(data).display()

# %%
baseline_results = model.evaluate([x_local_train,x_global_train],Y_train,
                                  batch_size=BATCH_SIZE, verbose=0)
for name, value in zip(model.metrics_names, baseline_results):
  print(name, ': ', value)
print()

# %% [markdown]
# #### CVRandomSearch (but using Keras Hypertune above)

# %%
cnn_global_filters_opts=[[16,32,64,128,256],[16,32],[32,64,128]]
cnn_global_kernel_opts=[5,2,3,7]
cnn_global_maxpool_window_opts=[3,5,7]
cnn_global_maxpool_stride_opts=[1,2,3]
cnn_local_filters_opts=[[16,32],[8,16,32],[8,16,32,64]]
cnn_local_kernel_opts=[5,2,3,7]
cnn_local_maxpool_window_opts=[5,7,9]
cnn_local_maxpool_stride_opts=[1,2,3]
fc_dropout_rate_opts  = [0, 0.2, 0.5]
fc_layers_opts = [[64, 64, 64, 64], [128, 128, 128], [512,512,512,512],[256,256,256]]
l2_penalty_opts = [0.01, 0.1, 0.5]
activation_opts=['relu','prelu']
optimizer_opts=['adam']
epochs_opts=[10,15,20]
batch_size_opts=[64,96,128]


keras_param_options = {
    'cnn_global_filters':cnn_global_filters_opts,
    'cnn_global_kernel':cnn_global_kernel_opts,
    'cnn_global_maxpool_window':cnn_global_maxpool_window_opts,
    'cnn_global_maxpool_stride':cnn_global_maxpool_stride_opts,
    'cnn_local_filters':cnn_local_filters_opts,
    'cnn_local_kernel':cnn_local_kernel_opts,
    'cnn_local_maxpool_window':cnn_local_maxpool_window_opts,
    'cnn_local_maxpool_stride':cnn_local_maxpool_stride_opts,
    'fc_layers': fc_layers_opts,
    'fc_dropout_rate':fc_dropout_rate_opts,
    'l2_penalty': l2_penalty_opts,
    'activation':activation_opts,
    'optimizer':optimizer_opts,
    'epochs':epochs_opts,
    'batch_size':batch_size_opts
}

def make_cnn_model(param)
    model = Sequential()   
    
    
    input_local = tf.keras.layers.Input(shape=[x_local.shape[1],1])
    input_global=tf.keras.layers.Input(shape=[x_global.shape[1],1])
    
    #combi_input = tf.keras.layers.Input((2,)) # (None, 3)
    #input_local = Lambda(lambda x: tf.expand_dims(x[:,0],-1))(combi_input) # (None, 1) 
    #input_global = Lambda(lambda x: tf.expand_dims(x[:,1],-1))(combi_input) # (None, 1)
    
    
    
    #build global branch
    for index, filters in enumerate(cnn_global_filters):       
        if not index:
            k_global=tf.keras.layers.Conv1D(filters=filters,
                                            kernel_size=cnn_global_kernel,
                                            activation=activation)(input_global)
        else:
            k_global=tf.keras.layers.Conv1D(filters=filters,
                                            kernel_size=cnn_global_kernel,
                                            activation=activation)(k_global)
        
        k_global=tf.keras.layers.MaxPooling1D(pool_size=cnn_global_window,
                                              strides=cnn_global_stride,padding='same')(k_global)
    
    #build local branch
    for index, filters in enumerate(cnn_local_filters):       
        if not index:
            k_local=tf.keras.layers.Conv1D(filters=filters,
                                            kernel_size=cnn_local_kernel,
                                            activation=activation)(input_local)
        else:
            k_local=tf.keras.layers.Conv1D(filters=filters,
                                            kernel_size=cnn_local_kernel,
                                            activation=activation)(k_local)
        
        k_local=tf.keras.layers.MaxPooling1D(pool_size=cnn_local_window,
                                              strides=cnn_local_stride,padding='same')(k_local)
    #flatten and concatenate
    k_global=tf.keras.layers.Flatten()(k_global)
    k_local=tf.keras.layers.Flatten()(k_local)
    k = tf.keras.layers.concatenate([k_local, k_global])
    
    #now add dense layers
    for fc_layer in fc_layers:
            k=tf.keras.layers.Dense(fc_layer,activation=activation)(k)
            k=tf.keras.layers.Dropout(fc_dropout_rate)(k)
    
    #output layer        
    output=tf.keras.layers.Dense(1,activation='sigmoid')(k)

    model=tf.keras.Model(inputs=[input_local,input_global],outputs=output)

    model.compile(loss=tf.keras.losses.BinaryCrossentropy()
                  ,optimizer=optimizer,
                  metrics=METRICS)
    return model

#randomizedsearchcv
#but will not take multiple inputs

model_keras = tf.keras.wrappers.scikit_learn.KerasClassifier(
    build_fn = make_cnn_model
    )

# specify other extra parameters pass to the .fit
# number of epochs is set to a large number, we'll
# let early stopping terminate the training process
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_auc', 
    verbose=1,
    patience=5,
    mode='max',
    restore_best_weights=True)

callbacks = [early_stop]

keras_fit_params = {   
    'callbacks': callbacks,
    'epochs': 20,
    'batch_size': 96,
    'validation_data': ([x_local_val,x_global_val], Y_val),
    'verbose': 1
}

rs_keras = RandomizedSearchCV( 
    model_keras, 
    param_distributions = keras_param_options,
    fit_params = keras_fit_params,
    scoring = 'neg_log_loss',
    n_iter = 3, 
    cv = 3,
    n_jobs = -1,
    verbose = 1
)


combi_input = np.stack([x_local_train, x_global_train], axis=-1)
#see https://stackoverflow.com/questions/56824968/grid-search-for-keras-with-multiple-inputs/62512554#62512554
rs_keras.fit([x_local_train,x_global_train], Y_train)
rs_keras.fit(combi_input, Y_train)

#rs_keras.fit([x_local_train,x_global_train],
#                  Y_train,
#                  validation_data=([x_local_val,x_global_val],Y_val),
#                  batch_size=BATCH_SIZE,
#                  epochs=EPOCHS,
#                  callbacks=[early_stopping],
#                  verbose=1)

print('Best score obtained: {0}'.format(rs_keras.best_score_))
print('Parameters:')
for param, value in rs_keras.best_params_.items():
    print('\t{}: {}'.format(param, value))

# %% [markdown]
# #### Old model work
# - setting initial bias
# - train simple model

# %%
#work on setting initial bias
tf.keras.backend.clear_session()
model=make_model()
model.predict([x_local_train[:10],x_global_train[:10]])
results = model.evaluate([x_local_train,x_global_train],Y_train, batch_size=BATCH_SIZE, verbose=1)
print("Loss: {:0.4f}".format(results[0]))
neg, pos = np.bincount(Y)
total = neg + pos
print(neg,pos,total)
initial_bias=np.log([pos/neg])
print(initial_bias)
model = make_model(output_bias = initial_bias)
model.predict([x_local_train[:10],x_global_train[:10]])
results = model.evaluate([x_local_train,x_global_train],Y_train, batch_size=BATCH_SIZE, verbose=1)
print("Loss: {:0.4f}".format(results[0]))

initial_weights = os.path.join(MODEL_DIR,'initial_weights')
model.save_weights(initial_weights)

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy', 
    verbose=1,
    patience=5,
    mode='max',
    restore_best_weights=True)

tf.keras.backend.clear_session()
model=make_model()
model.load_weights(initial_weights)

#history=model.fit([x_local_train,x_global_train],
#                  Y_train,
#                  validation_data=([x_local_val,x_global_val],Y_val),
#                  steps_per_epoch=25,
#                  epochs=EPOCHS*20,
#                  callbacks=[early_stopping],
#                  verbose=1)

EPOCHS=20

history=model.fit([x_local_train,x_global_train],
                  Y_train,
                  validation_data=([x_local_val,x_global_val],Y_val),
                  batch_size=BATCH_SIZE,
                  epochs=EPOCHS,
                  callbacks=[early_stopping],
                  verbose=1)

# %% [markdown]
# #### Class weighting to deal with unbalanced classes

# %%
weight_for_0 = (1 / neg)*(total)/2.0 
weight_for_1 = (1 / pos)*(total)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))

# %%
tf.keras.backend.clear_session()
model=make_model()
#model.load_weights(initial_weights)

history=model.fit([x_local_train,x_global_train],
                  Y_train,
                  validation_data=([x_local_val,x_global_val],Y_val),
                  epochs=EPOCHS,
                  batch_size=BATCH_SIZE,
                  class_weight=class_weight,
                  callbacks=[early_stopping],
                  verbose=2)

# %%
plot_metrics(history)
plot_cm(Y_val, val_predictions_baseline)

val_predictions_baseline = model.predict([x_local_val,x_global_val], batch_size=BATCH_SIZE)
train_predictions_baseline = model.predict([x_local_train,x_global_train], batch_size=BATCH_SIZE)

plot_roc("Train Baseline", Y_train, train_predictions_baseline, color=colors[0])
plot_roc("Test Baseline", Y_val, val_predictions_baseline, color=colors[0], linestyle='--')
plt.legend(loc='lower right')

# %% [markdown]
# #### Oversampling to deal with unbalanced classes

# %%
#oversampling
bool_train_labels = Y_train != 0
pos_features_local = x_local_train[bool_train_labels]
neg_features_local = x_local_train[~bool_train_labels]
pos_features_global = x_global_train[bool_train_labels]
neg_features_global = x_global_train[~bool_train_labels]

pos_labels = Y_train[bool_train_labels]
neg_labels = Y_train[~bool_train_labels]

# %%
ids = np.arange(len(pos_features_local))
choices = np.random.choice(ids, len(neg_features_local))

res_pos_features_local = pos_features_local[choices]
res_pos_features_global = pos_features_global[choices]
res_pos_labels = pos_labels[choices]

print(res_pos_features_local.shape,res_pos_features_global.shape)

# %%
res_features_local=np.concatenate([res_pos_features_local,neg_features_local],axis=0)
res_features_global=np.concatenate([res_pos_features_global,neg_features_global],axis=0)
res_labels=np.concatenate([res_pos_labels,neg_labels],axis=0)
order=np.arange(len(res_labels))
np.random.shuffle(order)
res_features_local=res_features_local[order]
res_features_global=res_features_global[order]
res_labels=res_labels[order]
print(res_features_local.shape,res_features_global.shape,res_labels.shape)

# %%
tf.keras.backend.clear_session()
model=make_model()
history = model.fit(
        [res_features_local,res_features_global],
        res_labels,
        validation_data=([x_local_val,x_global_val],Y_val),
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        callbacks=[early_stopping],
        verbose=2)

# %%
plot_metrics(history)
plot_cm(Y_val, val_predictions_baseline)

val_predictions_baseline = model.predict([x_local_val,x_global_val], batch_size=BATCH_SIZE)
train_predictions_baseline = model.predict([x_local_train,x_global_train], batch_size=BATCH_SIZE)

plot_roc("Train Baseline", Y_train, train_predictions_baseline, color=colors[0])
plot_roc("Test Baseline", Y_val, val_predictions_baseline, color=colors[0], linestyle='--')
plt.legend(loc='lower right')
